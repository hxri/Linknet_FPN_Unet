# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import tensorflow as tf
import cv2
import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
DATA_DIR = './dataset2/'

# %%
x_train_dir = os.path.join(DATA_DIR, 'train_images')
y_train_dir = os.path.join(DATA_DIR, 'train_annotations')

x_valid_dir = os.path.join(DATA_DIR, 'val_images')
y_valid_dir = os.path.join(DATA_DIR, 'val_annotations')

# %% [markdown]
# ## Dataloader

# %%
# helper function for data visualization
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()
    
# helper function for data visualization    
def denormalize(x):
    """Scale image to range 0..1 for correct plot"""
    x_max = np.percentile(x, 98)
    x_min = np.percentile(x, 2)    
    x = (x - x_min) / (x_max - x_min)
    x = x.clip(0, 1)
    return x
    

# classes for data loading and preprocessing
class Dataset:
    """CamVid Dataset. Read images, apply augmentation and preprocessing transformations.
    
    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing 
            (e.g. noralization, shape manipulation, etc.)
    
    """
    
    CLASSES = ['background', 'blob']
    
    def __init__(
            self, 
            images_dir, 
            masks_dir, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
    ):
        self.ids = os.listdir(images_dir)
        self.images_fps = [os.path.join(images_dir, image_id) for image_id in self.ids]
        self.masks_fps = [os.path.join(masks_dir, image_id) for image_id in self.ids]
        
        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        # read data
        image = cv2.imread(self.images_fps[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.masks_fps[i], 0)
        
        # extract certain classes from mask (e.g. cars)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1).astype('float')
        
        # add background if mask is not binary
        if mask.shape[-1] != 1:
            background = 1 - mask.sum(axis=-1, keepdims=True)
            mask = np.concatenate((mask, background), axis=-1)
        
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
            
        return image, mask
        
    def __len__(self):
        return len(self.ids)
    
    
class Dataloder(keras.utils.Sequence):
    """Load data from dataset and form batches
    
    Args:
        dataset: instance of Dataset class for image loading and preprocessing.
        batch_size: Integet number of images in batch.
        shuffle: Boolean, if `True` shuffle image indexes each epoch.
    """
    
    def __init__(self, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(dataset))

        self.on_epoch_end()

    def __getitem__(self, i):
        
        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        data = []
        for j in range(start, stop):
            data.append(self.dataset[j])
        
        # transpose list of lists
        batch = [np.stack(samples, axis=0) for samples in zip(*data)]
        
        return (batch[0],batch[1])
    
    def __len__(self):
        """Denotes the number of batches per epoch"""
        return len(self.indexes) // self.batch_size
    
    def on_epoch_end(self):
        """Callback function to shuffle indexes each epoch"""
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

# %%
# Lets look at data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['background', 'blob'])

image, mask = dataset[5] # get some sample
visualize(
    image=image, 
    background=mask[..., 0].squeeze(),
    blob=mask[..., 1].squeeze(),
)

# %% [markdown]
# ## Augmentation

# %%
import albumentations as A

# %%
def round_clip_0_1(x, **kwargs):
    return x.round().clip(0, 1)

# define heavy augmentations
def get_training_augmentation():
    train_transform = [

        A.Resize (320, 480, interpolation=1, always_apply=True, p=1),
    ]
    return A.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        A.PadIfNeeded(384, 480, always_apply=True)
    ]
    return A.Compose(test_transform)

def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        A.Lambda(image=preprocessing_fn),
    ]
    return A.Compose(_transform)

# %%
# Lets look at augmented data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['background', 'blob'], augmentation=get_training_augmentation())

image, mask = dataset[12] # get some sample
visualize(
    image=image, 
    background=mask[..., 0].squeeze(),
    blob=mask[..., 1].squeeze(),
)

# %% [markdown]
# ## Model

# %%
# %env SM_FRAMEWORK=tf.keras

import segmentation_models as sm
# Out:
# env: SM_FRAMEWORK=tf.keras
# Segmentation Models: using `tf.keras` framework.

# %%
BACKBONE = 'efficientnetb0'
BATCH_SIZE = 2
CLASSES = ['background', 'blob']
LR = 0.0001
EPOCHS = 5

preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
# define network parameters
n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
activation = 'sigmoid' if n_classes == 1 else 'softmax'

def build_model_func():
    #create model
    model = sm.FPN(BACKBONE, classes=n_classes, activation=activation)

    # define optomizer
    optim = keras.optimizers.Adam(LR)

    # Segmentation models losses can be combined together by '+' and scaled by integer or float factor
    dice_loss = sm.losses.DiceLoss()
    focal_loss = sm.losses.BinaryFocalLoss() if n_classes == 1 else sm.losses.CategoricalFocalLoss()
    total_loss = dice_loss + (1 * focal_loss)

    # actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
    # total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss 

    metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5), tf.keras.metrics.Precision(), tf.keras.metrics.AUC()]

    # compile keras model with defined optimozer, loss and metrics
    model.compile(optim, total_loss, metrics)
    return model

# %%
# Dataset for train images
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

# Dataset for validation images
valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

train_dataloader = Dataloder(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_dataloader = Dataloder(valid_dataset, batch_size=1, shuffle=False)

# check shapes for errors
assert train_dataloader[0][0].shape == (BATCH_SIZE, 320, 480, 3)
assert train_dataloader[0][1].shape == (BATCH_SIZE, 320, 480, n_classes)



# define callbacks for learning rate scheduling and best checkpoints saving
filepath = "checkpoints/saved_weights.{epoch:02d}.hdf5"
callbacks = [
    keras.callbacks.ModelCheckpoint(
            filepath, 
            save_weights_only=True, 
            save_best_only=False, 
            mode="min",
            verbose=0,
            save_freq='epoch',
        ),
    keras.callbacks.ReduceLROnPlateau(),
]

# %%
print(valid_dataloader[0][0].shape)
# Out:
# (1, 320, 480, 3)

# %%
#checkpoint_path = "checkpoints/saved_weights.03.hdf5"
checkpoint_path = None
from tensorflow.keras.models import model_from_json

def get_init_epoch(checkpoint_path):
    return int(checkpoint_path.split('.')[1])

# Load checkpoint:
if checkpoint_path is not None:
    # Load model:
    model = build_model_func()
    model.load_weights(checkpoint_path)
    # Finding the epoch index from which we are resuming
    initial_epoch = get_init_epoch(checkpoint_path)
    # Calculating the correct value of count
    count = initial_epoch*BATCH_SIZE
    # Update the value of count in callback instance
    callbacks[1].count = count
else:
    model = build_model_func()
    initial_epoch = 0

# train model
history = model.fit(
    train_dataloader, 
    steps_per_epoch=len(train_dataloader), 
    epochs=100, 
    callbacks=callbacks,
    initial_epoch=initial_epoch,
    validation_data=valid_dataloader, 
    validation_steps=len(valid_dataloader),
)
# Out:
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b0_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 16809984/16804768 [==============================] - 13s 1us/step
# Epoch 1/100
# 35/35 [==============================] - 22s 619ms/step - loss: 0.5660 - iou_score: 0.4749 - f1-score: 0.5322 - precision: 0.8709 - auc: 0.9156 - val_loss: 0.9829 - val_iou_score: 0.0899 - val_f1-score: 0.1528 - val_precision: 0.2899 - val_auc: 0.4335
# Epoch 2/100
# 35/35 [==============================] - 20s 576ms/step - loss: 0.3997 - iou_score: 0.6724 - f1-score: 0.6987 - precision: 0.9864 - auc: 0.9957 - val_loss: 0.6575 - val_iou_score: 0.4764 - val_f1-score: 0.5582 - val_precision: 0.9262 - val_auc: 0.9290
# Epoch 3/100
# 35/35 [==============================] - 21s 588ms/step - loss: 0.3695 - iou_score: 0.8102 - f1-score: 0.8276 - precision: 0.9918 - auc: 0.9984 - val_loss: 0.5407 - val_iou_score: 0.7295 - val_f1-score: 0.7801 - val_precision: 0.9635 - val_auc: 0.9708
# Epoch 4/100
# 35/35 [==============================] - 19s 557ms/step - loss: 0.3596 - iou_score: 0.8368 - f1-score: 0.8510 - precision: 0.9933 - auc: 0.9989 - val_loss: 0.5315 - val_iou_score: 0.7323 - val_f1-score: 0.7872 - val_precision: 0.9452 - val_auc: 0.9618
# Epoch 5/100
# 35/35 [==============================] - 20s 561ms/step - loss: 0.3549 - iou_score: 0.9254 - f1-score: 0.9383 - precision: 0.9942 - auc: 0.9991 - val_loss: 0.4844 - val_iou_score: 0.8166 - val_f1-score: 0.8668 - val_precision: 0.9641 - val_auc: 0.9832
# Epoch 6/100
# 35/35 [==============================] - 20s 585ms/step - loss: 0.3516 - iou_score: 0.9287 - f1-score: 0.9401 - precision: 0.9948 - auc: 0.9993 - val_loss: 0.4504 - val_iou_score: 0.8262 - val_f1-score: 0.8665 - val_precision: 0.9706 - val_auc: 0.9879
# Epoch 7/100
# 35/35 [==============================] - 21s 587ms/step - loss: 0.3509 - iou_score: 0.9286 - f1-score: 0.9400 - precision: 0.9950 - auc: 0.9993 - val_loss: 0.4081 - val_iou_score: 0.9030 - val_f1-score: 0.9318 - val_precision: 0.9836 - val_auc: 0.9945
# Epoch 8/100
# 35/35 [==============================] - 21s 590ms/step - loss: 0.3491 - iou_score: 0.9401 - f1-score: 0.9506 - precision: 0.9953 - auc: 0.9994 - val_loss: 0.3940 - val_iou_score: 0.9329 - val_f1-score: 0.9593 - val_precision: 0.9858 - val_auc: 0.9961
# Epoch 9/100
# 35/35 [==============================] - 20s 585ms/step - loss: 0.3474 - iou_score: 0.9705 - f1-score: 0.9802 - precision: 0.9956 - auc: 0.9995 - val_loss: 0.3809 - val_iou_score: 0.9411 - val_f1-score: 0.9652 - val_precision: 0.9877 - val_auc: 0.9972
# Epoch 10/100
# 35/35 [==============================] - 20s 576ms/step - loss: 0.3467 - iou_score: 0.9714 - f1-score: 0.9807 - precision: 0.9959 - auc: 0.9996 - val_loss: 0.3747 - val_iou_score: 0.9418 - val_f1-score: 0.9670 - val_precision: 0.9878 - val_auc: 0.9971
# Epoch 11/100
# 35/35 [==============================] - 20s 579ms/step - loss: 0.3465 - iou_score: 0.9712 - f1-score: 0.9806 - precision: 0.9959 - auc: 0.9995 - val_loss: 0.3748 - val_iou_score: 0.9405 - val_f1-score: 0.9663 - val_precision: 0.9872 - val_auc: 0.9968
# Epoch 12/100
# 35/35 [==============================] - 20s 562ms/step - loss: 0.3456 - iou_score: 0.9628 - f1-score: 0.9716 - precision: 0.9960 - auc: 0.9996 - val_loss: 0.3665 - val_iou_score: 0.9510 - val_f1-score: 0.9730 - val_precision: 0.9894 - val_auc: 0.9974
# Epoch 13/100
# 35/35 [==============================] - 20s 584ms/step - loss: 0.3447 - iou_score: 0.9741 - f1-score: 0.9821 - precision: 0.9963 - auc: 0.9997 - val_loss: 0.3605 - val_iou_score: 0.9594 - val_f1-score: 0.9780 - val_precision: 0.9912 - val_auc: 0.9980
# Epoch 14/100
# 35/35 [==============================] - 20s 561ms/step - loss: 0.3439 - iou_score: 0.9844 - f1-score: 0.9920 - precision: 0.9965 - auc: 0.9997 - val_loss: 0.3629 - val_iou_score: 0.9560 - val_f1-score: 0.9760 - val_precision: 0.9907 - val_auc: 0.9976
# Epoch 15/100
# 35/35 [==============================] - 20s 578ms/step - loss: 0.3433 - iou_score: 0.9851 - f1-score: 0.9924 - precision: 0.9967 - auc: 0.9997 - val_loss: 0.3647 - val_iou_score: 0.9527 - val_f1-score: 0.9740 - val_precision: 0.9898 - val_auc: 0.9974
# Epoch 16/100
# 35/35 [==============================] - 20s 574ms/step - loss: 0.3429 - iou_score: 0.9858 - f1-score: 0.9927 - precision: 0.9969 - auc: 0.9998 - val_loss: 0.3608 - val_iou_score: 0.9587 - val_f1-score: 0.9777 - val_precision: 0.9913 - val_auc: 0.9977
# Epoch 17/100
# 35/35 [==============================] - 20s 564ms/step - loss: 0.3431 - iou_score: 0.9853 - f1-score: 0.9925 - precision: 0.9968 - auc: 0.9997 - val_loss: 0.3604 - val_iou_score: 0.9594 - val_f1-score: 0.9780 - val_precision: 0.9913 - val_auc: 0.9977
# Epoch 18/100
# 35/35 [==============================] - 20s 579ms/step - loss: 0.3429 - iou_score: 0.9855 - f1-score: 0.9926 - precision: 0.9968 - auc: 0.9997 - val_loss: 0.3649 - val_iou_score: 0.9528 - val_f1-score: 0.9741 - val_precision: 0.9901 - val_auc: 0.9970
# Epoch 19/100
# 35/35 [==============================] - 19s 555ms/step - loss: 0.3427 - iou_score: 0.9856 - f1-score: 0.9927 - precision: 0.9969 - auc: 0.9997 - val_loss: 0.3635 - val_iou_score: 0.9546 - val_f1-score: 0.9753 - val_precision: 0.9904 - val_auc: 0.9972
# Epoch 20/100
# 35/35 [==============================] - 20s 578ms/step - loss: 0.3419 - iou_score: 0.9871 - f1-score: 0.9934 - precision: 0.9972 - auc: 0.9998 - val_loss: 0.3600 - val_iou_score: 0.9597 - val_f1-score: 0.9783 - val_precision: 0.9915 - val_auc: 0.9977
# Epoch 21/100
# 35/35 [==============================] - 20s 560ms/step - loss: 0.3419 - iou_score: 0.9869 - f1-score: 0.9934 - precision: 0.9972 - auc: 0.9998 - val_loss: 0.3672 - val_iou_score: 0.9491 - val_f1-score: 0.9717 - val_precision: 0.9889 - val_auc: 0.9968
# Epoch 22/100
# 35/35 [==============================] - 20s 572ms/step - loss: 0.3418 - iou_score: 0.9871 - f1-score: 0.9934 - precision: 0.9972 - auc: 0.9998 - val_loss: 0.3587 - val_iou_score: 0.9622 - val_f1-score: 0.9798 - val_precision: 0.9920 - val_auc: 0.9981
# Epoch 23/100
# 35/35 [==============================] - 20s 557ms/step - loss: 0.3415 - iou_score: 0.9876 - f1-score: 0.9937 - precision: 0.9973 - auc: 0.9998 - val_loss: 0.3604 - val_iou_score: 0.9591 - val_f1-score: 0.9778 - val_precision: 0.9910 - val_auc: 0.9974
# Epoch 24/100
# 35/35 [==============================] - 20s 573ms/step - loss: 0.3413 - iou_score: 0.9878 - f1-score: 0.9938 - precision: 0.9974 - auc: 0.9998 - val_loss: 0.3593 - val_iou_score: 0.9605 - val_f1-score: 0.9787 - val_precision: 0.9914 - val_auc: 0.9975
# Epoch 25/100
# 35/35 [==============================] - 20s 571ms/step - loss: 0.3410 - iou_score: 0.9882 - f1-score: 0.9940 - precision: 0.9975 - auc: 0.9998 - val_loss: 0.3640 - val_iou_score: 0.9542 - val_f1-score: 0.9749 - val_precision: 0.9902 - val_auc: 0.9967
# Epoch 26/100
# 35/35 [==============================] - 20s 560ms/step - loss: 0.3409 - iou_score: 0.9884 - f1-score: 0.9941 - precision: 0.9974 - auc: 0.9998 - val_loss: 0.3588 - val_iou_score: 0.9613 - val_f1-score: 0.9791 - val_precision: 0.9916 - val_auc: 0.9976
# Epoch 27/100
# 35/35 [==============================] - 20s 571ms/step - loss: 0.3406 - iou_score: 0.9888 - f1-score: 0.9943 - precision: 0.9976 - auc: 0.9998 - val_loss: 0.3591 - val_iou_score: 0.9611 - val_f1-score: 0.9791 - val_precision: 0.9917 - val_auc: 0.9974
# Epoch 28/100
# 35/35 [==============================] - 19s 557ms/step - loss: 0.3403 - iou_score: 0.9894 - f1-score: 0.9946 - precision: 0.9977 - auc: 0.9998 - val_loss: 0.3579 - val_iou_score: 0.9630 - val_f1-score: 0.9801 - val_precision: 0.9919 - val_auc: 0.9977
# Epoch 29/100
# 35/35 [==============================] - 21s 586ms/step - loss: 0.3403 - iou_score: 0.9893 - f1-score: 0.9946 - precision: 0.9977 - auc: 0.9998 - val_loss: 0.3589 - val_iou_score: 0.9610 - val_f1-score: 0.9789 - val_precision: 0.9915 - val_auc: 0.9974
# Epoch 30/100
# 35/35 [==============================] - 19s 555ms/step - loss: 0.3405 - iou_score: 0.9891 - f1-score: 0.9945 - precision: 0.9976 - auc: 0.9998 - val_loss: 0.3588 - val_iou_score: 0.9615 - val_f1-score: 0.9792 - val_precision: 0.9916 - val_auc: 0.9974
# Epoch 31/100
# 35/35 [==============================] - 20s 569ms/step - loss: 0.3399 - iou_score: 0.9899 - f1-score: 0.9949 - precision: 0.9978 - auc: 0.9998 - val_loss: 0.3587 - val_iou_score: 0.9616 - val_f1-score: 0.9793 - val_precision: 0.9916 - val_auc: 0.9974
# Epoch 32/100
# 35/35 [==============================] - 20s 579ms/step - loss: 0.3397 - iou_score: 0.9902 - f1-score: 0.9950 - precision: 0.9978 - auc: 0.9998 - val_loss: 0.3583 - val_iou_score: 0.9625 - val_f1-score: 0.9798 - val_precision: 0.9918 - val_auc: 0.9975
# Epoch 33/100
# 35/35 [==============================] - 20s 577ms/step - loss: 0.3396 - iou_score: 0.9902 - f1-score: 0.9951 - precision: 0.9979 - auc: 0.9998 - val_loss: 0.3599 - val_iou_score: 0.9597 - val_f1-score: 0.9782 - val_precision: 0.9912 - val_auc: 0.9973
# Epoch 34/100
# 35/35 [==============================] - 19s 550ms/step - loss: 0.3403 - iou_score: 0.9889 - f1-score: 0.9944 - precision: 0.9976 - auc: 0.9998 - val_loss: 0.3644 - val_iou_score: 0.9540 - val_f1-score: 0.9749 - val_precision: 0.9903 - val_auc: 0.9964
# Epoch 35/100
# 35/35 [==============================] - 20s 574ms/step - loss: 0.3401 - iou_score: 0.9894 - f1-score: 0.9946 - precision: 0.9977 - auc: 0.9998 - val_loss: 0.3612 - val_iou_score: 0.9582 - val_f1-score: 0.9772 - val_precision: 0.9909 - val_auc: 0.9969
# Epoch 36/100
# 35/35 [==============================] - 21s 586ms/step - loss: 0.3393 - iou_score: 0.9908 - f1-score: 0.9953 - precision: 0.9980 - auc: 0.9999 - val_loss: 0.3627 - val_iou_score: 0.9562 - val_f1-score: 0.9762 - val_precision: 0.9906 - val_auc: 0.9966
# Epoch 37/100
# 35/35 [==============================] - 19s 555ms/step - loss: 0.3394 - iou_score: 0.9905 - f1-score: 0.9952 - precision: 0.9979 - auc: 0.9998 - val_loss: 0.3598 - val_iou_score: 0.9601 - val_f1-score: 0.9784 - val_precision: 0.9912 - val_auc: 0.9971
# Epoch 38/100
# 35/35 [==============================] - 20s 560ms/step - loss: 0.3391 - iou_score: 0.9910 - f1-score: 0.9954 - precision: 0.9981 - auc: 0.9999 - val_loss: 0.3603 - val_iou_score: 0.9599 - val_f1-score: 0.9783 - val_precision: 0.9914 - val_auc: 0.9971
# Epoch 39/100
# 35/35 [==============================] - 20s 577ms/step - loss: 0.3386 - iou_score: 0.9919 - f1-score: 0.9959 - precision: 0.9983 - auc: 0.9999 - val_loss: 0.3591 - val_iou_score: 0.9612 - val_f1-score: 0.9790 - val_precision: 0.9915 - val_auc: 0.9971
# Epoch 40/100
# 35/35 [==============================] - 20s 579ms/step - loss: 0.3383 - iou_score: 0.9926 - f1-score: 0.9963 - precision: 0.9984 - auc: 0.9999 - val_loss: 0.3591 - val_iou_score: 0.9612 - val_f1-score: 0.9790 - val_precision: 0.9915 - val_auc: 0.9971
# Epoch 41/100
# 35/35 [==============================] - 20s 567ms/step - loss: 0.3380 - iou_score: 0.9931 - f1-score: 0.9965 - precision: 0.9985 - auc: 0.9999 - val_loss: 0.3591 - val_iou_score: 0.9611 - val_f1-score: 0.9790 - val_precision: 0.9915 - val_auc: 0.9971
# Epoch 42/100
# 35/35 [==============================] - 20s 574ms/step - loss: 0.3381 - iou_score: 0.9929 - f1-score: 0.9964 - precision: 0.9984 - auc: 0.9999 - val_loss: 0.3593 - val_iou_score: 0.9608 - val_f1-score: 0.9788 - val_precision: 0.9914 - val_auc: 0.9971
# Epoch 43/100
# 35/35 [==============================] - 20s 578ms/step - loss: 0.3379 - iou_score: 0.9934 - f1-score: 0.9967 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3596 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision: 0.9913 - val_auc: 0.9970
# Epoch 44/100
# 35/35 [==============================] - 20s 578ms/step - loss: 0.3381 - iou_score: 0.9930 - f1-score: 0.9965 - precision: 0.9984 - auc: 0.9999 - val_loss: 0.3599 - val_iou_score: 0.9599 - val_f1-score: 0.9783 - val_precision: 0.9912 - val_auc: 0.9970
# Epoch 45/100
# 35/35 [==============================] - 20s 561ms/step - loss: 0.3378 - iou_score: 0.9936 - f1-score: 0.9968 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9606 - val_f1-score: 0.9787 - val_precision: 0.9914 - val_auc: 0.9971
# Epoch 46/100
# 35/35 [==============================] - 20s 582ms/step - loss: 0.3377 - iou_score: 0.9938 - f1-score: 0.9969 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3601 - val_iou_score: 0.9597 - val_f1-score: 0.9781 - val_precision: 0.9912 - val_auc: 0.9969
# Epoch 47/100
# 35/35 [==============================] - 21s 586ms/step - loss: 0.3379 - iou_score: 0.9934 - f1-score: 0.9967 - precision: 0.9985 - auc: 0.9999 - val_loss: 0.3599 - val_iou_score: 0.9600 - val_f1-score: 0.9783 - val_precision: 0.9912 - val_auc: 0.9970
# Epoch 48/100
# 35/35 [==============================] - 20s 573ms/step - loss: 0.3380 - iou_score: 0.9933 - f1-score: 0.9966 - precision: 0.9985 - auc: 0.9999 - val_loss: 0.3597 - val_iou_score: 0.9603 - val_f1-score: 0.9785 - val_precision: 0.9913 - val_auc: 0.9970
# Epoch 49/100
# 35/35 [==============================] - 20s 559ms/step - loss: 0.3377 - iou_score: 0.9937 - f1-score: 0.9968 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3597 - val_iou_score: 0.9602 - val_f1-score: 0.9785 - val_precision: 0.9913 - val_auc: 0.9970
# Epoch 50/100
# 35/35 [==============================] - 20s 564ms/step - loss: 0.3378 - iou_score: 0.9936 - f1-score: 0.9968 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3597 - val_iou_score: 0.9603 - val_f1-score: 0.9785 - val_precision: 0.9913 - val_auc: 0.9970
# Epoch 51/100
# 35/35 [==============================] - 20s 565ms/step - loss: 0.3377 - iou_score: 0.9938 - f1-score: 0.9969 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3597 - val_iou_score: 0.9602 - val_f1-score: 0.9784 - val_precision: 0.9913 - val_auc: 0.9970
# Epoch 52/100
# 35/35 [==============================] - 20s 565ms/step - loss: 0.3376 - iou_score: 0.9941 - f1-score: 0.9970 - precision: 0.9987 - auc: 0.9999 - val_loss: 0.3597 - val_iou_score: 0.9603 - val_f1-score: 0.9785 - val_precision: 0.9913 - val_auc: 0.9970
# Epoch 53/100
# 35/35 [==============================] - 20s 579ms/step - loss: 0.3377 - iou_score: 0.9937 - f1-score: 0.9968 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3597 - val_iou_score: 0.9603 - val_f1-score: 0.9785 - val_precision: 0.9913 - val_auc: 0.9970
# Epoch 54/100
# 35/35 [==============================] - 20s 575ms/step - loss: 0.3377 - iou_score: 0.9938 - f1-score: 0.9969 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3597 - val_iou_score: 0.9603 - val_f1-score: 0.9785 - val_precision: 0.9913 - val_auc: 0.9970
# Epoch 55/100
# 35/35 [==============================] - 20s 560ms/step - loss: 0.3377 - iou_score: 0.9938 - f1-score: 0.9969 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 56/100
# 35/35 [==============================] - 20s 573ms/step - loss: 0.3378 - iou_score: 0.9937 - f1-score: 0.9968 - precision: 0.9985 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9606 - val_f1-score: 0.9787 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 57/100
# 35/35 [==============================] - 21s 605ms/step - loss: 0.3377 - iou_score: 0.9939 - f1-score: 0.9969 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3596 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision: 0.9913 - val_auc: 0.9970
# Epoch 58/100
# 35/35 [==============================] - 21s 591ms/step - loss: 0.3377 - iou_score: 0.9938 - f1-score: 0.9969 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9606 - val_f1-score: 0.9787 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 59/100
# 35/35 [==============================] - 20s 576ms/step - loss: 0.3377 - iou_score: 0.9938 - f1-score: 0.9969 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 60/100
# 35/35 [==============================] - 20s 583ms/step - loss: 0.3377 - iou_score: 0.9939 - f1-score: 0.9969 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3596 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 61/100
# 35/35 [==============================] - 20s 585ms/step - loss: 0.3378 - iou_score: 0.9936 - f1-score: 0.9968 - precision: 0.9985 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 62/100
# 35/35 [==============================] - 20s 579ms/step - loss: 0.3377 - iou_score: 0.9938 - f1-score: 0.9969 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9606 - val_f1-score: 0.9787 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 63/100
# 35/35 [==============================] - 20s 573ms/step - loss: 0.3378 - iou_score: 0.9937 - f1-score: 0.9968 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9606 - val_f1-score: 0.9787 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 64/100
# 35/35 [==============================] - 20s 562ms/step - loss: 0.3376 - iou_score: 0.9939 - f1-score: 0.9969 - precision: 0.9987 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9606 - val_f1-score: 0.9787 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 65/100
# 35/35 [==============================] - 20s 581ms/step - loss: 0.3378 - iou_score: 0.9937 - f1-score: 0.9968 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9606 - val_f1-score: 0.9787 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 66/100
# 35/35 [==============================] - 20s 568ms/step - loss: 0.3379 - iou_score: 0.9935 - f1-score: 0.9967 - precision: 0.9985 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 67/100
# 35/35 [==============================] - 20s 574ms/step - loss: 0.3380 - iou_score: 0.9933 - f1-score: 0.9966 - precision: 0.9985 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9606 - val_f1-score: 0.9787 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 68/100
# 35/35 [==============================] - 20s 581ms/step - loss: 0.3379 - iou_score: 0.9935 - f1-score: 0.9967 - precision: 0.9985 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9606 - val_f1-score: 0.9787 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 69/100
# 35/35 [==============================] - 20s 579ms/step - loss: 0.3378 - iou_score: 0.9936 - f1-score: 0.9968 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9606 - val_f1-score: 0.9787 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 70/100
# 35/35 [==============================] - 20s 562ms/step - loss: 0.3378 - iou_score: 0.9936 - f1-score: 0.9968 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9606 - val_f1-score: 0.9787 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 71/100
# 35/35 [==============================] - 20s 576ms/step - loss: 0.3378 - iou_score: 0.9935 - f1-score: 0.9967 - precision: 0.9985 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 72/100
# 35/35 [==============================] - 19s 556ms/step - loss: 0.3375 - iou_score: 0.9942 - f1-score: 0.9971 - precision: 0.9987 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9606 - val_f1-score: 0.9787 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 73/100
# 35/35 [==============================] - 20s 574ms/step - loss: 0.3377 - iou_score: 0.9937 - f1-score: 0.9968 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9606 - val_f1-score: 0.9787 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 74/100
# 35/35 [==============================] - 20s 560ms/step - loss: 0.3377 - iou_score: 0.9939 - f1-score: 0.9969 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9606 - val_f1-score: 0.9787 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 75/100
# 35/35 [==============================] - 20s 576ms/step - loss: 0.3378 - iou_score: 0.9936 - f1-score: 0.9968 - precision: 0.9985 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9606 - val_f1-score: 0.9787 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 76/100
# 35/35 [==============================] - 20s 566ms/step - loss: 0.3376 - iou_score: 0.9940 - f1-score: 0.9970 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9606 - val_f1-score: 0.9787 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 77/100
# 35/35 [==============================] - 20s 579ms/step - loss: 0.3376 - iou_score: 0.9940 - f1-score: 0.9970 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9606 - val_f1-score: 0.9787 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 78/100
# 35/35 [==============================] - 21s 594ms/step - loss: 0.3376 - iou_score: 0.9941 - f1-score: 0.9970 - precision: 0.9987 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 79/100
# 35/35 [==============================] - 20s 573ms/step - loss: 0.3379 - iou_score: 0.9934 - f1-score: 0.9967 - precision: 0.9985 - auc: 0.9999 - val_loss: 0.3596 - val_iou_score: 0.9605 - val_f1-score: 0.9787 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 80/100
# 35/35 [==============================] - 20s 570ms/step - loss: 0.3376 - iou_score: 0.9941 - f1-score: 0.9970 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 81/100
# 35/35 [==============================] - 20s 577ms/step - loss: 0.3376 - iou_score: 0.9939 - f1-score: 0.9969 - precision: 0.9987 - auc: 0.9999 - val_loss: 0.3596 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 82/100
# 35/35 [==============================] - 19s 554ms/step - loss: 0.3377 - iou_score: 0.9938 - f1-score: 0.9969 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3596 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 83/100
# 35/35 [==============================] - 19s 556ms/step - loss: 0.3376 - iou_score: 0.9940 - f1-score: 0.9970 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3596 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 84/100
# 35/35 [==============================] - 20s 576ms/step - loss: 0.3379 - iou_score: 0.9934 - f1-score: 0.9967 - precision: 0.9985 - auc: 0.9999 - val_loss: 0.3596 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 85/100
# 35/35 [==============================] - 20s 579ms/step - loss: 0.3376 - iou_score: 0.9940 - f1-score: 0.9970 - precision: 0.9987 - auc: 0.9999 - val_loss: 0.3596 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 86/100
# 35/35 [==============================] - 20s 559ms/step - loss: 0.3376 - iou_score: 0.9939 - f1-score: 0.9969 - precision: 0.9987 - auc: 0.9999 - val_loss: 0.3596 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 87/100
# 35/35 [==============================] - 20s 571ms/step - loss: 0.3377 - iou_score: 0.9938 - f1-score: 0.9969 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3596 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 88/100
# 35/35 [==============================] - 20s 570ms/step - loss: 0.3378 - iou_score: 0.9937 - f1-score: 0.9968 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3596 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 89/100
# 35/35 [==============================] - 21s 586ms/step - loss: 0.3378 - iou_score: 0.9937 - f1-score: 0.9968 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3596 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 90/100
# 35/35 [==============================] - 20s 584ms/step - loss: 0.3380 - iou_score: 0.9933 - f1-score: 0.9966 - precision: 0.9985 - auc: 0.9999 - val_loss: 0.3596 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 91/100
# 35/35 [==============================] - 20s 574ms/step - loss: 0.3378 - iou_score: 0.9937 - f1-score: 0.9968 - precision: 0.9985 - auc: 0.9999 - val_loss: 0.3596 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 92/100
# 35/35 [==============================] - 20s 580ms/step - loss: 0.3378 - iou_score: 0.9936 - f1-score: 0.9968 - precision: 0.9985 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 93/100
# 35/35 [==============================] - 19s 550ms/step - loss: 0.3378 - iou_score: 0.9937 - f1-score: 0.9968 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9606 - val_f1-score: 0.9787 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 94/100
# 35/35 [==============================] - 20s 562ms/step - loss: 0.3379 - iou_score: 0.9935 - f1-score: 0.9967 - precision: 0.9985 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9605 - val_f1-score: 0.9787 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 95/100
# 35/35 [==============================] - 19s 555ms/step - loss: 0.3376 - iou_score: 0.9939 - f1-score: 0.9969 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 96/100
# 35/35 [==============================] - 20s 572ms/step - loss: 0.3378 - iou_score: 0.9937 - f1-score: 0.9968 - precision: 0.9985 - auc: 0.9999 - val_loss: 0.3596 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 97/100
# 35/35 [==============================] - 20s 580ms/step - loss: 0.3377 - iou_score: 0.9939 - f1-score: 0.9969 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 98/100
# 35/35 [==============================] - 19s 550ms/step - loss: 0.3377 - iou_score: 0.9938 - f1-score: 0.9969 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 99/100
# 35/35 [==============================] - 20s 584ms/step - loss: 0.3378 - iou_score: 0.9936 - f1-score: 0.9968 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3595 - val_iou_score: 0.9605 - val_f1-score: 0.9787 - val_precision: 0.9914 - val_auc: 0.9970
# Epoch 100/100
# 35/35 [==============================] - 20s 557ms/step - loss: 0.3378 - iou_score: 0.9936 - f1-score: 0.9968 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3596 - val_iou_score: 0.9606 - val_f1-score: 0.9787 - val_precision: 0.9914 - val_auc: 0.9970

# %%
# Plot training & validation iou_score values
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['f1-score'])
plt.plot(history.history['val_f1-score'])
plt.title('Model f1 Score')
plt.ylabel('f1 Score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.ylabel('Precision')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
n = 5

for i in range(n):
    
    image, gt_mask = valid_dataset[i]
    image = np.expand_dims(image, axis=0)
    pr_mask = model.predict(image).round()
    
    visualize(
        image=denormalize(image.squeeze()),
        gt_mask=gt_mask[..., 1].squeeze(),
        pr_mask=pr_mask[..., 1].squeeze(),
    )

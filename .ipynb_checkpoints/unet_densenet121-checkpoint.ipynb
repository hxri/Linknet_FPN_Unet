# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

import cv2
import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
DATA_DIR = './dataset2/'

# %%
x_train_dir = os.path.join(DATA_DIR, 'train_images')
y_train_dir = os.path.join(DATA_DIR, 'train_annotations')

x_valid_dir = os.path.join(DATA_DIR, 'val_images')
y_valid_dir = os.path.join(DATA_DIR, 'val_annotations')

# %% [markdown]
# ## Dataloader

# %%
# helper function for data visualization
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()
    
# helper function for data visualization    
def denormalize(x):
    """Scale image to range 0..1 for correct plot"""
    x_max = np.percentile(x, 98)
    x_min = np.percentile(x, 2)    
    x = (x - x_min) / (x_max - x_min)
    x = x.clip(0, 1)
    return x
    

# classes for data loading and preprocessing
class Dataset:
    """CamVid Dataset. Read images, apply augmentation and preprocessing transformations.
    
    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing 
            (e.g. noralization, shape manipulation, etc.)
    
    """
    
    CLASSES = ['background', 'blob']
    
    def __init__(
            self, 
            images_dir, 
            masks_dir, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
    ):
        self.ids = os.listdir(images_dir)
        self.images_fps = [os.path.join(images_dir, image_id) for image_id in self.ids]
        self.masks_fps = [os.path.join(masks_dir, image_id) for image_id in self.ids]
        
        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        # read data
        image = cv2.imread(self.images_fps[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.masks_fps[i], 0)
        
        # extract certain classes from mask (e.g. cars)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1).astype('float')
        
        # add background if mask is not binary
        if mask.shape[-1] != 1:
            background = 1 - mask.sum(axis=-1, keepdims=True)
            mask = np.concatenate((mask, background), axis=-1)
        
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
            
        return image, mask
        
    def __len__(self):
        return len(self.ids)
    
    
class Dataloder(keras.utils.Sequence):
    """Load data from dataset and form batches
    
    Args:
        dataset: instance of Dataset class for image loading and preprocessing.
        batch_size: Integet number of images in batch.
        shuffle: Boolean, if `True` shuffle image indexes each epoch.
    """
    
    def __init__(self, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(dataset))

        self.on_epoch_end()

    def __getitem__(self, i):
        
        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        data = []
        for j in range(start, stop):
            data.append(self.dataset[j])
        
        # transpose list of lists
        batch = [np.stack(samples, axis=0) for samples in zip(*data)]
        
        return (batch[0],batch[1])
    
    def __len__(self):
        """Denotes the number of batches per epoch"""
        return len(self.indexes) // self.batch_size
    
    def on_epoch_end(self):
        """Callback function to shuffle indexes each epoch"""
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

# %%
# Lets look at data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['background', 'blob'])

image, mask = dataset[5] # get some sample
visualize(
    image=image, 
    background=mask[..., 0].squeeze(),
    blob=mask[..., 1].squeeze(),
)

# %% [markdown]
# ## Augmentation

# %%
import albumentations as A

# %%
def round_clip_0_1(x, **kwargs):
    return x.round().clip(0, 1)

# define heavy augmentations
def get_training_augmentation():
    train_transform = [

        A.Resize (320, 480, interpolation=1, always_apply=True, p=1),
    ]
    return A.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        A.PadIfNeeded(384, 480, always_apply=True)
    ]
    return A.Compose(test_transform)

def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        A.Lambda(image=preprocessing_fn),
    ]
    return A.Compose(_transform)

# %%
# Lets look at augmented data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['background', 'blob'], augmentation=get_training_augmentation())

image, mask = dataset[12] # get some sample
visualize(
    image=image, 
    background=mask[..., 0].squeeze(),
    blob=mask[..., 1].squeeze(),
)

# %% [markdown]
# ## Model

# %%
# %env SM_FRAMEWORK=tf.keras

import segmentation_models as sm
# Out:
# env: SM_FRAMEWORK=tf.keras
# Segmentation Models: using `tf.keras` framework.

# %%
BACKBONE = 'densenet121'
BATCH_SIZE = 2
CLASSES = ['background', 'blob']
LR = 0.0001
EPOCHS = 5

preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
# define network parameters
n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
activation = 'sigmoid' if n_classes == 1 else 'softmax'

#create model
model = sm.Unet(BACKBONE, classes=n_classes, activation=activation)

# %%
# define optomizer
optim = keras.optimizers.Adam(LR)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
dice_loss = sm.losses.DiceLoss()
focal_loss = sm.losses.BinaryFocalLoss() if n_classes == 1 else sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
# total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss 

metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]

# compile keras model with defined optimozer, loss and metrics
model.compile(optim, total_loss, metrics)

# %%
# Dataset for train images
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

# Dataset for validation images
valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

train_dataloader = Dataloder(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_dataloader = Dataloder(valid_dataset, batch_size=1, shuffle=False)

# check shapes for errors
assert train_dataloader[0][0].shape == (BATCH_SIZE, 320, 480, 3)
assert train_dataloader[0][1].shape == (BATCH_SIZE, 320, 480, n_classes)

# define callbacks for learning rate scheduling and best checkpoints saving
callbacks = [
    keras.callbacks.ModelCheckpoint('./best_model.h5', save_weights_only=True, save_best_only=True, mode='min'),
    keras.callbacks.ReduceLROnPlateau(),
]

# %%
print(valid_dataloader[0][0].shape)
# Out:
# (1, 320, 480, 3)

# %%
# train model
history = model.fit(
    train_dataloader, 
    steps_per_epoch=len(train_dataloader), 
    epochs=100, 
    callbacks=callbacks,
    validation_data=valid_dataloader, 
    validation_steps=len(valid_dataloader),
)
# Out:
# Epoch 1/100
# 35/35 [==============================] - 24s 680ms/step - loss: 0.7533 - iou_score: 0.2204 - f1-score: 0.3122 - val_loss: 0.7068 - val_iou_score: 0.3779 - val_f1-score: 0.4623
# Epoch 2/100
# 35/35 [==============================] - 21s 608ms/step - loss: 0.6408 - iou_score: 0.4780 - f1-score: 0.5519 - val_loss: 0.6311 - val_iou_score: 0.4932 - val_f1-score: 0.5642
# Epoch 3/100
# 35/35 [==============================] - 22s 637ms/step - loss: 0.5807 - iou_score: 0.5690 - f1-score: 0.6122 - val_loss: 0.6211 - val_iou_score: 0.5242 - val_f1-score: 0.5857
# Epoch 4/100
# 35/35 [==============================] - 21s 614ms/step - loss: 0.5393 - iou_score: 0.6026 - f1-score: 0.6321 - val_loss: 0.5634 - val_iou_score: 0.5968 - val_f1-score: 0.6283
# Epoch 5/100
# 35/35 [==============================] - 21s 599ms/step - loss: 0.5056 - iou_score: 0.6167 - f1-score: 0.6398 - val_loss: 0.5422 - val_iou_score: 0.6140 - val_f1-score: 0.6421
# Epoch 6/100
# 35/35 [==============================] - 21s 586ms/step - loss: 0.4748 - iou_score: 0.6268 - f1-score: 0.6453 - val_loss: 0.5161 - val_iou_score: 0.6447 - val_f1-score: 0.6694
# Epoch 7/100
# 35/35 [==============================] - 21s 600ms/step - loss: 0.4479 - iou_score: 0.6427 - f1-score: 0.6585 - val_loss: 0.4990 - val_iou_score: 0.6607 - val_f1-score: 0.6833
# Epoch 8/100
# 35/35 [==============================] - 21s 608ms/step - loss: 0.4270 - iou_score: 0.6569 - f1-score: 0.6706 - val_loss: 0.4734 - val_iou_score: 0.6486 - val_f1-score: 0.6673
# Epoch 9/100
# 35/35 [==============================] - 20s 579ms/step - loss: 0.4103 - iou_score: 0.6978 - f1-score: 0.7103 - val_loss: 0.4652 - val_iou_score: 0.7722 - val_f1-score: 0.7943
# Epoch 10/100
# 35/35 [==============================] - 21s 611ms/step - loss: 0.3967 - iou_score: 0.7104 - f1-score: 0.7214 - val_loss: 0.4390 - val_iou_score: 0.7814 - val_f1-score: 0.8001
# Epoch 11/100
# 35/35 [==============================] - 21s 598ms/step - loss: 0.3875 - iou_score: 0.7781 - f1-score: 0.7887 - val_loss: 0.4271 - val_iou_score: 0.8138 - val_f1-score: 0.8329
# Epoch 12/100
# 35/35 [==============================] - 21s 589ms/step - loss: 0.3799 - iou_score: 0.8080 - f1-score: 0.8179 - val_loss: 0.4137 - val_iou_score: 0.7841 - val_f1-score: 0.8017
# Epoch 13/100
# 35/35 [==============================] - 21s 602ms/step - loss: 0.3741 - iou_score: 0.8852 - f1-score: 0.8947 - val_loss: 0.4045 - val_iou_score: 0.8144 - val_f1-score: 0.8332
# Epoch 14/100
# 35/35 [==============================] - 20s 576ms/step - loss: 0.3689 - iou_score: 0.9060 - f1-score: 0.9147 - val_loss: 0.4008 - val_iou_score: 0.9201 - val_f1-score: 0.9411
# Epoch 15/100
# 35/35 [==============================] - 20s 569ms/step - loss: 0.3651 - iou_score: 0.9352 - f1-score: 0.9436 - val_loss: 0.3948 - val_iou_score: 0.9303 - val_f1-score: 0.9516
# Epoch 16/100
# 35/35 [==============================] - 20s 571ms/step - loss: 0.3612 - iou_score: 0.9850 - f1-score: 0.9923 - val_loss: 0.3845 - val_iou_score: 0.9508 - val_f1-score: 0.9683
# Epoch 17/100
# 35/35 [==============================] - 20s 569ms/step - loss: 0.3586 - iou_score: 0.9857 - f1-score: 0.9927 - val_loss: 0.3833 - val_iou_score: 0.9466 - val_f1-score: 0.9658
# Epoch 18/100
# 35/35 [==============================] - 20s 584ms/step - loss: 0.3563 - iou_score: 0.9866 - f1-score: 0.9932 - val_loss: 0.3768 - val_iou_score: 0.9621 - val_f1-score: 0.9796
# Epoch 19/100
# 35/35 [==============================] - 21s 609ms/step - loss: 0.3544 - iou_score: 0.9871 - f1-score: 0.9934 - val_loss: 0.3767 - val_iou_score: 0.9600 - val_f1-score: 0.9784
# Epoch 20/100
# 35/35 [==============================] - 21s 595ms/step - loss: 0.3526 - iou_score: 0.9785 - f1-score: 0.9844 - val_loss: 0.3747 - val_iou_score: 0.9478 - val_f1-score: 0.9666
# Epoch 21/100
# 35/35 [==============================] - 21s 594ms/step - loss: 0.3511 - iou_score: 0.9886 - f1-score: 0.9942 - val_loss: 0.3732 - val_iou_score: 0.9593 - val_f1-score: 0.9779
# Epoch 22/100
# 35/35 [==============================] - 21s 591ms/step - loss: 0.3502 - iou_score: 0.9789 - f1-score: 0.9846 - val_loss: 0.3729 - val_iou_score: 0.9470 - val_f1-score: 0.9662
# Epoch 23/100
# 35/35 [==============================] - 20s 571ms/step - loss: 0.3498 - iou_score: 0.9876 - f1-score: 0.9937 - val_loss: 0.3692 - val_iou_score: 0.9618 - val_f1-score: 0.9794
# Epoch 24/100
# 35/35 [==============================] - 18s 507ms/step - loss: 0.3485 - iou_score: 0.9793 - f1-score: 0.9848 - val_loss: 0.3693 - val_iou_score: 0.9597 - val_f1-score: 0.9782
# Epoch 25/100
# 35/35 [==============================] - 20s 569ms/step - loss: 0.3474 - iou_score: 0.9894 - f1-score: 0.9946 - val_loss: 0.3689 - val_iou_score: 0.9597 - val_f1-score: 0.9782
# Epoch 26/100
# 35/35 [==============================] - 21s 606ms/step - loss: 0.3466 - iou_score: 0.9899 - f1-score: 0.9949 - val_loss: 0.3666 - val_iou_score: 0.9613 - val_f1-score: 0.9791
# Epoch 27/100
# 35/35 [==============================] - 21s 587ms/step - loss: 0.3459 - iou_score: 0.9902 - f1-score: 0.9950 - val_loss: 0.3666 - val_iou_score: 0.9608 - val_f1-score: 0.9788
# Epoch 28/100
# 35/35 [==============================] - 21s 599ms/step - loss: 0.3453 - iou_score: 0.9905 - f1-score: 0.9952 - val_loss: 0.3662 - val_iou_score: 0.9601 - val_f1-score: 0.9784
# Epoch 29/100
# 35/35 [==============================] - 21s 594ms/step - loss: 0.3449 - iou_score: 0.9904 - f1-score: 0.9952 - val_loss: 0.3661 - val_iou_score: 0.9599 - val_f1-score: 0.9783
# Epoch 30/100
# 35/35 [==============================] - 21s 608ms/step - loss: 0.3444 - iou_score: 0.9907 - f1-score: 0.9953 - val_loss: 0.3650 - val_iou_score: 0.9611 - val_f1-score: 0.9790
# Epoch 31/100
# 35/35 [==============================] - 18s 507ms/step - loss: 0.3440 - iou_score: 0.9908 - f1-score: 0.9953 - val_loss: 0.3669 - val_iou_score: 0.9579 - val_f1-score: 0.9772
# Epoch 32/100
# 35/35 [==============================] - 20s 572ms/step - loss: 0.3441 - iou_score: 0.9899 - f1-score: 0.9949 - val_loss: 0.3643 - val_iou_score: 0.9607 - val_f1-score: 0.9787
# Epoch 33/100
# 35/35 [==============================] - 21s 604ms/step - loss: 0.3437 - iou_score: 0.9901 - f1-score: 0.9950 - val_loss: 0.3628 - val_iou_score: 0.9626 - val_f1-score: 0.9798
# Epoch 34/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3432 - iou_score: 0.9906 - f1-score: 0.9952 - val_loss: 0.3633 - val_iou_score: 0.9613 - val_f1-score: 0.9791
# Epoch 35/100
# 35/35 [==============================] - 18s 516ms/step - loss: 0.3426 - iou_score: 0.9913 - f1-score: 0.9956 - val_loss: 0.3636 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 36/100
# 35/35 [==============================] - 18s 516ms/step - loss: 0.3421 - iou_score: 0.9920 - f1-score: 0.9959 - val_loss: 0.3630 - val_iou_score: 0.9609 - val_f1-score: 0.9789
# Epoch 37/100
# 35/35 [==============================] - 21s 599ms/step - loss: 0.3416 - iou_score: 0.9924 - f1-score: 0.9962 - val_loss: 0.3628 - val_iou_score: 0.9613 - val_f1-score: 0.9790
# Epoch 38/100
# 35/35 [==============================] - 18s 508ms/step - loss: 0.3412 - iou_score: 0.9930 - f1-score: 0.9965 - val_loss: 0.3635 - val_iou_score: 0.9601 - val_f1-score: 0.9784
# Epoch 39/100
# 35/35 [==============================] - 20s 570ms/step - loss: 0.3410 - iou_score: 0.9927 - f1-score: 0.9963 - val_loss: 0.3619 - val_iou_score: 0.9619 - val_f1-score: 0.9795
# Epoch 40/100
# 35/35 [==============================] - 21s 609ms/step - loss: 0.3408 - iou_score: 0.9928 - f1-score: 0.9964 - val_loss: 0.3617 - val_iou_score: 0.9619 - val_f1-score: 0.9795
# Epoch 41/100
# 35/35 [==============================] - 21s 592ms/step - loss: 0.3405 - iou_score: 0.9837 - f1-score: 0.9871 - val_loss: 0.3612 - val_iou_score: 0.9625 - val_f1-score: 0.9798
# Epoch 42/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3404 - iou_score: 0.9932 - f1-score: 0.9966 - val_loss: 0.3621 - val_iou_score: 0.9608 - val_f1-score: 0.9788
# Epoch 43/100
# 35/35 [==============================] - 18s 508ms/step - loss: 0.3404 - iou_score: 0.9834 - f1-score: 0.9869 - val_loss: 0.3617 - val_iou_score: 0.9614 - val_f1-score: 0.9792
# Epoch 44/100
# 35/35 [==============================] - 21s 597ms/step - loss: 0.3402 - iou_score: 0.9835 - f1-score: 0.9869 - val_loss: 0.3611 - val_iou_score: 0.9621 - val_f1-score: 0.9795
# Epoch 45/100
# 35/35 [==============================] - 18s 508ms/step - loss: 0.3400 - iou_score: 0.9931 - f1-score: 0.9965 - val_loss: 0.3620 - val_iou_score: 0.9606 - val_f1-score: 0.9787
# Epoch 46/100
# 35/35 [==============================] - 20s 584ms/step - loss: 0.3399 - iou_score: 0.9930 - f1-score: 0.9965 - val_loss: 0.3610 - val_iou_score: 0.9618 - val_f1-score: 0.9793
# Epoch 47/100
# 35/35 [==============================] - 21s 587ms/step - loss: 0.3396 - iou_score: 0.9935 - f1-score: 0.9967 - val_loss: 0.3607 - val_iou_score: 0.9620 - val_f1-score: 0.9795
# Epoch 48/100
# 35/35 [==============================] - 18s 515ms/step - loss: 0.3395 - iou_score: 0.9934 - f1-score: 0.9967 - val_loss: 0.3609 - val_iou_score: 0.9616 - val_f1-score: 0.9793
# Epoch 49/100
# 35/35 [==============================] - 21s 605ms/step - loss: 0.3395 - iou_score: 0.9933 - f1-score: 0.9966 - val_loss: 0.3605 - val_iou_score: 0.9622 - val_f1-score: 0.9796
# Epoch 50/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3395 - iou_score: 0.9836 - f1-score: 0.9870 - val_loss: 0.3620 - val_iou_score: 0.9602 - val_f1-score: 0.9784
# Epoch 51/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3392 - iou_score: 0.9935 - f1-score: 0.9967 - val_loss: 0.3609 - val_iou_score: 0.9617 - val_f1-score: 0.9792
# Epoch 52/100
# 35/35 [==============================] - 18s 508ms/step - loss: 0.3388 - iou_score: 0.9941 - f1-score: 0.9970 - val_loss: 0.3610 - val_iou_score: 0.9613 - val_f1-score: 0.9790
# Epoch 53/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3385 - iou_score: 0.9947 - f1-score: 0.9973 - val_loss: 0.3611 - val_iou_score: 0.9613 - val_f1-score: 0.9791
# Epoch 54/100
# 35/35 [==============================] - 18s 508ms/step - loss: 0.3384 - iou_score: 0.9946 - f1-score: 0.9973 - val_loss: 0.3609 - val_iou_score: 0.9617 - val_f1-score: 0.9793
# Epoch 55/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3382 - iou_score: 0.9948 - f1-score: 0.9974 - val_loss: 0.3615 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 56/100
# 35/35 [==============================] - 22s 619ms/step - loss: 0.3381 - iou_score: 0.9949 - f1-score: 0.9974 - val_loss: 0.3599 - val_iou_score: 0.9627 - val_f1-score: 0.9799
# Epoch 57/100
# 35/35 [==============================] - 18s 519ms/step - loss: 0.3381 - iou_score: 0.9948 - f1-score: 0.9974 - val_loss: 0.3606 - val_iou_score: 0.9617 - val_f1-score: 0.9793
# Epoch 58/100
# 35/35 [==============================] - 18s 515ms/step - loss: 0.3381 - iou_score: 0.9948 - f1-score: 0.9974 - val_loss: 0.3603 - val_iou_score: 0.9621 - val_f1-score: 0.9796
# Epoch 59/100
# 35/35 [==============================] - 18s 513ms/step - loss: 0.3380 - iou_score: 0.9947 - f1-score: 0.9973 - val_loss: 0.3602 - val_iou_score: 0.9621 - val_f1-score: 0.9795
# Epoch 60/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3383 - iou_score: 0.9941 - f1-score: 0.9970 - val_loss: 0.3615 - val_iou_score: 0.9604 - val_f1-score: 0.9784
# Epoch 61/100
# 35/35 [==============================] - 21s 610ms/step - loss: 0.3381 - iou_score: 0.9944 - f1-score: 0.9972 - val_loss: 0.3598 - val_iou_score: 0.9626 - val_f1-score: 0.9799
# Epoch 62/100
# 35/35 [==============================] - 18s 520ms/step - loss: 0.3382 - iou_score: 0.9940 - f1-score: 0.9970 - val_loss: 0.3605 - val_iou_score: 0.9617 - val_f1-score: 0.9794
# Epoch 63/100
# 35/35 [==============================] - 18s 524ms/step - loss: 0.3384 - iou_score: 0.9936 - f1-score: 0.9968 - val_loss: 0.3603 - val_iou_score: 0.9619 - val_f1-score: 0.9794
# Epoch 64/100
# 35/35 [==============================] - 18s 512ms/step - loss: 0.3379 - iou_score: 0.9945 - f1-score: 0.9972 - val_loss: 0.3607 - val_iou_score: 0.9615 - val_f1-score: 0.9792
# Epoch 65/100
# 35/35 [==============================] - 18s 514ms/step - loss: 0.3374 - iou_score: 0.9953 - f1-score: 0.9976 - val_loss: 0.3607 - val_iou_score: 0.9614 - val_f1-score: 0.9792
# Epoch 66/100
# 35/35 [==============================] - 18s 511ms/step - loss: 0.3372 - iou_score: 0.9957 - f1-score: 0.9979 - val_loss: 0.3603 - val_iou_score: 0.9619 - val_f1-score: 0.9795
# Epoch 67/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3372 - iou_score: 0.9956 - f1-score: 0.9978 - val_loss: 0.3601 - val_iou_score: 0.9622 - val_f1-score: 0.9796
# Epoch 68/100
# 35/35 [==============================] - 21s 595ms/step - loss: 0.3371 - iou_score: 0.9956 - f1-score: 0.9978 - val_loss: 0.3591 - val_iou_score: 0.9637 - val_f1-score: 0.9805
# Epoch 69/100
# 35/35 [==============================] - 18s 514ms/step - loss: 0.3370 - iou_score: 0.9959 - f1-score: 0.9980 - val_loss: 0.3610 - val_iou_score: 0.9609 - val_f1-score: 0.9788
# Epoch 70/100
# 35/35 [==============================] - 18s 522ms/step - loss: 0.3370 - iou_score: 0.9958 - f1-score: 0.9979 - val_loss: 0.3607 - val_iou_score: 0.9614 - val_f1-score: 0.9791
# Epoch 71/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3370 - iou_score: 0.9957 - f1-score: 0.9978 - val_loss: 0.3606 - val_iou_score: 0.9614 - val_f1-score: 0.9791
# Epoch 72/100
# 35/35 [==============================] - 18s 513ms/step - loss: 0.3371 - iou_score: 0.9954 - f1-score: 0.9977 - val_loss: 0.3608 - val_iou_score: 0.9612 - val_f1-score: 0.9790
# Epoch 73/100
# 35/35 [==============================] - 18s 515ms/step - loss: 0.3372 - iou_score: 0.9950 - f1-score: 0.9975 - val_loss: 0.3605 - val_iou_score: 0.9617 - val_f1-score: 0.9793
# Epoch 74/100
# 35/35 [==============================] - 18s 512ms/step - loss: 0.3368 - iou_score: 0.9959 - f1-score: 0.9980 - val_loss: 0.3603 - val_iou_score: 0.9620 - val_f1-score: 0.9795
# Epoch 75/100
# 35/35 [==============================] - 18s 511ms/step - loss: 0.3367 - iou_score: 0.9960 - f1-score: 0.9980 - val_loss: 0.3601 - val_iou_score: 0.9621 - val_f1-score: 0.9795
# Epoch 76/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3366 - iou_score: 0.9962 - f1-score: 0.9981 - val_loss: 0.3609 - val_iou_score: 0.9612 - val_f1-score: 0.9791
# Epoch 77/100
# 35/35 [==============================] - 18s 525ms/step - loss: 0.3364 - iou_score: 0.9964 - f1-score: 0.9982 - val_loss: 0.3602 - val_iou_score: 0.9620 - val_f1-score: 0.9795
# Epoch 78/100
# 35/35 [==============================] - 18s 515ms/step - loss: 0.3365 - iou_score: 0.9963 - f1-score: 0.9982 - val_loss: 0.3605 - val_iou_score: 0.9617 - val_f1-score: 0.9793
# Epoch 79/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3362 - iou_score: 0.9968 - f1-score: 0.9984 - val_loss: 0.3605 - val_iou_score: 0.9618 - val_f1-score: 0.9793
# Epoch 80/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3359 - iou_score: 0.9974 - f1-score: 0.9987 - val_loss: 0.3604 - val_iou_score: 0.9618 - val_f1-score: 0.9793
# Epoch 81/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3358 - iou_score: 0.9977 - f1-score: 0.9989 - val_loss: 0.3604 - val_iou_score: 0.9619 - val_f1-score: 0.9794
# Epoch 82/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3357 - iou_score: 0.9980 - f1-score: 0.9990 - val_loss: 0.3604 - val_iou_score: 0.9619 - val_f1-score: 0.9794
# Epoch 83/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3356 - iou_score: 0.9982 - f1-score: 0.9991 - val_loss: 0.3604 - val_iou_score: 0.9620 - val_f1-score: 0.9794
# Epoch 84/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3355 - iou_score: 0.9983 - f1-score: 0.9992 - val_loss: 0.3604 - val_iou_score: 0.9620 - val_f1-score: 0.9794
# Epoch 85/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3355 - iou_score: 0.9984 - f1-score: 0.9992 - val_loss: 0.3604 - val_iou_score: 0.9620 - val_f1-score: 0.9795
# Epoch 86/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3355 - iou_score: 0.9985 - f1-score: 0.9993 - val_loss: 0.3604 - val_iou_score: 0.9620 - val_f1-score: 0.9795
# Epoch 87/100
# 35/35 [==============================] - 18s 516ms/step - loss: 0.3354 - iou_score: 0.9986 - f1-score: 0.9993 - val_loss: 0.3604 - val_iou_score: 0.9620 - val_f1-score: 0.9794
# Epoch 88/100
# 35/35 [==============================] - 18s 514ms/step - loss: 0.3354 - iou_score: 0.9987 - f1-score: 0.9993 - val_loss: 0.3604 - val_iou_score: 0.9620 - val_f1-score: 0.9795
# Epoch 89/100
# 35/35 [==============================] - 18s 516ms/step - loss: 0.3354 - iou_score: 0.9987 - f1-score: 0.9993 - val_loss: 0.3604 - val_iou_score: 0.9620 - val_f1-score: 0.9794
# Epoch 90/100
# 35/35 [==============================] - 18s 511ms/step - loss: 0.3354 - iou_score: 0.9987 - f1-score: 0.9993 - val_loss: 0.3605 - val_iou_score: 0.9619 - val_f1-score: 0.9794
# Epoch 91/100
# 35/35 [==============================] - 18s 514ms/step - loss: 0.3354 - iou_score: 0.9987 - f1-score: 0.9993 - val_loss: 0.3605 - val_iou_score: 0.9620 - val_f1-score: 0.9794
# Epoch 92/100
# 35/35 [==============================] - 18s 516ms/step - loss: 0.3354 - iou_score: 0.9987 - f1-score: 0.9994 - val_loss: 0.3605 - val_iou_score: 0.9619 - val_f1-score: 0.9794
# Epoch 93/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3354 - iou_score: 0.9987 - f1-score: 0.9994 - val_loss: 0.3605 - val_iou_score: 0.9620 - val_f1-score: 0.9795
# Epoch 94/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3354 - iou_score: 0.9987 - f1-score: 0.9994 - val_loss: 0.3605 - val_iou_score: 0.9619 - val_f1-score: 0.9794
# Epoch 95/100
# 35/35 [==============================] - 18s 511ms/step - loss: 0.3354 - iou_score: 0.9987 - f1-score: 0.9994 - val_loss: 0.3605 - val_iou_score: 0.9619 - val_f1-score: 0.9794
# Epoch 96/100
# 35/35 [==============================] - 18s 521ms/step - loss: 0.3354 - iou_score: 0.9987 - f1-score: 0.9994 - val_loss: 0.3605 - val_iou_score: 0.9619 - val_f1-score: 0.9794
# Epoch 97/100
# 35/35 [==============================] - 18s 514ms/step - loss: 0.3354 - iou_score: 0.9987 - f1-score: 0.9994 - val_loss: 0.3605 - val_iou_score: 0.9619 - val_f1-score: 0.9794
# Epoch 98/100
# 35/35 [==============================] - 18s 518ms/step - loss: 0.3354 - iou_score: 0.9987 - f1-score: 0.9994 - val_loss: 0.3605 - val_iou_score: 0.9620 - val_f1-score: 0.9794
# Epoch 99/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3354 - iou_score: 0.9987 - f1-score: 0.9994 - val_loss: 0.3605 - val_iou_score: 0.9620 - val_f1-score: 0.9795
# Epoch 100/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3354 - iou_score: 0.9987 - f1-score: 0.9994 - val_loss: 0.3604 - val_iou_score: 0.9620 - val_f1-score: 0.9795

# %%
# Plot training & validation iou_score values
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['f1-score'])
plt.plot(history.history['val_f1-score'])
plt.title('Model f1 Score')
plt.ylabel('f1 Score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
n = 5

for i in range(n):
    
    image, gt_mask = valid_dataset[i]
    image = np.expand_dims(image, axis=0)
    pr_mask = model.predict(image).round()
    
    visualize(
        image=denormalize(image.squeeze()),
        gt_mask=gt_mask[..., 1].squeeze(),
        pr_mask=pr_mask[..., 1].squeeze(),
    )

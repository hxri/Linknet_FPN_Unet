# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import tensorflow as tf
import cv2
import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
DATA_DIR = './dataset2/'

# %%
x_train_dir = os.path.join(DATA_DIR, 'train_images')
y_train_dir = os.path.join(DATA_DIR, 'train_annotations')

x_valid_dir = os.path.join(DATA_DIR, 'val_images')
y_valid_dir = os.path.join(DATA_DIR, 'val_annotations')

# %% [markdown]
# ## Dataloader

# %%
# helper function for data visualization
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()
    
# helper function for data visualization    
def denormalize(x):
    """Scale image to range 0..1 for correct plot"""
    x_max = np.percentile(x, 98)
    x_min = np.percentile(x, 2)    
    x = (x - x_min) / (x_max - x_min)
    x = x.clip(0, 1)
    return x
    

# classes for data loading and preprocessing
class Dataset:
    """CamVid Dataset. Read images, apply augmentation and preprocessing transformations.
    
    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing 
            (e.g. noralization, shape manipulation, etc.)
    
    """
    
    CLASSES = ['background', 'blob']
    
    def __init__(
            self, 
            images_dir, 
            masks_dir, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
    ):
        self.ids = os.listdir(images_dir)
        self.images_fps = [os.path.join(images_dir, image_id) for image_id in self.ids]
        self.masks_fps = [os.path.join(masks_dir, image_id) for image_id in self.ids]
        
        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        # read data
        image = cv2.imread(self.images_fps[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.masks_fps[i], 0)
        
        # extract certain classes from mask (e.g. cars)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1).astype('float')
        
        # add background if mask is not binary
        if mask.shape[-1] != 1:
            background = 1 - mask.sum(axis=-1, keepdims=True)
            mask = np.concatenate((mask, background), axis=-1)
        
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
            
        return image, mask
        
    def __len__(self):
        return len(self.ids)
    
    
class Dataloder(keras.utils.Sequence):
    """Load data from dataset and form batches
    
    Args:
        dataset: instance of Dataset class for image loading and preprocessing.
        batch_size: Integet number of images in batch.
        shuffle: Boolean, if `True` shuffle image indexes each epoch.
    """
    
    def __init__(self, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(dataset))

        self.on_epoch_end()

    def __getitem__(self, i):
        
        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        data = []
        for j in range(start, stop):
            data.append(self.dataset[j])
        
        # transpose list of lists
        batch = [np.stack(samples, axis=0) for samples in zip(*data)]
        
        return (batch[0],batch[1])
    
    def __len__(self):
        """Denotes the number of batches per epoch"""
        return len(self.indexes) // self.batch_size
    
    def on_epoch_end(self):
        """Callback function to shuffle indexes each epoch"""
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

# %%
# Lets look at data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['background', 'blob'])

image, mask = dataset[5] # get some sample
visualize(
    image=image, 
    background=mask[..., 0].squeeze(),
    blob=mask[..., 1].squeeze(),
)

# %% [markdown]
# ## Augmentation

# %%
import albumentations as A

# %%
def round_clip_0_1(x, **kwargs):
    return x.round().clip(0, 1)

# define heavy augmentations
def get_training_augmentation():
    train_transform = [

        A.Resize (320, 480, interpolation=1, always_apply=True, p=1),
    ]
    return A.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        A.PadIfNeeded(384, 480, always_apply=True)
    ]
    return A.Compose(test_transform)

def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        A.Lambda(image=preprocessing_fn),
    ]
    return A.Compose(_transform)

# %%
# Lets look at augmented data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['background', 'blob'], augmentation=get_training_augmentation())

image, mask = dataset[12] # get some sample
visualize(
    image=image, 
    background=mask[..., 0].squeeze(),
    blob=mask[..., 1].squeeze(),
)

# %% [markdown]
# ## Model

# %%
# %env SM_FRAMEWORK=tf.keras

import segmentation_models as sm
# Out:
# env: SM_FRAMEWORK=tf.keras
# Segmentation Models: using `tf.keras` framework.

# %%
BACKBONE = 'vgg16'
BATCH_SIZE = 2
CLASSES = ['background', 'blob']
LR = 0.0001
EPOCHS = 5

preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
# define network parameters
n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
activation = 'sigmoid' if n_classes == 1 else 'softmax'

def build_model_func():
    #create model
    model = sm.Linknet(BACKBONE, classes=n_classes, activation=activation)

    # define optomizer
    optim = keras.optimizers.Adam(LR)

    # Segmentation models losses can be combined together by '+' and scaled by integer or float factor
    dice_loss = sm.losses.DiceLoss()
    focal_loss = sm.losses.BinaryFocalLoss() if n_classes == 1 else sm.losses.CategoricalFocalLoss()
    total_loss = dice_loss + (1 * focal_loss)

    # actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
    # total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss 

    metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5), tf.keras.metrics.Precision(), tf.keras.metrics.AUC()]

    # compile keras model with defined optimozer, loss and metrics
    model.compile(optim, total_loss, metrics)
    return model

# %%
# Dataset for train images
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

# Dataset for validation images
valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

train_dataloader = Dataloder(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_dataloader = Dataloder(valid_dataset, batch_size=1, shuffle=False)

# check shapes for errors
assert train_dataloader[0][0].shape == (BATCH_SIZE, 320, 480, 3)
assert train_dataloader[0][1].shape == (BATCH_SIZE, 320, 480, n_classes)



# define callbacks for learning rate scheduling and best checkpoints saving
filepath = "checkpoints/saved_weights.{epoch:02d}.hdf5"
callbacks = [
    keras.callbacks.ModelCheckpoint(
            filepath, 
            save_weights_only=True, 
            save_best_only=False, 
            mode="min",
            verbose=0,
            save_freq='epoch',
        ),
    keras.callbacks.ReduceLROnPlateau(),
]

# %%
print(valid_dataloader[0][0].shape)
# Out:
# (1, 320, 480, 3)

# %%
#checkpoint_path = "checkpoints/saved_weights.12.hdf5"
checkpoint_path = None
from tensorflow.keras.models import model_from_json

def get_init_epoch(checkpoint_path):
    return int(checkpoint_path.split('.')[1])

# Load checkpoint:
if checkpoint_path is not None:
    # Load model:
    model = build_model_func()
    model.load_weights(checkpoint_path)
    # Finding the epoch index from which we are resuming
    initial_epoch = get_init_epoch(checkpoint_path)
    # Calculating the correct value of count
    count = initial_epoch*BATCH_SIZE
    # Update the value of count in callback instance
    callbacks[1].count = count
else:
    model = build_model_func()
    initial_epoch = 0

# train model
history = model.fit(
    train_dataloader, 
    steps_per_epoch=len(train_dataloader), 
    epochs=100, 
    callbacks=callbacks,
    initial_epoch=initial_epoch,
    validation_data=valid_dataloader, 
    validation_steps=len(valid_dataloader),
)
# Out:
# Epoch 1/100
# 35/35 [==============================] - 19s 552ms/step - loss: 0.7636 - iou_score: 0.1753 - f1-score: 0.2534 - precision: 0.7061 - auc: 0.7994 - val_loss: 0.7069 - val_iou_score: 0.3539 - val_f1-score: 0.4575 - val_precision: 0.8819 - val_auc: 0.9147
# Epoch 2/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.6608 - iou_score: 0.4234 - f1-score: 0.5142 - precision: 0.9212 - auc: 0.9402 - val_loss: 0.6577 - val_iou_score: 0.4819 - val_f1-score: 0.5527 - val_precision: 0.9609 - val_auc: 0.9713
# Epoch 3/100
# 35/35 [==============================] - 18s 526ms/step - loss: 0.6043 - iou_score: 0.5009 - f1-score: 0.5671 - precision: 0.9581 - auc: 0.9754 - val_loss: 0.6266 - val_iou_score: 0.5132 - val_f1-score: 0.5752 - val_precision: 0.9776 - val_auc: 0.9867
# Epoch 4/100
# 35/35 [==============================] - 18s 526ms/step - loss: 0.5563 - iou_score: 0.5476 - f1-score: 0.5958 - precision: 0.9716 - auc: 0.9871 - val_loss: 0.5784 - val_iou_score: 0.5329 - val_f1-score: 0.5871 - val_precision: 0.9807 - val_auc: 0.9916
# Epoch 5/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.5197 - iou_score: 0.5642 - f1-score: 0.6056 - precision: 0.9767 - auc: 0.9909 - val_loss: 0.5694 - val_iou_score: 0.5695 - val_f1-score: 0.6119 - val_precision: 0.9840 - val_auc: 0.9925
# Epoch 6/100
# 35/35 [==============================] - 18s 526ms/step - loss: 0.4872 - iou_score: 0.5796 - f1-score: 0.6159 - precision: 0.9818 - auc: 0.9938 - val_loss: 0.5348 - val_iou_score: 0.5642 - val_f1-score: 0.6069 - val_precision: 0.9846 - val_auc: 0.9954
# Epoch 7/100
# 35/35 [==============================] - 19s 542ms/step - loss: 0.4658 - iou_score: 0.5833 - f1-score: 0.6181 - precision: 0.9831 - auc: 0.9942 - val_loss: 0.5104 - val_iou_score: 0.5828 - val_f1-score: 0.6190 - val_precision: 0.9870 - val_auc: 0.9957
# Epoch 8/100
# 35/35 [==============================] - 18s 526ms/step - loss: 0.4472 - iou_score: 0.6100 - f1-score: 0.6424 - precision: 0.9850 - auc: 0.9954 - val_loss: 0.4869 - val_iou_score: 0.6366 - val_f1-score: 0.6730 - val_precision: 0.9853 - val_auc: 0.9949
# Epoch 9/100
# 35/35 [==============================] - 18s 528ms/step - loss: 0.4342 - iou_score: 0.7270 - f1-score: 0.7579 - precision: 0.9852 - auc: 0.9956 - val_loss: 0.4559 - val_iou_score: 0.6858 - val_f1-score: 0.7160 - val_precision: 0.9873 - val_auc: 0.9970
# Epoch 10/100
# 35/35 [==============================] - 18s 526ms/step - loss: 0.4239 - iou_score: 0.7395 - f1-score: 0.7700 - precision: 0.9860 - auc: 0.9962 - val_loss: 0.4373 - val_iou_score: 0.9209 - val_f1-score: 0.9505 - val_precision: 0.9870 - val_auc: 0.9965
# Epoch 11/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.4147 - iou_score: 0.8561 - f1-score: 0.8856 - precision: 0.9862 - auc: 0.9966 - val_loss: 0.4237 - val_iou_score: 0.9377 - val_f1-score: 0.9654 - val_precision: 0.9881 - val_auc: 0.9971
# Epoch 12/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.4077 - iou_score: 0.8797 - f1-score: 0.9073 - precision: 0.9869 - auc: 0.9965 - val_loss: 0.4204 - val_iou_score: 0.9354 - val_f1-score: 0.9629 - val_precision: 0.9870 - val_auc: 0.9964
# Epoch 13/100
# 35/35 [==============================] - 19s 541ms/step - loss: 0.4018 - iou_score: 0.8907 - f1-score: 0.9176 - precision: 0.9872 - auc: 0.9969 - val_loss: 0.4129 - val_iou_score: 0.9386 - val_f1-score: 0.9652 - val_precision: 0.9878 - val_auc: 0.9974
# Epoch 14/100
# 35/35 [==============================] - 18s 526ms/step - loss: 0.3956 - iou_score: 0.9032 - f1-score: 0.9290 - precision: 0.9878 - auc: 0.9972 - val_loss: 0.4048 - val_iou_score: 0.9396 - val_f1-score: 0.9660 - val_precision: 0.9878 - val_auc: 0.9974
# Epoch 15/100
# 35/35 [==============================] - 18s 524ms/step - loss: 0.3936 - iou_score: 0.9036 - f1-score: 0.9291 - precision: 0.9878 - auc: 0.9970 - val_loss: 0.4087 - val_iou_score: 0.9255 - val_f1-score: 0.9552 - val_precision: 0.9845 - val_auc: 0.9972
# Epoch 16/100
# 35/35 [==============================] - 18s 528ms/step - loss: 0.3883 - iou_score: 0.9073 - f1-score: 0.9314 - precision: 0.9886 - auc: 0.9974 - val_loss: 0.4018 - val_iou_score: 0.9352 - val_f1-score: 0.9625 - val_precision: 0.9869 - val_auc: 0.9971
# Epoch 17/100
# 35/35 [==============================] - 19s 537ms/step - loss: 0.3861 - iou_score: 0.9278 - f1-score: 0.9517 - precision: 0.9891 - auc: 0.9976 - val_loss: 0.3915 - val_iou_score: 0.9394 - val_f1-score: 0.9655 - val_precision: 0.9872 - val_auc: 0.9970
# Epoch 18/100
# 35/35 [==============================] - 18s 526ms/step - loss: 0.3828 - iou_score: 0.9200 - f1-score: 0.9431 - precision: 0.9893 - auc: 0.9975 - val_loss: 0.3928 - val_iou_score: 0.9387 - val_f1-score: 0.9649 - val_precision: 0.9874 - val_auc: 0.9970
# Epoch 19/100
# 35/35 [==============================] - 19s 529ms/step - loss: 0.3830 - iou_score: 0.9360 - f1-score: 0.9604 - precision: 0.9885 - auc: 0.9976 - val_loss: 0.3879 - val_iou_score: 0.9413 - val_f1-score: 0.9665 - val_precision: 0.9877 - val_auc: 0.9968
# Epoch 20/100
# 35/35 [==============================] - 19s 530ms/step - loss: 0.3789 - iou_score: 0.9401 - f1-score: 0.9627 - precision: 0.9892 - auc: 0.9976 - val_loss: 0.3925 - val_iou_score: 0.9358 - val_f1-score: 0.9628 - val_precision: 0.9866 - val_auc: 0.9969
# Epoch 21/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3770 - iou_score: 0.9418 - f1-score: 0.9637 - precision: 0.9898 - auc: 0.9977 - val_loss: 0.3856 - val_iou_score: 0.9427 - val_f1-score: 0.9677 - val_precision: 0.9880 - val_auc: 0.9968
# Epoch 22/100
# 35/35 [==============================] - 19s 529ms/step - loss: 0.3763 - iou_score: 0.9408 - f1-score: 0.9631 - precision: 0.9895 - auc: 0.9978 - val_loss: 0.3855 - val_iou_score: 0.9436 - val_f1-score: 0.9680 - val_precision: 0.9879 - val_auc: 0.9965
# Epoch 23/100
# 35/35 [==============================] - 18s 528ms/step - loss: 0.3720 - iou_score: 0.9465 - f1-score: 0.9666 - precision: 0.9907 - auc: 0.9979 - val_loss: 0.3933 - val_iou_score: 0.9338 - val_f1-score: 0.9614 - val_precision: 0.9861 - val_auc: 0.9961
# Epoch 24/100
# 35/35 [==============================] - 19s 533ms/step - loss: 0.3732 - iou_score: 0.9431 - f1-score: 0.9646 - precision: 0.9899 - auc: 0.9980 - val_loss: 0.3811 - val_iou_score: 0.9457 - val_f1-score: 0.9696 - val_precision: 0.9884 - val_auc: 0.9965
# Epoch 25/100
# 35/35 [==============================] - 18s 528ms/step - loss: 0.3679 - iou_score: 0.9506 - f1-score: 0.9689 - precision: 0.9916 - auc: 0.9982 - val_loss: 0.4058 - val_iou_score: 0.9149 - val_f1-score: 0.9485 - val_precision: 0.9818 - val_auc: 0.9963
# Epoch 26/100
# 35/35 [==============================] - 19s 542ms/step - loss: 0.3685 - iou_score: 0.9486 - f1-score: 0.9677 - precision: 0.9912 - auc: 0.9981 - val_loss: 0.3748 - val_iou_score: 0.9475 - val_f1-score: 0.9708 - val_precision: 0.9886 - val_auc: 0.9966
# Epoch 27/100
# 35/35 [==============================] - 18s 528ms/step - loss: 0.3667 - iou_score: 0.9507 - f1-score: 0.9690 - precision: 0.9915 - auc: 0.9983 - val_loss: 0.3766 - val_iou_score: 0.9477 - val_f1-score: 0.9706 - val_precision: 0.9889 - val_auc: 0.9971
# Epoch 28/100
# 35/35 [==============================] - 18s 526ms/step - loss: 0.3642 - iou_score: 0.9535 - f1-score: 0.9707 - precision: 0.9921 - auc: 0.9984 - val_loss: 0.3753 - val_iou_score: 0.9466 - val_f1-score: 0.9700 - val_precision: 0.9883 - val_auc: 0.9973
# Epoch 29/100
# 35/35 [==============================] - 19s 529ms/step - loss: 0.3654 - iou_score: 0.9509 - f1-score: 0.9691 - precision: 0.9915 - auc: 0.9984 - val_loss: 0.3992 - val_iou_score: 0.9203 - val_f1-score: 0.9532 - val_precision: 0.9839 - val_auc: 0.9970
# Epoch 30/100
# 35/35 [==============================] - 18s 526ms/step - loss: 0.3672 - iou_score: 0.9573 - f1-score: 0.9769 - precision: 0.9912 - auc: 0.9983 - val_loss: 0.3685 - val_iou_score: 0.9533 - val_f1-score: 0.9743 - val_precision: 0.9898 - val_auc: 0.9966
# Epoch 31/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3645 - iou_score: 0.9514 - f1-score: 0.9693 - precision: 0.9915 - auc: 0.9983 - val_loss: 0.3843 - val_iou_score: 0.9387 - val_f1-score: 0.9649 - val_precision: 0.9872 - val_auc: 0.9968
# Epoch 32/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3601 - iou_score: 0.9667 - f1-score: 0.9822 - precision: 0.9928 - auc: 0.9985 - val_loss: 0.3732 - val_iou_score: 0.9488 - val_f1-score: 0.9714 - val_precision: 0.9886 - val_auc: 0.9971
# Epoch 33/100
# 35/35 [==============================] - 18s 529ms/step - loss: 0.3601 - iou_score: 0.9668 - f1-score: 0.9823 - precision: 0.9926 - auc: 0.9986 - val_loss: 0.3738 - val_iou_score: 0.9441 - val_f1-score: 0.9691 - val_precision: 0.9882 - val_auc: 0.9964
# Epoch 34/100
# 35/35 [==============================] - 19s 543ms/step - loss: 0.3610 - iou_score: 0.9648 - f1-score: 0.9811 - precision: 0.9921 - auc: 0.9985 - val_loss: 0.3704 - val_iou_score: 0.9507 - val_f1-score: 0.9726 - val_precision: 0.9891 - val_auc: 0.9971
# Epoch 35/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3583 - iou_score: 0.9684 - f1-score: 0.9833 - precision: 0.9932 - auc: 0.9986 - val_loss: 0.3766 - val_iou_score: 0.9458 - val_f1-score: 0.9696 - val_precision: 0.9887 - val_auc: 0.9977
# Epoch 36/100
# 35/35 [==============================] - 18s 526ms/step - loss: 0.3560 - iou_score: 0.9716 - f1-score: 0.9852 - precision: 0.9939 - auc: 0.9988 - val_loss: 0.3757 - val_iou_score: 0.9464 - val_f1-score: 0.9700 - val_precision: 0.9886 - val_auc: 0.9968
# Epoch 37/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3549 - iou_score: 0.9726 - f1-score: 0.9857 - precision: 0.9939 - auc: 0.9989 - val_loss: 0.3890 - val_iou_score: 0.9297 - val_f1-score: 0.9591 - val_precision: 0.9853 - val_auc: 0.9975
# Epoch 38/100
# 35/35 [==============================] - 18s 526ms/step - loss: 0.3585 - iou_score: 0.9671 - f1-score: 0.9823 - precision: 0.9932 - auc: 0.9986 - val_loss: 0.3814 - val_iou_score: 0.9429 - val_f1-score: 0.9674 - val_precision: 0.9875 - val_auc: 0.9955
# Epoch 39/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3644 - iou_score: 0.9572 - f1-score: 0.9768 - precision: 0.9908 - auc: 0.9983 - val_loss: 0.3761 - val_iou_score: 0.9400 - val_f1-score: 0.9660 - val_precision: 0.9867 - val_auc: 0.9971
# Epoch 40/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3595 - iou_score: 0.9652 - f1-score: 0.9814 - precision: 0.9924 - auc: 0.9987 - val_loss: 0.3748 - val_iou_score: 0.9446 - val_f1-score: 0.9687 - val_precision: 0.9882 - val_auc: 0.9976
# Epoch 41/100
# 35/35 [==============================] - 19s 529ms/step - loss: 0.3549 - iou_score: 0.9716 - f1-score: 0.9851 - precision: 0.9938 - auc: 0.9989 - val_loss: 0.3697 - val_iou_score: 0.9501 - val_f1-score: 0.9722 - val_precision: 0.9890 - val_auc: 0.9978
# Epoch 42/100
# 35/35 [==============================] - 19s 547ms/step - loss: 0.3538 - iou_score: 0.9733 - f1-score: 0.9860 - precision: 0.9941 - auc: 0.9989 - val_loss: 0.3680 - val_iou_score: 0.9517 - val_f1-score: 0.9733 - val_precision: 0.9893 - val_auc: 0.9979
# Epoch 43/100
# 35/35 [==============================] - 19s 536ms/step - loss: 0.3533 - iou_score: 0.9740 - f1-score: 0.9864 - precision: 0.9942 - auc: 0.9990 - val_loss: 0.3666 - val_iou_score: 0.9535 - val_f1-score: 0.9745 - val_precision: 0.9898 - val_auc: 0.9979
# Epoch 44/100
# 35/35 [==============================] - 19s 553ms/step - loss: 0.3529 - iou_score: 0.9746 - f1-score: 0.9867 - precision: 0.9944 - auc: 0.9990 - val_loss: 0.3663 - val_iou_score: 0.9539 - val_f1-score: 0.9747 - val_precision: 0.9899 - val_auc: 0.9979
# Epoch 45/100
# 35/35 [==============================] - 19s 536ms/step - loss: 0.3525 - iou_score: 0.9749 - f1-score: 0.9869 - precision: 0.9944 - auc: 0.9990 - val_loss: 0.3661 - val_iou_score: 0.9543 - val_f1-score: 0.9750 - val_precision: 0.9900 - val_auc: 0.9978
# Epoch 46/100
# 35/35 [==============================] - 19s 532ms/step - loss: 0.3523 - iou_score: 0.9753 - f1-score: 0.9872 - precision: 0.9945 - auc: 0.9991 - val_loss: 0.3657 - val_iou_score: 0.9551 - val_f1-score: 0.9755 - val_precision: 0.9902 - val_auc: 0.9978
# Epoch 47/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3520 - iou_score: 0.9756 - f1-score: 0.9873 - precision: 0.9946 - auc: 0.9991 - val_loss: 0.3655 - val_iou_score: 0.9554 - val_f1-score: 0.9756 - val_precision: 0.9903 - val_auc: 0.9978
# Epoch 48/100
# 35/35 [==============================] - 19s 535ms/step - loss: 0.3518 - iou_score: 0.9760 - f1-score: 0.9875 - precision: 0.9947 - auc: 0.9991 - val_loss: 0.3649 - val_iou_score: 0.9561 - val_f1-score: 0.9761 - val_precision: 0.9904 - val_auc: 0.9978
# Epoch 49/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3516 - iou_score: 0.9762 - f1-score: 0.9876 - precision: 0.9947 - auc: 0.9991 - val_loss: 0.3647 - val_iou_score: 0.9565 - val_f1-score: 0.9763 - val_precision: 0.9905 - val_auc: 0.9978
# Epoch 50/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3514 - iou_score: 0.9765 - f1-score: 0.9878 - precision: 0.9948 - auc: 0.9991 - val_loss: 0.3649 - val_iou_score: 0.9562 - val_f1-score: 0.9762 - val_precision: 0.9905 - val_auc: 0.9978
# Epoch 51/100
# 35/35 [==============================] - 18s 525ms/step - loss: 0.3512 - iou_score: 0.9768 - f1-score: 0.9880 - precision: 0.9948 - auc: 0.9991 - val_loss: 0.3641 - val_iou_score: 0.9572 - val_f1-score: 0.9768 - val_precision: 0.9907 - val_auc: 0.9978
# Epoch 52/100
# 35/35 [==============================] - 18s 526ms/step - loss: 0.3510 - iou_score: 0.9770 - f1-score: 0.9881 - precision: 0.9949 - auc: 0.9991 - val_loss: 0.3644 - val_iou_score: 0.9570 - val_f1-score: 0.9766 - val_precision: 0.9906 - val_auc: 0.9978
# Epoch 53/100
# 35/35 [==============================] - 18s 526ms/step - loss: 0.3509 - iou_score: 0.9773 - f1-score: 0.9883 - precision: 0.9950 - auc: 0.9992 - val_loss: 0.3643 - val_iou_score: 0.9570 - val_f1-score: 0.9766 - val_precision: 0.9906 - val_auc: 0.9978
# Epoch 54/100
# 35/35 [==============================] - 19s 531ms/step - loss: 0.3507 - iou_score: 0.9775 - f1-score: 0.9884 - precision: 0.9950 - auc: 0.9992 - val_loss: 0.3640 - val_iou_score: 0.9573 - val_f1-score: 0.9768 - val_precision: 0.9907 - val_auc: 0.9978
# Epoch 55/100
# 35/35 [==============================] - 19s 529ms/step - loss: 0.3505 - iou_score: 0.9777 - f1-score: 0.9885 - precision: 0.9951 - auc: 0.9992 - val_loss: 0.3637 - val_iou_score: 0.9576 - val_f1-score: 0.9770 - val_precision: 0.9908 - val_auc: 0.9978
# Epoch 56/100
# 35/35 [==============================] - 19s 540ms/step - loss: 0.3503 - iou_score: 0.9780 - f1-score: 0.9886 - precision: 0.9951 - auc: 0.9992 - val_loss: 0.3641 - val_iou_score: 0.9573 - val_f1-score: 0.9768 - val_precision: 0.9907 - val_auc: 0.9977
# Epoch 57/100
# 35/35 [==============================] - 18s 526ms/step - loss: 0.3502 - iou_score: 0.9782 - f1-score: 0.9887 - precision: 0.9951 - auc: 0.9992 - val_loss: 0.3642 - val_iou_score: 0.9568 - val_f1-score: 0.9765 - val_precision: 0.9906 - val_auc: 0.9977
# Epoch 58/100
# 35/35 [==============================] - 18s 528ms/step - loss: 0.3500 - iou_score: 0.9784 - f1-score: 0.9888 - precision: 0.9952 - auc: 0.9992 - val_loss: 0.3635 - val_iou_score: 0.9579 - val_f1-score: 0.9772 - val_precision: 0.9908 - val_auc: 0.9977
# Epoch 59/100
# 35/35 [==============================] - 18s 526ms/step - loss: 0.3499 - iou_score: 0.9785 - f1-score: 0.9889 - precision: 0.9952 - auc: 0.9992 - val_loss: 0.3634 - val_iou_score: 0.9580 - val_f1-score: 0.9772 - val_precision: 0.9908 - val_auc: 0.9977
# Epoch 60/100
# 35/35 [==============================] - 18s 528ms/step - loss: 0.3498 - iou_score: 0.9788 - f1-score: 0.9891 - precision: 0.9953 - auc: 0.9992 - val_loss: 0.3636 - val_iou_score: 0.9577 - val_f1-score: 0.9771 - val_precision: 0.9908 - val_auc: 0.9977
# Epoch 61/100
# 35/35 [==============================] - 18s 528ms/step - loss: 0.3496 - iou_score: 0.9789 - f1-score: 0.9891 - precision: 0.9953 - auc: 0.9992 - val_loss: 0.3636 - val_iou_score: 0.9578 - val_f1-score: 0.9771 - val_precision: 0.9908 - val_auc: 0.9977
# Epoch 62/100
# 35/35 [==============================] - 19s 529ms/step - loss: 0.3495 - iou_score: 0.9792 - f1-score: 0.9893 - precision: 0.9953 - auc: 0.9993 - val_loss: 0.3644 - val_iou_score: 0.9568 - val_f1-score: 0.9765 - val_precision: 0.9905 - val_auc: 0.9977
# Epoch 63/100
# 35/35 [==============================] - 18s 528ms/step - loss: 0.3493 - iou_score: 0.9793 - f1-score: 0.9893 - precision: 0.9954 - auc: 0.9993 - val_loss: 0.3639 - val_iou_score: 0.9574 - val_f1-score: 0.9769 - val_precision: 0.9906 - val_auc: 0.9977
# Epoch 64/100
# 35/35 [==============================] - 19s 529ms/step - loss: 0.3492 - iou_score: 0.9795 - f1-score: 0.9894 - precision: 0.9954 - auc: 0.9993 - val_loss: 0.3640 - val_iou_score: 0.9572 - val_f1-score: 0.9768 - val_precision: 0.9906 - val_auc: 0.9977
# Epoch 65/100
# 35/35 [==============================] - 18s 526ms/step - loss: 0.3491 - iou_score: 0.9797 - f1-score: 0.9896 - precision: 0.9955 - auc: 0.9993 - val_loss: 0.3644 - val_iou_score: 0.9566 - val_f1-score: 0.9764 - val_precision: 0.9905 - val_auc: 0.9976
# Epoch 66/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3489 - iou_score: 0.9798 - f1-score: 0.9896 - precision: 0.9955 - auc: 0.9993 - val_loss: 0.3633 - val_iou_score: 0.9583 - val_f1-score: 0.9775 - val_precision: 0.9909 - val_auc: 0.9977
# Epoch 67/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3488 - iou_score: 0.9801 - f1-score: 0.9897 - precision: 0.9955 - auc: 0.9993 - val_loss: 0.3636 - val_iou_score: 0.9578 - val_f1-score: 0.9772 - val_precision: 0.9907 - val_auc: 0.9976
# Epoch 68/100
# 35/35 [==============================] - 19s 542ms/step - loss: 0.3487 - iou_score: 0.9802 - f1-score: 0.9898 - precision: 0.9956 - auc: 0.9993 - val_loss: 0.3636 - val_iou_score: 0.9577 - val_f1-score: 0.9771 - val_precision: 0.9907 - val_auc: 0.9976
# Epoch 69/100
# 35/35 [==============================] - 18s 525ms/step - loss: 0.3485 - iou_score: 0.9803 - f1-score: 0.9899 - precision: 0.9956 - auc: 0.9993 - val_loss: 0.3636 - val_iou_score: 0.9580 - val_f1-score: 0.9772 - val_precision: 0.9907 - val_auc: 0.9976
# Epoch 70/100
# 35/35 [==============================] - 19s 535ms/step - loss: 0.3484 - iou_score: 0.9806 - f1-score: 0.9900 - precision: 0.9956 - auc: 0.9993 - val_loss: 0.3632 - val_iou_score: 0.9583 - val_f1-score: 0.9774 - val_precision: 0.9908 - val_auc: 0.9976
# Epoch 71/100
# 35/35 [==============================] - 18s 525ms/step - loss: 0.3483 - iou_score: 0.9807 - f1-score: 0.9901 - precision: 0.9957 - auc: 0.9993 - val_loss: 0.3632 - val_iou_score: 0.9584 - val_f1-score: 0.9775 - val_precision: 0.9908 - val_auc: 0.9976
# Epoch 72/100
# 35/35 [==============================] - 18s 525ms/step - loss: 0.3482 - iou_score: 0.9807 - f1-score: 0.9901 - precision: 0.9956 - auc: 0.9993 - val_loss: 0.3645 - val_iou_score: 0.9566 - val_f1-score: 0.9763 - val_precision: 0.9904 - val_auc: 0.9975
# Epoch 73/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3481 - iou_score: 0.9810 - f1-score: 0.9902 - precision: 0.9957 - auc: 0.9993 - val_loss: 0.3632 - val_iou_score: 0.9586 - val_f1-score: 0.9776 - val_precision: 0.9908 - val_auc: 0.9975
# Epoch 74/100
# 35/35 [==============================] - 18s 526ms/step - loss: 0.3480 - iou_score: 0.9811 - f1-score: 0.9903 - precision: 0.9957 - auc: 0.9993 - val_loss: 0.3640 - val_iou_score: 0.9570 - val_f1-score: 0.9766 - val_precision: 0.9905 - val_auc: 0.9975
# Epoch 75/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3478 - iou_score: 0.9813 - f1-score: 0.9904 - precision: 0.9958 - auc: 0.9994 - val_loss: 0.3628 - val_iou_score: 0.9588 - val_f1-score: 0.9777 - val_precision: 0.9909 - val_auc: 0.9975
# Epoch 76/100
# 35/35 [==============================] - 19s 541ms/step - loss: 0.3477 - iou_score: 0.9814 - f1-score: 0.9905 - precision: 0.9958 - auc: 0.9994 - val_loss: 0.3628 - val_iou_score: 0.9588 - val_f1-score: 0.9778 - val_precision: 0.9909 - val_auc: 0.9975
# Epoch 77/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3477 - iou_score: 0.9815 - f1-score: 0.9905 - precision: 0.9958 - auc: 0.9994 - val_loss: 0.3628 - val_iou_score: 0.9587 - val_f1-score: 0.9777 - val_precision: 0.9908 - val_auc: 0.9975
# Epoch 78/100
# 35/35 [==============================] - 19s 531ms/step - loss: 0.3475 - iou_score: 0.9817 - f1-score: 0.9906 - precision: 0.9958 - auc: 0.9994 - val_loss: 0.3638 - val_iou_score: 0.9576 - val_f1-score: 0.9770 - val_precision: 0.9906 - val_auc: 0.9974
# Epoch 79/100
# 35/35 [==============================] - 19s 529ms/step - loss: 0.3474 - iou_score: 0.9819 - f1-score: 0.9907 - precision: 0.9959 - auc: 0.9994 - val_loss: 0.3632 - val_iou_score: 0.9580 - val_f1-score: 0.9773 - val_precision: 0.9908 - val_auc: 0.9974
# Epoch 80/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3473 - iou_score: 0.9820 - f1-score: 0.9908 - precision: 0.9959 - auc: 0.9994 - val_loss: 0.3636 - val_iou_score: 0.9578 - val_f1-score: 0.9771 - val_precision: 0.9906 - val_auc: 0.9974
# Epoch 81/100
# 35/35 [==============================] - 18s 528ms/step - loss: 0.3472 - iou_score: 0.9823 - f1-score: 0.9909 - precision: 0.9960 - auc: 0.9994 - val_loss: 0.3627 - val_iou_score: 0.9587 - val_f1-score: 0.9777 - val_precision: 0.9909 - val_auc: 0.9975
# Epoch 82/100
# 35/35 [==============================] - 19s 534ms/step - loss: 0.3471 - iou_score: 0.9823 - f1-score: 0.9909 - precision: 0.9960 - auc: 0.9994 - val_loss: 0.3632 - val_iou_score: 0.9581 - val_f1-score: 0.9773 - val_precision: 0.9908 - val_auc: 0.9974
# Epoch 83/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3470 - iou_score: 0.9825 - f1-score: 0.9910 - precision: 0.9960 - auc: 0.9994 - val_loss: 0.3629 - val_iou_score: 0.9586 - val_f1-score: 0.9776 - val_precision: 0.9908 - val_auc: 0.9974
# Epoch 84/100
# 35/35 [==============================] - 18s 526ms/step - loss: 0.3469 - iou_score: 0.9826 - f1-score: 0.9911 - precision: 0.9960 - auc: 0.9994 - val_loss: 0.3626 - val_iou_score: 0.9589 - val_f1-score: 0.9778 - val_precision: 0.9910 - val_auc: 0.9974
# Epoch 85/100
# 35/35 [==============================] - 19s 529ms/step - loss: 0.3468 - iou_score: 0.9827 - f1-score: 0.9912 - precision: 0.9960 - auc: 0.9994 - val_loss: 0.3630 - val_iou_score: 0.9587 - val_f1-score: 0.9777 - val_precision: 0.9908 - val_auc: 0.9974
# Epoch 86/100
# 35/35 [==============================] - 19s 537ms/step - loss: 0.3467 - iou_score: 0.9829 - f1-score: 0.9912 - precision: 0.9961 - auc: 0.9994 - val_loss: 0.3624 - val_iou_score: 0.9592 - val_f1-score: 0.9780 - val_precision: 0.9910 - val_auc: 0.9974
# Epoch 87/100
# 35/35 [==============================] - 18s 521ms/step - loss: 0.3466 - iou_score: 0.9829 - f1-score: 0.9913 - precision: 0.9961 - auc: 0.9994 - val_loss: 0.3626 - val_iou_score: 0.9590 - val_f1-score: 0.9778 - val_precision: 0.9909 - val_auc: 0.9974
# Epoch 88/100
# 35/35 [==============================] - 18s 523ms/step - loss: 0.3464 - iou_score: 0.9831 - f1-score: 0.9914 - precision: 0.9961 - auc: 0.9995 - val_loss: 0.3626 - val_iou_score: 0.9590 - val_f1-score: 0.9779 - val_precision: 0.9909 - val_auc: 0.9974
# Epoch 89/100
# 35/35 [==============================] - 18s 522ms/step - loss: 0.3464 - iou_score: 0.9832 - f1-score: 0.9914 - precision: 0.9961 - auc: 0.9995 - val_loss: 0.3625 - val_iou_score: 0.9591 - val_f1-score: 0.9779 - val_precision: 0.9910 - val_auc: 0.9974
# Epoch 90/100
# 35/35 [==============================] - 18s 522ms/step - loss: 0.3462 - iou_score: 0.9835 - f1-score: 0.9916 - precision: 0.9962 - auc: 0.9995 - val_loss: 0.3626 - val_iou_score: 0.9588 - val_f1-score: 0.9777 - val_precision: 0.9908 - val_auc: 0.9974
# Epoch 91/100
# 35/35 [==============================] - 18s 522ms/step - loss: 0.3461 - iou_score: 0.9837 - f1-score: 0.9917 - precision: 0.9962 - auc: 0.9995 - val_loss: 0.3629 - val_iou_score: 0.9583 - val_f1-score: 0.9774 - val_precision: 0.9907 - val_auc: 0.9973
# Epoch 92/100
# 35/35 [==============================] - 18s 525ms/step - loss: 0.3460 - iou_score: 0.9837 - f1-score: 0.9917 - precision: 0.9963 - auc: 0.9995 - val_loss: 0.3633 - val_iou_score: 0.9576 - val_f1-score: 0.9771 - val_precision: 0.9907 - val_auc: 0.9972
# Epoch 93/100
# 35/35 [==============================] - 19s 532ms/step - loss: 0.3459 - iou_score: 0.9838 - f1-score: 0.9917 - precision: 0.9963 - auc: 0.9995 - val_loss: 0.3635 - val_iou_score: 0.9576 - val_f1-score: 0.9770 - val_precision: 0.9905 - val_auc: 0.9972
# Epoch 94/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3458 - iou_score: 0.9841 - f1-score: 0.9919 - precision: 0.9963 - auc: 0.9995 - val_loss: 0.3618 - val_iou_score: 0.9599 - val_f1-score: 0.9783 - val_precision: 0.9910 - val_auc: 0.9973
# Epoch 95/100
# 35/35 [==============================] - 19s 537ms/step - loss: 0.3457 - iou_score: 0.9841 - f1-score: 0.9919 - precision: 0.9963 - auc: 0.9995 - val_loss: 0.3625 - val_iou_score: 0.9588 - val_f1-score: 0.9777 - val_precision: 0.9909 - val_auc: 0.9973
# Epoch 96/100
# 35/35 [==============================] - 18s 523ms/step - loss: 0.3456 - iou_score: 0.9843 - f1-score: 0.9920 - precision: 0.9964 - auc: 0.9995 - val_loss: 0.3626 - val_iou_score: 0.9586 - val_f1-score: 0.9776 - val_precision: 0.9909 - val_auc: 0.9973
# Epoch 97/100
# 35/35 [==============================] - 18s 522ms/step - loss: 0.3455 - iou_score: 0.9844 - f1-score: 0.9920 - precision: 0.9964 - auc: 0.9995 - val_loss: 0.3639 - val_iou_score: 0.9570 - val_f1-score: 0.9766 - val_precision: 0.9903 - val_auc: 0.9972
# Epoch 98/100
# 35/35 [==============================] - 18s 522ms/step - loss: 0.3454 - iou_score: 0.9846 - f1-score: 0.9921 - precision: 0.9964 - auc: 0.9995 - val_loss: 0.3633 - val_iou_score: 0.9577 - val_f1-score: 0.9770 - val_precision: 0.9906 - val_auc: 0.9972
# Epoch 99/100
# 35/35 [==============================] - 18s 526ms/step - loss: 0.3452 - iou_score: 0.9849 - f1-score: 0.9923 - precision: 0.9965 - auc: 0.9996 - val_loss: 0.3627 - val_iou_score: 0.9585 - val_f1-score: 0.9775 - val_precision: 0.9908 - val_auc: 0.9972
# Epoch 100/100
# 35/35 [==============================] - 18s 523ms/step - loss: 0.3451 - iou_score: 0.9850 - f1-score: 0.9923 - precision: 0.9965 - auc: 0.9995 - val_loss: 0.3629 - val_iou_score: 0.9581 - val_f1-score: 0.9773 - val_precision: 0.9908 - val_auc: 0.9972

# %%
# Plot training & validation iou_score values
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['f1-score'])
plt.plot(history.history['val_f1-score'])
plt.title('Model f1 Score')
plt.ylabel('f1 Score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.ylabel('Precision')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
n = 5

for i in range(n):
    
    image, gt_mask = valid_dataset[i]
    image = np.expand_dims(image, axis=0)
    pr_mask = model.predict(image).round()
    
    visualize(
        image=denormalize(image.squeeze()),
        gt_mask=gt_mask[..., 1].squeeze(),
        pr_mask=pr_mask[..., 1].squeeze(),
    )

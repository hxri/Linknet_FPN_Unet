# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

import cv2
import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
DATA_DIR = './dataset2/'

# %%
x_train_dir = os.path.join(DATA_DIR, 'train_images')
y_train_dir = os.path.join(DATA_DIR, 'train_annotations')

x_valid_dir = os.path.join(DATA_DIR, 'val_images')
y_valid_dir = os.path.join(DATA_DIR, 'val_annotations')

# %% [markdown]
# ## Dataloader

# %%
# helper function for data visualization
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()
    
# helper function for data visualization    
def denormalize(x):
    """Scale image to range 0..1 for correct plot"""
    x_max = np.percentile(x, 98)
    x_min = np.percentile(x, 2)    
    x = (x - x_min) / (x_max - x_min)
    x = x.clip(0, 1)
    return x
    

# classes for data loading and preprocessing
class Dataset:
    """CamVid Dataset. Read images, apply augmentation and preprocessing transformations.
    
    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing 
            (e.g. noralization, shape manipulation, etc.)
    
    """
    
    CLASSES = ['background', 'blob']
    
    def __init__(
            self, 
            images_dir, 
            masks_dir, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
    ):
        self.ids = os.listdir(images_dir)
        self.images_fps = [os.path.join(images_dir, image_id) for image_id in self.ids]
        self.masks_fps = [os.path.join(masks_dir, image_id) for image_id in self.ids]
        
        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        # read data
        image = cv2.imread(self.images_fps[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.masks_fps[i], 0)
        
        # extract certain classes from mask (e.g. cars)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1).astype('float')
        
        # add background if mask is not binary
        if mask.shape[-1] != 1:
            background = 1 - mask.sum(axis=-1, keepdims=True)
            mask = np.concatenate((mask, background), axis=-1)
        
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
            
        return image, mask
        
    def __len__(self):
        return len(self.ids)
    
    
class Dataloder(keras.utils.Sequence):
    """Load data from dataset and form batches
    
    Args:
        dataset: instance of Dataset class for image loading and preprocessing.
        batch_size: Integet number of images in batch.
        shuffle: Boolean, if `True` shuffle image indexes each epoch.
    """
    
    def __init__(self, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(dataset))

        self.on_epoch_end()

    def __getitem__(self, i):
        
        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        data = []
        for j in range(start, stop):
            data.append(self.dataset[j])
        
        # transpose list of lists
        batch = [np.stack(samples, axis=0) for samples in zip(*data)]
        
        return (batch[0],batch[1])
    
    def __len__(self):
        """Denotes the number of batches per epoch"""
        return len(self.indexes) // self.batch_size
    
    def on_epoch_end(self):
        """Callback function to shuffle indexes each epoch"""
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

# %%
# Lets look at data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['background', 'blob'])

image, mask = dataset[5] # get some sample
visualize(
    image=image, 
    background=mask[..., 0].squeeze(),
    blob=mask[..., 1].squeeze(),
)

# %% [markdown]
# ## Augmentation

# %%
import albumentations as A

# %%
def round_clip_0_1(x, **kwargs):
    return x.round().clip(0, 1)

# define heavy augmentations
def get_training_augmentation():
    train_transform = [

        A.Resize (320, 480, interpolation=1, always_apply=True, p=1),
    ]
    return A.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        A.PadIfNeeded(384, 480, always_apply=True)
    ]
    return A.Compose(test_transform)

def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        A.Lambda(image=preprocessing_fn),
    ]
    return A.Compose(_transform)

# %%
# Lets look at augmented data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['background', 'blob'], augmentation=get_training_augmentation())

image, mask = dataset[12] # get some sample
visualize(
    image=image, 
    background=mask[..., 0].squeeze(),
    blob=mask[..., 1].squeeze(),
)

# %% [markdown]
# ## Model

# %%
# %env SM_FRAMEWORK=tf.keras

import segmentation_models as sm
# Out:
# env: SM_FRAMEWORK=tf.keras

# %%
BACKBONE = 'efficientnetb3'
BATCH_SIZE = 2
CLASSES = ['background', 'blob']
LR = 0.0001
EPOCHS = 5

preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
# define network parameters
n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
activation = 'sigmoid' if n_classes == 1 else 'softmax'

#create model
model = sm.Unet(BACKBONE, classes=n_classes, activation=activation)

# %%
# define optomizer
optim = keras.optimizers.Adam(LR)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
dice_loss = sm.losses.DiceLoss()
focal_loss = sm.losses.BinaryFocalLoss() if n_classes == 1 else sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
# total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss 

metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]

# compile keras model with defined optimozer, loss and metrics
model.compile(optim, total_loss, metrics)

# %%
# Dataset for train images
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

# Dataset for validation images
valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

train_dataloader = Dataloder(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_dataloader = Dataloder(valid_dataset, batch_size=1, shuffle=False)

# check shapes for errors
assert train_dataloader[0][0].shape == (BATCH_SIZE, 320, 480, 3)
assert train_dataloader[0][1].shape == (BATCH_SIZE, 320, 480, n_classes)

# define callbacks for learning rate scheduling and best checkpoints saving
callbacks = [
    keras.callbacks.ModelCheckpoint('./best_model.h5', save_weights_only=True, save_best_only=True, mode='min'),
    keras.callbacks.ReduceLROnPlateau(),
]

# %%
print(valid_dataloader[0][0].shape)
# Out:
# (1, 320, 480, 3)

# %%
# train model
history = model.fit(
    train_dataloader, 
    steps_per_epoch=len(train_dataloader), 
    epochs=100, 
    callbacks=callbacks,
    validation_data=valid_dataloader, 
    validation_steps=len(valid_dataloader),
)
# Out:
# Epoch 1/100
# 35/35 [==============================] - 23s 666ms/step - loss: 0.8367 - iou_score: 0.0937 - f1-score: 0.1413 - val_loss: 1.1682 - val_iou_score: 0.0259 - val_f1-score: 0.0465
# Epoch 2/100
# 35/35 [==============================] - 22s 629ms/step - loss: 0.7549 - iou_score: 0.1538 - f1-score: 0.2065 - val_loss: 0.8424 - val_iou_score: 0.1382 - val_f1-score: 0.1907
# Epoch 3/100
# 35/35 [==============================] - 22s 628ms/step - loss: 0.7214 - iou_score: 0.2101 - f1-score: 0.2563 - val_loss: 0.7446 - val_iou_score: 0.2487 - val_f1-score: 0.2996
# Epoch 4/100
# 35/35 [==============================] - 22s 618ms/step - loss: 0.6936 - iou_score: 0.3909 - f1-score: 0.4455 - val_loss: 0.6984 - val_iou_score: 0.3633 - val_f1-score: 0.4211
# Epoch 5/100
# 35/35 [==============================] - 21s 602ms/step - loss: 0.6589 - iou_score: 0.5407 - f1-score: 0.5954 - val_loss: 0.6780 - val_iou_score: 0.6399 - val_f1-score: 0.6914
# Epoch 6/100
# 35/35 [==============================] - 22s 625ms/step - loss: 0.6121 - iou_score: 0.5985 - f1-score: 0.6379 - val_loss: 0.6445 - val_iou_score: 0.6719 - val_f1-score: 0.7151
# Epoch 7/100
# 35/35 [==============================] - 22s 615ms/step - loss: 0.5644 - iou_score: 0.7735 - f1-score: 0.7989 - val_loss: 0.5903 - val_iou_score: 0.7440 - val_f1-score: 0.7651
# Epoch 8/100
# 35/35 [==============================] - 22s 619ms/step - loss: 0.5232 - iou_score: 0.8580 - f1-score: 0.8756 - val_loss: 0.5404 - val_iou_score: 0.8850 - val_f1-score: 0.9025
# Epoch 9/100
# 35/35 [==============================] - 21s 607ms/step - loss: 0.4901 - iou_score: 0.9297 - f1-score: 0.9450 - val_loss: 0.5031 - val_iou_score: 0.9637 - val_f1-score: 0.9805
# Epoch 10/100
# 35/35 [==============================] - 22s 639ms/step - loss: 0.4615 - iou_score: 0.9724 - f1-score: 0.9856 - val_loss: 0.4788 - val_iou_score: 0.9627 - val_f1-score: 0.9798
# Epoch 11/100
# 35/35 [==============================] - 22s 625ms/step - loss: 0.4361 - iou_score: 0.9744 - f1-score: 0.9866 - val_loss: 0.4532 - val_iou_score: 0.9604 - val_f1-score: 0.9783
# Epoch 12/100
# 35/35 [==============================] - 22s 633ms/step - loss: 0.4167 - iou_score: 0.9759 - f1-score: 0.9875 - val_loss: 0.4372 - val_iou_score: 0.9631 - val_f1-score: 0.9800
# Epoch 13/100
# 35/35 [==============================] - 21s 609ms/step - loss: 0.4017 - iou_score: 0.9779 - f1-score: 0.9886 - val_loss: 0.4291 - val_iou_score: 0.9616 - val_f1-score: 0.9791
# Epoch 14/100
# 35/35 [==============================] - 22s 632ms/step - loss: 0.3906 - iou_score: 0.9795 - f1-score: 0.9894 - val_loss: 0.4138 - val_iou_score: 0.9618 - val_f1-score: 0.9793
# Epoch 15/100
# 35/35 [==============================] - 22s 627ms/step - loss: 0.3820 - iou_score: 0.9808 - f1-score: 0.9902 - val_loss: 0.4068 - val_iou_score: 0.9635 - val_f1-score: 0.9803
# Epoch 16/100
# 35/35 [==============================] - 21s 609ms/step - loss: 0.3751 - iou_score: 0.9827 - f1-score: 0.9911 - val_loss: 0.3972 - val_iou_score: 0.9651 - val_f1-score: 0.9813
# Epoch 17/100
# 35/35 [==============================] - 22s 630ms/step - loss: 0.3701 - iou_score: 0.9835 - f1-score: 0.9915 - val_loss: 0.3907 - val_iou_score: 0.9646 - val_f1-score: 0.9810
# Epoch 18/100
# 35/35 [==============================] - 18s 516ms/step - loss: 0.3659 - iou_score: 0.9841 - f1-score: 0.9919 - val_loss: 0.3991 - val_iou_score: 0.9514 - val_f1-score: 0.9712
# Epoch 19/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3628 - iou_score: 0.9843 - f1-score: 0.9920 - val_loss: 0.3978 - val_iou_score: 0.9503 - val_f1-score: 0.9702
# Epoch 20/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3597 - iou_score: 0.9855 - f1-score: 0.9926 - val_loss: 0.3963 - val_iou_score: 0.9498 - val_f1-score: 0.9696
# Epoch 21/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3573 - iou_score: 0.9864 - f1-score: 0.9931 - val_loss: 0.3926 - val_iou_score: 0.9501 - val_f1-score: 0.9697
# Epoch 22/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3552 - iou_score: 0.9872 - f1-score: 0.9935 - val_loss: 0.3917 - val_iou_score: 0.9498 - val_f1-score: 0.9696
# Epoch 23/100
# 35/35 [==============================] - 21s 609ms/step - loss: 0.3540 - iou_score: 0.9866 - f1-score: 0.9932 - val_loss: 0.3890 - val_iou_score: 0.9490 - val_f1-score: 0.9693
# Epoch 24/100
# 35/35 [==============================] - 22s 620ms/step - loss: 0.3529 - iou_score: 0.9864 - f1-score: 0.9931 - val_loss: 0.3884 - val_iou_score: 0.9495 - val_f1-score: 0.9693
# Epoch 25/100
# 35/35 [==============================] - 22s 623ms/step - loss: 0.3511 - iou_score: 0.9878 - f1-score: 0.9938 - val_loss: 0.3865 - val_iou_score: 0.9506 - val_f1-score: 0.9701
# Epoch 26/100
# 35/35 [==============================] - 22s 616ms/step - loss: 0.3498 - iou_score: 0.9885 - f1-score: 0.9942 - val_loss: 0.3864 - val_iou_score: 0.9499 - val_f1-score: 0.9695
# Epoch 27/100
# 35/35 [==============================] - 22s 641ms/step - loss: 0.3487 - iou_score: 0.9890 - f1-score: 0.9944 - val_loss: 0.3839 - val_iou_score: 0.9492 - val_f1-score: 0.9694
# Epoch 28/100
# 35/35 [==============================] - 18s 525ms/step - loss: 0.3483 - iou_score: 0.9884 - f1-score: 0.9941 - val_loss: 0.3855 - val_iou_score: 0.9472 - val_f1-score: 0.9679
# Epoch 29/100
# 35/35 [==============================] - 22s 619ms/step - loss: 0.3473 - iou_score: 0.9891 - f1-score: 0.9945 - val_loss: 0.3832 - val_iou_score: 0.9487 - val_f1-score: 0.9689
# Epoch 30/100
# 35/35 [==============================] - 22s 627ms/step - loss: 0.3471 - iou_score: 0.9887 - f1-score: 0.9942 - val_loss: 0.3816 - val_iou_score: 0.9504 - val_f1-score: 0.9699
# Epoch 31/100
# 35/35 [==============================] - 18s 514ms/step - loss: 0.3460 - iou_score: 0.9897 - f1-score: 0.9948 - val_loss: 0.3818 - val_iou_score: 0.9491 - val_f1-score: 0.9692
# Epoch 32/100
# 35/35 [==============================] - 18s 519ms/step - loss: 0.3453 - iou_score: 0.9902 - f1-score: 0.9950 - val_loss: 0.3827 - val_iou_score: 0.9483 - val_f1-score: 0.9685
# Epoch 33/100
# 35/35 [==============================] - 18s 524ms/step - loss: 0.3449 - iou_score: 0.9901 - f1-score: 0.9950 - val_loss: 0.3823 - val_iou_score: 0.9482 - val_f1-score: 0.9685
# Epoch 34/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3445 - iou_score: 0.9903 - f1-score: 0.9951 - val_loss: 0.3817 - val_iou_score: 0.9484 - val_f1-score: 0.9686
# Epoch 35/100
# 35/35 [==============================] - 22s 620ms/step - loss: 0.3438 - iou_score: 0.9910 - f1-score: 0.9955 - val_loss: 0.3798 - val_iou_score: 0.9488 - val_f1-score: 0.9690
# Epoch 36/100
# 35/35 [==============================] - 18s 521ms/step - loss: 0.3436 - iou_score: 0.9909 - f1-score: 0.9954 - val_loss: 0.3811 - val_iou_score: 0.9479 - val_f1-score: 0.9683
# Epoch 37/100
# 35/35 [==============================] - 21s 601ms/step - loss: 0.3431 - iou_score: 0.9912 - f1-score: 0.9956 - val_loss: 0.3787 - val_iou_score: 0.9493 - val_f1-score: 0.9693
# Epoch 38/100
# 35/35 [==============================] - 18s 519ms/step - loss: 0.3428 - iou_score: 0.9912 - f1-score: 0.9956 - val_loss: 0.3794 - val_iou_score: 0.9489 - val_f1-score: 0.9691
# Epoch 39/100
# 35/35 [==============================] - 19s 534ms/step - loss: 0.3425 - iou_score: 0.9915 - f1-score: 0.9957 - val_loss: 0.3794 - val_iou_score: 0.9487 - val_f1-score: 0.9688
# Epoch 40/100
# 35/35 [==============================] - 19s 531ms/step - loss: 0.3421 - iou_score: 0.9917 - f1-score: 0.9958 - val_loss: 0.3796 - val_iou_score: 0.9489 - val_f1-score: 0.9690
# Epoch 41/100
# 35/35 [==============================] - 22s 625ms/step - loss: 0.3419 - iou_score: 0.9917 - f1-score: 0.9958 - val_loss: 0.3770 - val_iou_score: 0.9492 - val_f1-score: 0.9694
# Epoch 42/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3416 - iou_score: 0.9921 - f1-score: 0.9960 - val_loss: 0.3795 - val_iou_score: 0.9480 - val_f1-score: 0.9683
# Epoch 43/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3413 - iou_score: 0.9922 - f1-score: 0.9961 - val_loss: 0.3783 - val_iou_score: 0.9484 - val_f1-score: 0.9687
# Epoch 44/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3409 - iou_score: 0.9928 - f1-score: 0.9963 - val_loss: 0.3802 - val_iou_score: 0.9477 - val_f1-score: 0.9681
# Epoch 45/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3407 - iou_score: 0.9929 - f1-score: 0.9964 - val_loss: 0.3783 - val_iou_score: 0.9484 - val_f1-score: 0.9687
# Epoch 46/100
# 35/35 [==============================] - 18s 516ms/step - loss: 0.3408 - iou_score: 0.9924 - f1-score: 0.9962 - val_loss: 0.3785 - val_iou_score: 0.9481 - val_f1-score: 0.9684
# Epoch 47/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3407 - iou_score: 0.9922 - f1-score: 0.9961 - val_loss: 0.3792 - val_iou_score: 0.9485 - val_f1-score: 0.9685
# Epoch 48/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3402 - iou_score: 0.9929 - f1-score: 0.9964 - val_loss: 0.3796 - val_iou_score: 0.9479 - val_f1-score: 0.9681
# Epoch 49/100
# 35/35 [==============================] - 18s 516ms/step - loss: 0.3400 - iou_score: 0.9931 - f1-score: 0.9965 - val_loss: 0.3798 - val_iou_score: 0.9474 - val_f1-score: 0.9679
# Epoch 50/100
# 35/35 [==============================] - 18s 516ms/step - loss: 0.3399 - iou_score: 0.9932 - f1-score: 0.9966 - val_loss: 0.3799 - val_iou_score: 0.9472 - val_f1-score: 0.9677
# Epoch 51/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3395 - iou_score: 0.9937 - f1-score: 0.9968 - val_loss: 0.3792 - val_iou_score: 0.9481 - val_f1-score: 0.9682
# Epoch 52/100
# 35/35 [==============================] - 18s 518ms/step - loss: 0.3392 - iou_score: 0.9943 - f1-score: 0.9971 - val_loss: 0.3792 - val_iou_score: 0.9481 - val_f1-score: 0.9682
# Epoch 53/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3389 - iou_score: 0.9948 - f1-score: 0.9974 - val_loss: 0.3789 - val_iou_score: 0.9482 - val_f1-score: 0.9684
# Epoch 54/100
# 35/35 [==============================] - 18s 524ms/step - loss: 0.3388 - iou_score: 0.9950 - f1-score: 0.9975 - val_loss: 0.3789 - val_iou_score: 0.9481 - val_f1-score: 0.9684
# Epoch 55/100
# 35/35 [==============================] - 18s 521ms/step - loss: 0.3387 - iou_score: 0.9951 - f1-score: 0.9975 - val_loss: 0.3792 - val_iou_score: 0.9480 - val_f1-score: 0.9682
# Epoch 56/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3387 - iou_score: 0.9952 - f1-score: 0.9976 - val_loss: 0.3791 - val_iou_score: 0.9480 - val_f1-score: 0.9682
# Epoch 57/100
# 35/35 [==============================] - 18s 518ms/step - loss: 0.3386 - iou_score: 0.9953 - f1-score: 0.9976 - val_loss: 0.3787 - val_iou_score: 0.9482 - val_f1-score: 0.9685
# Epoch 58/100
# 35/35 [==============================] - 18s 518ms/step - loss: 0.3386 - iou_score: 0.9954 - f1-score: 0.9977 - val_loss: 0.3786 - val_iou_score: 0.9483 - val_f1-score: 0.9685
# Epoch 59/100
# 35/35 [==============================] - 18s 518ms/step - loss: 0.3385 - iou_score: 0.9955 - f1-score: 0.9977 - val_loss: 0.3782 - val_iou_score: 0.9486 - val_f1-score: 0.9687
# Epoch 60/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3386 - iou_score: 0.9954 - f1-score: 0.9977 - val_loss: 0.3780 - val_iou_score: 0.9485 - val_f1-score: 0.9688
# Epoch 61/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3385 - iou_score: 0.9955 - f1-score: 0.9977 - val_loss: 0.3779 - val_iou_score: 0.9486 - val_f1-score: 0.9688
# Epoch 62/100
# 35/35 [==============================] - 18s 518ms/step - loss: 0.3386 - iou_score: 0.9954 - f1-score: 0.9977 - val_loss: 0.3782 - val_iou_score: 0.9485 - val_f1-score: 0.9687
# Epoch 63/100
# 35/35 [==============================] - 18s 518ms/step - loss: 0.3385 - iou_score: 0.9954 - f1-score: 0.9977 - val_loss: 0.3782 - val_iou_score: 0.9485 - val_f1-score: 0.9687
# Epoch 64/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3385 - iou_score: 0.9956 - f1-score: 0.9978 - val_loss: 0.3776 - val_iou_score: 0.9488 - val_f1-score: 0.9690
# Epoch 65/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3385 - iou_score: 0.9956 - f1-score: 0.9978 - val_loss: 0.3780 - val_iou_score: 0.9486 - val_f1-score: 0.9688
# Epoch 66/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3385 - iou_score: 0.9956 - f1-score: 0.9978 - val_loss: 0.3786 - val_iou_score: 0.9483 - val_f1-score: 0.9685
# Epoch 67/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3385 - iou_score: 0.9955 - f1-score: 0.9977 - val_loss: 0.3794 - val_iou_score: 0.9479 - val_f1-score: 0.9682
# Epoch 68/100
# 35/35 [==============================] - 18s 522ms/step - loss: 0.3384 - iou_score: 0.9957 - f1-score: 0.9978 - val_loss: 0.3792 - val_iou_score: 0.9480 - val_f1-score: 0.9683
# Epoch 69/100
# 35/35 [==============================] - 18s 518ms/step - loss: 0.3384 - iou_score: 0.9957 - f1-score: 0.9978 - val_loss: 0.3791 - val_iou_score: 0.9481 - val_f1-score: 0.9683
# Epoch 70/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3384 - iou_score: 0.9957 - f1-score: 0.9978 - val_loss: 0.3785 - val_iou_score: 0.9483 - val_f1-score: 0.9685
# Epoch 71/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3385 - iou_score: 0.9956 - f1-score: 0.9978 - val_loss: 0.3791 - val_iou_score: 0.9480 - val_f1-score: 0.9683
# Epoch 72/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3384 - iou_score: 0.9957 - f1-score: 0.9978 - val_loss: 0.3794 - val_iou_score: 0.9478 - val_f1-score: 0.9681
# Epoch 73/100
# 35/35 [==============================] - 18s 518ms/step - loss: 0.3384 - iou_score: 0.9957 - f1-score: 0.9978 - val_loss: 0.3794 - val_iou_score: 0.9478 - val_f1-score: 0.9681
# Epoch 74/100
# 35/35 [==============================] - 18s 522ms/step - loss: 0.3384 - iou_score: 0.9956 - f1-score: 0.9978 - val_loss: 0.3799 - val_iou_score: 0.9475 - val_f1-score: 0.9679
# Epoch 75/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3384 - iou_score: 0.9957 - f1-score: 0.9978 - val_loss: 0.3797 - val_iou_score: 0.9476 - val_f1-score: 0.9680
# Epoch 76/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3385 - iou_score: 0.9955 - f1-score: 0.9977 - val_loss: 0.3801 - val_iou_score: 0.9474 - val_f1-score: 0.9677
# Epoch 77/100
# 35/35 [==============================] - 18s 518ms/step - loss: 0.3385 - iou_score: 0.9955 - f1-score: 0.9978 - val_loss: 0.3798 - val_iou_score: 0.9476 - val_f1-score: 0.9679
# Epoch 78/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3385 - iou_score: 0.9954 - f1-score: 0.9977 - val_loss: 0.3800 - val_iou_score: 0.9475 - val_f1-score: 0.9678
# Epoch 79/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3385 - iou_score: 0.9955 - f1-score: 0.9977 - val_loss: 0.3790 - val_iou_score: 0.9481 - val_f1-score: 0.9684
# Epoch 80/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3384 - iou_score: 0.9956 - f1-score: 0.9978 - val_loss: 0.3790 - val_iou_score: 0.9481 - val_f1-score: 0.9684
# Epoch 81/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3385 - iou_score: 0.9954 - f1-score: 0.9977 - val_loss: 0.3793 - val_iou_score: 0.9480 - val_f1-score: 0.9682
# Epoch 82/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3384 - iou_score: 0.9957 - f1-score: 0.9978 - val_loss: 0.3793 - val_iou_score: 0.9480 - val_f1-score: 0.9682
# Epoch 83/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3384 - iou_score: 0.9957 - f1-score: 0.9978 - val_loss: 0.3798 - val_iou_score: 0.9477 - val_f1-score: 0.9680
# Epoch 84/100
# 35/35 [==============================] - 18s 518ms/step - loss: 0.3385 - iou_score: 0.9955 - f1-score: 0.9977 - val_loss: 0.3802 - val_iou_score: 0.9474 - val_f1-score: 0.9677
# Epoch 85/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3384 - iou_score: 0.9956 - f1-score: 0.9978 - val_loss: 0.3801 - val_iou_score: 0.9475 - val_f1-score: 0.9678
# Epoch 86/100
# 35/35 [==============================] - 18s 518ms/step - loss: 0.3384 - iou_score: 0.9956 - f1-score: 0.9978 - val_loss: 0.3801 - val_iou_score: 0.9475 - val_f1-score: 0.9678
# Epoch 87/100
# 35/35 [==============================] - 18s 523ms/step - loss: 0.3384 - iou_score: 0.9956 - f1-score: 0.9978 - val_loss: 0.3795 - val_iou_score: 0.9478 - val_f1-score: 0.9681
# Epoch 88/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3384 - iou_score: 0.9957 - f1-score: 0.9978 - val_loss: 0.3791 - val_iou_score: 0.9481 - val_f1-score: 0.9683
# Epoch 89/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3384 - iou_score: 0.9957 - f1-score: 0.9978 - val_loss: 0.3794 - val_iou_score: 0.9479 - val_f1-score: 0.9682
# Epoch 90/100
# 35/35 [==============================] - 18s 518ms/step - loss: 0.3385 - iou_score: 0.9955 - f1-score: 0.9977 - val_loss: 0.3799 - val_iou_score: 0.9476 - val_f1-score: 0.9679
# Epoch 91/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3384 - iou_score: 0.9958 - f1-score: 0.9979 - val_loss: 0.3789 - val_iou_score: 0.9481 - val_f1-score: 0.9684
# Epoch 92/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3384 - iou_score: 0.9956 - f1-score: 0.9978 - val_loss: 0.3786 - val_iou_score: 0.9483 - val_f1-score: 0.9685
# Epoch 93/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3384 - iou_score: 0.9957 - f1-score: 0.9979 - val_loss: 0.3783 - val_iou_score: 0.9484 - val_f1-score: 0.9686
# Epoch 94/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3384 - iou_score: 0.9957 - f1-score: 0.9978 - val_loss: 0.3793 - val_iou_score: 0.9479 - val_f1-score: 0.9682
# Epoch 95/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3384 - iou_score: 0.9957 - f1-score: 0.9978 - val_loss: 0.3790 - val_iou_score: 0.9481 - val_f1-score: 0.9683
# Epoch 96/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3384 - iou_score: 0.9957 - f1-score: 0.9978 - val_loss: 0.3795 - val_iou_score: 0.9478 - val_f1-score: 0.9681
# Epoch 97/100
# 35/35 [==============================] - 18s 518ms/step - loss: 0.3384 - iou_score: 0.9957 - f1-score: 0.9979 - val_loss: 0.3796 - val_iou_score: 0.9477 - val_f1-score: 0.9680
# Epoch 98/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3384 - iou_score: 0.9957 - f1-score: 0.9978 - val_loss: 0.3800 - val_iou_score: 0.9475 - val_f1-score: 0.9678
# Epoch 99/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3384 - iou_score: 0.9957 - f1-score: 0.9978 - val_loss: 0.3797 - val_iou_score: 0.9476 - val_f1-score: 0.9679
# Epoch 100/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3384 - iou_score: 0.9957 - f1-score: 0.9978 - val_loss: 0.3798 - val_iou_score: 0.9476 - val_f1-score: 0.9679

# %%
# Plot training & validation iou_score values
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['f1-score'])
plt.plot(history.history['val_f1-score'])
plt.title('Model f1 Score')
plt.ylabel('f1 Score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
n = 5

for i in range(n):
    
    image, gt_mask = valid_dataset[i]
    image = np.expand_dims(image, axis=0)
    pr_mask = model.predict(image).round()
    
    visualize(
        image=denormalize(image.squeeze()),
        gt_mask=gt_mask[..., 1].squeeze(),
        pr_mask=pr_mask[..., 1].squeeze(),
    )

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import tensorflow as tf
import cv2
import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
DATA_DIR = './dataset2/'

# %%
x_train_dir = os.path.join(DATA_DIR, 'train_images')
y_train_dir = os.path.join(DATA_DIR, 'train_annotations')

x_valid_dir = os.path.join(DATA_DIR, 'val_images')
y_valid_dir = os.path.join(DATA_DIR, 'val_annotations')

# %% [markdown]
# ## Dataloader

# %%
# helper function for data visualization
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()
    
# helper function for data visualization    
def denormalize(x):
    """Scale image to range 0..1 for correct plot"""
    x_max = np.percentile(x, 98)
    x_min = np.percentile(x, 2)    
    x = (x - x_min) / (x_max - x_min)
    x = x.clip(0, 1)
    return x
    

# classes for data loading and preprocessing
class Dataset:
    """CamVid Dataset. Read images, apply augmentation and preprocessing transformations.
    
    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing 
            (e.g. noralization, shape manipulation, etc.)
    
    """
    
    CLASSES = ['background', 'blob']
    
    def __init__(
            self, 
            images_dir, 
            masks_dir, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
    ):
        self.ids = os.listdir(images_dir)
        self.images_fps = [os.path.join(images_dir, image_id) for image_id in self.ids]
        self.masks_fps = [os.path.join(masks_dir, image_id) for image_id in self.ids]
        
        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        # read data
        image = cv2.imread(self.images_fps[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.masks_fps[i], 0)
        
        # extract certain classes from mask (e.g. cars)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1).astype('float')
        
        # add background if mask is not binary
        if mask.shape[-1] != 1:
            background = 1 - mask.sum(axis=-1, keepdims=True)
            mask = np.concatenate((mask, background), axis=-1)
        
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
            
        return image, mask
        
    def __len__(self):
        return len(self.ids)
    
    
class Dataloder(keras.utils.Sequence):
    """Load data from dataset and form batches
    
    Args:
        dataset: instance of Dataset class for image loading and preprocessing.
        batch_size: Integet number of images in batch.
        shuffle: Boolean, if `True` shuffle image indexes each epoch.
    """
    
    def __init__(self, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(dataset))

        self.on_epoch_end()

    def __getitem__(self, i):
        
        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        data = []
        for j in range(start, stop):
            data.append(self.dataset[j])
        
        # transpose list of lists
        batch = [np.stack(samples, axis=0) for samples in zip(*data)]
        
        return (batch[0],batch[1])
    
    def __len__(self):
        """Denotes the number of batches per epoch"""
        return len(self.indexes) // self.batch_size
    
    def on_epoch_end(self):
        """Callback function to shuffle indexes each epoch"""
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

# %%
# Lets look at data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['background', 'blob'])

image, mask = dataset[5] # get some sample
visualize(
    image=image, 
    background=mask[..., 0].squeeze(),
    blob=mask[..., 1].squeeze(),
)

# %% [markdown]
# ## Augmentation

# %%
import albumentations as A

# %%
def round_clip_0_1(x, **kwargs):
    return x.round().clip(0, 1)

# define heavy augmentations
def get_training_augmentation():
    train_transform = [

        A.Resize (320, 480, interpolation=1, always_apply=True, p=1),
    ]
    return A.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        A.PadIfNeeded(384, 480, always_apply=True)
    ]
    return A.Compose(test_transform)

def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        A.Lambda(image=preprocessing_fn),
    ]
    return A.Compose(_transform)

# %%
# Lets look at augmented data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['background', 'blob'], augmentation=get_training_augmentation())

image, mask = dataset[12] # get some sample
visualize(
    image=image, 
    background=mask[..., 0].squeeze(),
    blob=mask[..., 1].squeeze(),
)

# %% [markdown]
# ## Model

# %%
# %env SM_FRAMEWORK=tf.keras

import segmentation_models as sm
# Out:
# env: SM_FRAMEWORK=tf.keras
# Segmentation Models: using `tf.keras` framework.

# %%
BACKBONE = 'densenet121'
BATCH_SIZE = 2
CLASSES = ['background', 'blob']
LR = 0.0001
EPOCHS = 5

preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
# define network parameters
n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
activation = 'sigmoid' if n_classes == 1 else 'softmax'

def build_model_func():
    #create model
    model = sm.Linknet(BACKBONE, classes=n_classes, activation=activation)

    # define optomizer
    optim = keras.optimizers.Adam(LR)

    # Segmentation models losses can be combined together by '+' and scaled by integer or float factor
    dice_loss = sm.losses.DiceLoss()
    focal_loss = sm.losses.BinaryFocalLoss() if n_classes == 1 else sm.losses.CategoricalFocalLoss()
    total_loss = dice_loss + (1 * focal_loss)

    # actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
    # total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss 

    metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5), tf.keras.metrics.Precision(), tf.keras.metrics.AUC()]

    # compile keras model with defined optimozer, loss and metrics
    model.compile(optim, total_loss, metrics)
    return model

# %%
# Dataset for train images
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

# Dataset for validation images
valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

train_dataloader = Dataloder(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_dataloader = Dataloder(valid_dataset, batch_size=1, shuffle=False)

# check shapes for errors
assert train_dataloader[0][0].shape == (BATCH_SIZE, 320, 480, 3)
assert train_dataloader[0][1].shape == (BATCH_SIZE, 320, 480, n_classes)



# define callbacks for learning rate scheduling and best checkpoints saving
filepath = "checkpoints/saved_weights.{epoch:02d}.hdf5"
callbacks = [
    keras.callbacks.ModelCheckpoint(
            filepath, 
            save_weights_only=True, 
            save_best_only=False, 
            mode="min",
            verbose=0,
            save_freq='epoch',
        ),
    keras.callbacks.ReduceLROnPlateau(),
]

# %%
print(valid_dataloader[0][0].shape)
# Out:
# (1, 320, 480, 3)

# %%
#checkpoint_path = "proj/custom-segmentation/checkpoints/saved_weights.9.hdf5"
checkpoint_path = None
from tensorflow.keras.models import model_from_json

def get_init_epoch(checkpoint_path):
    return int(checkpoint_path.split('.')[1])

# Load checkpoint:
if checkpoint_path is not None:
    # Load model:
    model = build_model_func()
    model.load_weights(checkpoint_path)
    # Finding the epoch index from which we are resuming
    initial_epoch = get_init_epoch(checkpoint_path)
    # Calculating the correct value of count
    count = initial_epoch*BATCH_SIZE
    # Update the value of count in callback instance
    callbacks[1].count = count
else:
    model = build_model_func()
    initial_epoch = 0

# train model
history = model.fit(
    train_dataloader, 
    steps_per_epoch=len(train_dataloader), 
    epochs=100, 
    callbacks=callbacks,
    initial_epoch=initial_epoch,
    validation_data=valid_dataloader, 
    validation_steps=len(valid_dataloader),
)
# Out:
# Epoch 1/100
# 35/35 [==============================] - 26s 756ms/step - loss: 0.8190 - iou_score: 0.0972 - f1-score: 0.1518 - precision_3: 0.4359 - auc_3: 0.6371 - val_loss: 0.9765 - val_iou_score: 0.0087 - val_f1-score: 0.0170 - val_precision_3: 0.0654 - val_auc_3: 0.3840
# Epoch 2/100
# 35/35 [==============================] - 21s 613ms/step - loss: 0.6914 - iou_score: 0.3226 - f1-score: 0.4144 - precision_3: 0.7839 - auc_3: 0.8661 - val_loss: 1.0255 - val_iou_score: 0.1378 - val_f1-score: 0.2060 - val_precision_3: 0.1821 - val_auc_3: 0.4539
# Epoch 3/100
# 35/35 [==============================] - 22s 618ms/step - loss: 0.5768 - iou_score: 0.5046 - f1-score: 0.5719 - precision_3: 0.8953 - auc_3: 0.9483 - val_loss: 0.8057 - val_iou_score: 0.3591 - val_f1-score: 0.4557 - val_precision_3: 0.6539 - val_auc_3: 0.7293
# Epoch 4/100
# 35/35 [==============================] - 21s 613ms/step - loss: 0.5137 - iou_score: 0.5703 - f1-score: 0.6134 - precision_3: 0.9442 - auc_3: 0.9742 - val_loss: 0.7114 - val_iou_score: 0.4017 - val_f1-score: 0.4956 - val_precision_3: 0.6867 - val_auc_3: 0.7559
# Epoch 5/100
# 35/35 [==============================] - 21s 613ms/step - loss: 0.4704 - iou_score: 0.6033 - f1-score: 0.6327 - precision_3: 0.9651 - auc_3: 0.9897 - val_loss: 0.6047 - val_iou_score: 0.4788 - val_f1-score: 0.5541 - val_precision_3: 0.7924 - val_auc_3: 0.8809
# Epoch 6/100
# 35/35 [==============================] - 21s 609ms/step - loss: 0.4397 - iou_score: 0.6218 - f1-score: 0.6427 - precision_3: 0.9854 - auc_3: 0.9965 - val_loss: 0.5414 - val_iou_score: 0.5362 - val_f1-score: 0.5925 - val_precision_3: 0.8829 - val_auc_3: 0.9589
# Epoch 7/100
# 35/35 [==============================] - 22s 618ms/step - loss: 0.4181 - iou_score: 0.6298 - f1-score: 0.6472 - precision_3: 0.9922 - auc_3: 0.9976 - val_loss: 0.4958 - val_iou_score: 0.5752 - val_f1-score: 0.6150 - val_precision_3: 0.9459 - val_auc_3: 0.9866
# Epoch 8/100
# 35/35 [==============================] - 21s 612ms/step - loss: 0.4024 - iou_score: 0.6351 - f1-score: 0.6501 - precision_3: 0.9939 - auc_3: 0.9981 - val_loss: 0.4587 - val_iou_score: 0.5988 - val_f1-score: 0.6287 - val_precision_3: 0.9693 - val_auc_3: 0.9932
# Epoch 9/100
# 35/35 [==============================] - 21s 598ms/step - loss: 0.3908 - iou_score: 0.6378 - f1-score: 0.6516 - precision_3: 0.9946 - auc_3: 0.9984 - val_loss: 0.4416 - val_iou_score: 0.6090 - val_f1-score: 0.6355 - val_precision_3: 0.9749 - val_auc_3: 0.9947
# Epoch 10/100
# 35/35 [==============================] - 21s 601ms/step - loss: 0.3823 - iou_score: 0.6399 - f1-score: 0.6527 - precision_3: 0.9952 - auc_3: 0.9986 - val_loss: 0.4229 - val_iou_score: 0.6176 - val_f1-score: 0.6402 - val_precision_3: 0.9878 - val_auc_3: 0.9957
# Epoch 11/100
# 35/35 [==============================] - 22s 615ms/step - loss: 0.3753 - iou_score: 0.6430 - f1-score: 0.6544 - precision_3: 0.9957 - auc_3: 0.9988 - val_loss: 0.4094 - val_iou_score: 0.6168 - val_f1-score: 0.6394 - val_precision_3: 0.9889 - val_auc_3: 0.9957
# Epoch 12/100
# 35/35 [==============================] - 21s 604ms/step - loss: 0.3705 - iou_score: 0.6529 - f1-score: 0.6641 - precision_3: 0.9957 - auc_3: 0.9989 - val_loss: 0.4005 - val_iou_score: 0.6417 - val_f1-score: 0.6634 - val_precision_3: 0.9888 - val_auc_3: 0.9959
# Epoch 13/100
# 35/35 [==============================] - 22s 640ms/step - loss: 0.3659 - iou_score: 0.6555 - f1-score: 0.6655 - precision_3: 0.9962 - auc_3: 0.9991 - val_loss: 0.3937 - val_iou_score: 0.6423 - val_f1-score: 0.6633 - val_precision_3: 0.9911 - val_auc_3: 0.9963
# Epoch 14/100
# 35/35 [==============================] - 21s 605ms/step - loss: 0.3626 - iou_score: 0.6759 - f1-score: 0.6853 - precision_3: 0.9964 - auc_3: 0.9991 - val_loss: 0.3873 - val_iou_score: 0.6346 - val_f1-score: 0.6544 - val_precision_3: 0.9912 - val_auc_3: 0.9960
# Epoch 15/100
# 35/35 [==============================] - 21s 606ms/step - loss: 0.3600 - iou_score: 0.7240 - f1-score: 0.7332 - precision_3: 0.9965 - auc_3: 0.9992 - val_loss: 0.3841 - val_iou_score: 0.7115 - val_f1-score: 0.7313 - val_precision_3: 0.9915 - val_auc_3: 0.9964
# Epoch 16/100
# 35/35 [==============================] - 21s 609ms/step - loss: 0.3577 - iou_score: 0.7723 - f1-score: 0.7812 - precision_3: 0.9966 - auc_3: 0.9993 - val_loss: 0.3787 - val_iou_score: 0.7466 - val_f1-score: 0.7660 - val_precision_3: 0.9914 - val_auc_3: 0.9960
# Epoch 17/100
# 35/35 [==============================] - 21s 610ms/step - loss: 0.3560 - iou_score: 0.8967 - f1-score: 0.9053 - precision_3: 0.9966 - auc_3: 0.9993 - val_loss: 0.3748 - val_iou_score: 0.8573 - val_f1-score: 0.8766 - val_precision_3: 0.9916 - val_auc_3: 0.9961
# Epoch 18/100
# 35/35 [==============================] - 22s 626ms/step - loss: 0.3542 - iou_score: 0.8881 - f1-score: 0.8962 - precision_3: 0.9967 - auc_3: 0.9993 - val_loss: 0.3725 - val_iou_score: 0.8689 - val_f1-score: 0.8881 - val_precision_3: 0.9914 - val_auc_3: 0.9961
# Epoch 19/100
# 35/35 [==============================] - 21s 606ms/step - loss: 0.3526 - iou_score: 0.9272 - f1-score: 0.9348 - precision_3: 0.9969 - auc_3: 0.9994 - val_loss: 0.3732 - val_iou_score: 0.9106 - val_f1-score: 0.9306 - val_precision_3: 0.9912 - val_auc_3: 0.9960
# Epoch 20/100
# 35/35 [==============================] - 21s 611ms/step - loss: 0.3512 - iou_score: 0.9374 - f1-score: 0.9447 - precision_3: 0.9970 - auc_3: 0.9994 - val_loss: 0.3698 - val_iou_score: 0.9584 - val_f1-score: 0.9773 - val_precision_3: 0.9914 - val_auc_3: 0.9959
# Epoch 21/100
# 35/35 [==============================] - 22s 620ms/step - loss: 0.3503 - iou_score: 0.9470 - f1-score: 0.9543 - precision_3: 0.9970 - auc_3: 0.9994 - val_loss: 0.3703 - val_iou_score: 0.9450 - val_f1-score: 0.9648 - val_precision_3: 0.9911 - val_auc_3: 0.9958
# Epoch 22/100
# 35/35 [==============================] - 21s 611ms/step - loss: 0.3496 - iou_score: 0.9663 - f1-score: 0.9735 - precision_3: 0.9971 - auc_3: 0.9994 - val_loss: 0.3699 - val_iou_score: 0.9447 - val_f1-score: 0.9641 - val_precision_3: 0.9913 - val_auc_3: 0.9958
# Epoch 23/100
# 35/35 [==============================] - 21s 608ms/step - loss: 0.3494 - iou_score: 0.9655 - f1-score: 0.9730 - precision_3: 0.9970 - auc_3: 0.9994 - val_loss: 0.3672 - val_iou_score: 0.9586 - val_f1-score: 0.9774 - val_precision_3: 0.9915 - val_auc_3: 0.9959
# Epoch 24/100
# 35/35 [==============================] - 21s 612ms/step - loss: 0.3490 - iou_score: 0.9555 - f1-score: 0.9633 - precision_3: 0.9968 - auc_3: 0.9994 - val_loss: 0.3651 - val_iou_score: 0.9272 - val_f1-score: 0.9453 - val_precision_3: 0.9919 - val_auc_3: 0.9961
# Epoch 25/100
# 35/35 [==============================] - 21s 607ms/step - loss: 0.3481 - iou_score: 0.9755 - f1-score: 0.9828 - precision_3: 0.9970 - auc_3: 0.9995 - val_loss: 0.3653 - val_iou_score: 0.9597 - val_f1-score: 0.9782 - val_precision_3: 0.9917 - val_auc_3: 0.9960
# Epoch 26/100
# 35/35 [==============================] - 21s 602ms/step - loss: 0.3479 - iou_score: 0.9656 - f1-score: 0.9731 - precision_3: 0.9968 - auc_3: 0.9994 - val_loss: 0.3646 - val_iou_score: 0.9601 - val_f1-score: 0.9784 - val_precision_3: 0.9916 - val_auc_3: 0.9958
# Epoch 27/100
# 35/35 [==============================] - 21s 608ms/step - loss: 0.3469 - iou_score: 0.9762 - f1-score: 0.9832 - precision_3: 0.9971 - auc_3: 0.9995 - val_loss: 0.3651 - val_iou_score: 0.9582 - val_f1-score: 0.9773 - val_precision_3: 0.9914 - val_auc_3: 0.9959
# Epoch 28/100
# 35/35 [==============================] - 21s 612ms/step - loss: 0.3463 - iou_score: 0.9767 - f1-score: 0.9835 - precision_3: 0.9971 - auc_3: 0.9994 - val_loss: 0.3641 - val_iou_score: 0.9600 - val_f1-score: 0.9783 - val_precision_3: 0.9916 - val_auc_3: 0.9956
# Epoch 29/100
# 35/35 [==============================] - 21s 600ms/step - loss: 0.3460 - iou_score: 0.9863 - f1-score: 0.9930 - precision_3: 0.9971 - auc_3: 0.9995 - val_loss: 0.3636 - val_iou_score: 0.9479 - val_f1-score: 0.9665 - val_precision_3: 0.9917 - val_auc_3: 0.9961
# Epoch 30/100
# 35/35 [==============================] - 21s 609ms/step - loss: 0.3456 - iou_score: 0.9865 - f1-score: 0.9931 - precision_3: 0.9974 - auc_3: 0.9996 - val_loss: 0.3639 - val_iou_score: 0.9591 - val_f1-score: 0.9779 - val_precision_3: 0.9913 - val_auc_3: 0.9956
# Epoch 31/100
# 35/35 [==============================] - 21s 597ms/step - loss: 0.3459 - iou_score: 0.9856 - f1-score: 0.9926 - precision_3: 0.9970 - auc_3: 0.9995 - val_loss: 0.3629 - val_iou_score: 0.9598 - val_f1-score: 0.9783 - val_precision_3: 0.9914 - val_auc_3: 0.9957
# Epoch 32/100
# 35/35 [==============================] - 21s 594ms/step - loss: 0.3451 - iou_score: 0.9865 - f1-score: 0.9931 - precision_3: 0.9972 - auc_3: 0.9995 - val_loss: 0.3622 - val_iou_score: 0.9605 - val_f1-score: 0.9788 - val_precision_3: 0.9916 - val_auc_3: 0.9959
# Epoch 33/100
# 35/35 [==============================] - 21s 608ms/step - loss: 0.3446 - iou_score: 0.9871 - f1-score: 0.9934 - precision_3: 0.9973 - auc_3: 0.9996 - val_loss: 0.3627 - val_iou_score: 0.9597 - val_f1-score: 0.9782 - val_precision_3: 0.9915 - val_auc_3: 0.9957
# Epoch 34/100
# 35/35 [==============================] - 21s 598ms/step - loss: 0.3444 - iou_score: 0.9870 - f1-score: 0.9934 - precision_3: 0.9973 - auc_3: 0.9996 - val_loss: 0.3627 - val_iou_score: 0.9591 - val_f1-score: 0.9778 - val_precision_3: 0.9914 - val_auc_3: 0.9959
# Epoch 35/100
# 35/35 [==============================] - 21s 604ms/step - loss: 0.3435 - iou_score: 0.9882 - f1-score: 0.9940 - precision_3: 0.9975 - auc_3: 0.9997 - val_loss: 0.3630 - val_iou_score: 0.9592 - val_f1-score: 0.9778 - val_precision_3: 0.9913 - val_auc_3: 0.9957
# Epoch 36/100
# 35/35 [==============================] - 21s 598ms/step - loss: 0.3431 - iou_score: 0.9887 - f1-score: 0.9942 - precision_3: 0.9976 - auc_3: 0.9997 - val_loss: 0.3610 - val_iou_score: 0.9614 - val_f1-score: 0.9792 - val_precision_3: 0.9918 - val_auc_3: 0.9961
# Epoch 37/100
# 35/35 [==============================] - 22s 614ms/step - loss: 0.3428 - iou_score: 0.9890 - f1-score: 0.9944 - precision_3: 0.9977 - auc_3: 0.9997 - val_loss: 0.3630 - val_iou_score: 0.9584 - val_f1-score: 0.9774 - val_precision_3: 0.9913 - val_auc_3: 0.9958
# Epoch 38/100
# 35/35 [==============================] - 21s 608ms/step - loss: 0.3427 - iou_score: 0.9889 - f1-score: 0.9944 - precision_3: 0.9977 - auc_3: 0.9997 - val_loss: 0.3622 - val_iou_score: 0.9592 - val_f1-score: 0.9779 - val_precision_3: 0.9914 - val_auc_3: 0.9959
# Epoch 39/100
# 35/35 [==============================] - 21s 605ms/step - loss: 0.3422 - iou_score: 0.9897 - f1-score: 0.9948 - precision_3: 0.9978 - auc_3: 0.9997 - val_loss: 0.3622 - val_iou_score: 0.9590 - val_f1-score: 0.9777 - val_precision_3: 0.9914 - val_auc_3: 0.9959
# Epoch 40/100
# 35/35 [==============================] - 22s 626ms/step - loss: 0.3418 - iou_score: 0.9902 - f1-score: 0.9950 - precision_3: 0.9979 - auc_3: 0.9998 - val_loss: 0.3610 - val_iou_score: 0.9610 - val_f1-score: 0.9789 - val_precision_3: 0.9915 - val_auc_3: 0.9959
# Epoch 41/100
# 35/35 [==============================] - 21s 613ms/step - loss: 0.3416 - iou_score: 0.9901 - f1-score: 0.9950 - precision_3: 0.9979 - auc_3: 0.9998 - val_loss: 0.3625 - val_iou_score: 0.9586 - val_f1-score: 0.9775 - val_precision_3: 0.9912 - val_auc_3: 0.9957
# Epoch 42/100
# 35/35 [==============================] - 22s 622ms/step - loss: 0.3415 - iou_score: 0.9902 - f1-score: 0.9950 - precision_3: 0.9979 - auc_3: 0.9998 - val_loss: 0.3626 - val_iou_score: 0.9582 - val_f1-score: 0.9774 - val_precision_3: 0.9911 - val_auc_3: 0.9956
# Epoch 43/100
# 35/35 [==============================] - 21s 605ms/step - loss: 0.3412 - iou_score: 0.9906 - f1-score: 0.9952 - precision_3: 0.9980 - auc_3: 0.9998 - val_loss: 0.3617 - val_iou_score: 0.9594 - val_f1-score: 0.9780 - val_precision_3: 0.9913 - val_auc_3: 0.9957
# Epoch 44/100
# 35/35 [==============================] - 21s 606ms/step - loss: 0.3410 - iou_score: 0.9906 - f1-score: 0.9953 - precision_3: 0.9980 - auc_3: 0.9998 - val_loss: 0.3602 - val_iou_score: 0.9613 - val_f1-score: 0.9792 - val_precision_3: 0.9917 - val_auc_3: 0.9959
# Epoch 45/100
# 35/35 [==============================] - 21s 607ms/step - loss: 0.3407 - iou_score: 0.9911 - f1-score: 0.9955 - precision_3: 0.9981 - auc_3: 0.9998 - val_loss: 0.3618 - val_iou_score: 0.9589 - val_f1-score: 0.9778 - val_precision_3: 0.9912 - val_auc_3: 0.9956
# Epoch 46/100
# 35/35 [==============================] - 21s 602ms/step - loss: 0.3409 - iou_score: 0.9905 - f1-score: 0.9952 - precision_3: 0.9980 - auc_3: 0.9998 - val_loss: 0.3616 - val_iou_score: 0.9594 - val_f1-score: 0.9780 - val_precision_3: 0.9914 - val_auc_3: 0.9957
# Epoch 47/100
# 35/35 [==============================] - 21s 600ms/step - loss: 0.3410 - iou_score: 0.9903 - f1-score: 0.9951 - precision_3: 0.9980 - auc_3: 0.9998 - val_loss: 0.3618 - val_iou_score: 0.9588 - val_f1-score: 0.9777 - val_precision_3: 0.9911 - val_auc_3: 0.9956
# Epoch 48/100
# 35/35 [==============================] - 22s 617ms/step - loss: 0.3408 - iou_score: 0.9906 - f1-score: 0.9952 - precision_3: 0.9980 - auc_3: 0.9998 - val_loss: 0.3611 - val_iou_score: 0.9599 - val_f1-score: 0.9782 - val_precision_3: 0.9915 - val_auc_3: 0.9957
# Epoch 49/100
# 35/35 [==============================] - 22s 626ms/step - loss: 0.3406 - iou_score: 0.9907 - f1-score: 0.9953 - precision_3: 0.9981 - auc_3: 0.9998 - val_loss: 0.3620 - val_iou_score: 0.9587 - val_f1-score: 0.9776 - val_precision_3: 0.9912 - val_auc_3: 0.9955
# Epoch 50/100
# 35/35 [==============================] - 21s 606ms/step - loss: 0.3406 - iou_score: 0.9907 - f1-score: 0.9953 - precision_3: 0.9981 - auc_3: 0.9998 - val_loss: 0.3618 - val_iou_score: 0.9587 - val_f1-score: 0.9776 - val_precision_3: 0.9912 - val_auc_3: 0.9957
# Epoch 51/100
# 35/35 [==============================] - 21s 602ms/step - loss: 0.3402 - iou_score: 0.9912 - f1-score: 0.9955 - precision_3: 0.9981 - auc_3: 0.9998 - val_loss: 0.3610 - val_iou_score: 0.9597 - val_f1-score: 0.9782 - val_precision_3: 0.9914 - val_auc_3: 0.9959
# Epoch 52/100
# 35/35 [==============================] - 21s 612ms/step - loss: 0.3398 - iou_score: 0.9919 - f1-score: 0.9959 - precision_3: 0.9983 - auc_3: 0.9998 - val_loss: 0.3611 - val_iou_score: 0.9598 - val_f1-score: 0.9782 - val_precision_3: 0.9914 - val_auc_3: 0.9958
# Epoch 53/100
# 35/35 [==============================] - 21s 606ms/step - loss: 0.3397 - iou_score: 0.9921 - f1-score: 0.9960 - precision_3: 0.9983 - auc_3: 0.9998 - val_loss: 0.3619 - val_iou_score: 0.9584 - val_f1-score: 0.9775 - val_precision_3: 0.9912 - val_auc_3: 0.9957
# Epoch 54/100
# 35/35 [==============================] - 21s 607ms/step - loss: 0.3394 - iou_score: 0.9924 - f1-score: 0.9962 - precision_3: 0.9983 - auc_3: 0.9998 - val_loss: 0.3603 - val_iou_score: 0.9609 - val_f1-score: 0.9789 - val_precision_3: 0.9916 - val_auc_3: 0.9959
# Epoch 55/100
# 35/35 [==============================] - 22s 620ms/step - loss: 0.3390 - iou_score: 0.9933 - f1-score: 0.9966 - precision_3: 0.9986 - auc_3: 0.9998 - val_loss: 0.3603 - val_iou_score: 0.9609 - val_f1-score: 0.9789 - val_precision_3: 0.9916 - val_auc_3: 0.9959
# Epoch 56/100
# 35/35 [==============================] - 21s 601ms/step - loss: 0.3386 - iou_score: 0.9942 - f1-score: 0.9971 - precision_3: 0.9987 - auc_3: 0.9999 - val_loss: 0.3603 - val_iou_score: 0.9609 - val_f1-score: 0.9789 - val_precision_3: 0.9916 - val_auc_3: 0.9959
# Epoch 57/100
# 35/35 [==============================] - 21s 607ms/step - loss: 0.3383 - iou_score: 0.9947 - f1-score: 0.9973 - precision_3: 0.9989 - auc_3: 0.9999 - val_loss: 0.3604 - val_iou_score: 0.9607 - val_f1-score: 0.9787 - val_precision_3: 0.9915 - val_auc_3: 0.9959
# Epoch 58/100
# 35/35 [==============================] - 22s 615ms/step - loss: 0.3382 - iou_score: 0.9950 - f1-score: 0.9975 - precision_3: 0.9989 - auc_3: 0.9999 - val_loss: 0.3606 - val_iou_score: 0.9605 - val_f1-score: 0.9787 - val_precision_3: 0.9915 - val_auc_3: 0.9959
# Epoch 59/100
# 35/35 [==============================] - 22s 621ms/step - loss: 0.3381 - iou_score: 0.9953 - f1-score: 0.9976 - precision_3: 0.9990 - auc_3: 0.9999 - val_loss: 0.3606 - val_iou_score: 0.9606 - val_f1-score: 0.9787 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 60/100
# 35/35 [==============================] - 22s 618ms/step - loss: 0.3380 - iou_score: 0.9955 - f1-score: 0.9977 - precision_3: 0.9990 - auc_3: 0.9999 - val_loss: 0.3606 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 61/100
# 35/35 [==============================] - 22s 615ms/step - loss: 0.3379 - iou_score: 0.9956 - f1-score: 0.9978 - precision_3: 0.9990 - auc_3: 0.9999 - val_loss: 0.3607 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 62/100
# 35/35 [==============================] - 22s 617ms/step - loss: 0.3379 - iou_score: 0.9957 - f1-score: 0.9978 - precision_3: 0.9990 - auc_3: 0.9999 - val_loss: 0.3607 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 63/100
# 35/35 [==============================] - 22s 622ms/step - loss: 0.3378 - iou_score: 0.9958 - f1-score: 0.9979 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3607 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 64/100
# 35/35 [==============================] - 21s 613ms/step - loss: 0.3378 - iou_score: 0.9959 - f1-score: 0.9979 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3607 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 65/100
# 35/35 [==============================] - 22s 617ms/step - loss: 0.3378 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3607 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 66/100
# 35/35 [==============================] - 21s 604ms/step - loss: 0.3378 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3607 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 67/100
# 35/35 [==============================] - 21s 610ms/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3607 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 68/100
# 35/35 [==============================] - 21s 599ms/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3607 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 69/100
# 35/35 [==============================] - 21s 607ms/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9604 - val_f1-score: 0.9785 - val_precision_3: 0.9914 - val_auc_3: 0.9958
# Epoch 70/100
# 35/35 [==============================] - 21s 605ms/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3607 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 71/100
# 35/35 [==============================] - 21s 593ms/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3607 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 72/100
# 35/35 [==============================] - 21s 598ms/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3607 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 73/100
# 35/35 [==============================] - 21s 605ms/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9604 - val_f1-score: 0.9785 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 74/100
# 35/35 [==============================] - 21s 614ms/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9604 - val_f1-score: 0.9785 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 75/100
# 35/35 [==============================] - 21s 610ms/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3607 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 76/100
# 35/35 [==============================] - 21s 595ms/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 77/100
# 35/35 [==============================] - 21s 608ms/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3607 - val_iou_score: 0.9605 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 78/100
# 35/35 [==============================] - 21s 608ms/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 79/100
# 35/35 [==============================] - 21s 605ms/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 80/100
# 35/35 [==============================] - 21s 611ms/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9914 - val_auc_3: 0.9958
# Epoch 81/100
# 35/35 [==============================] - 21s 602ms/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9914 - val_auc_3: 0.9958
# Epoch 82/100
# 35/35 [==============================] - 22s 616ms/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9914 - val_auc_3: 0.9958
# Epoch 83/100
# 35/35 [==============================] - 21s 601ms/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9914 - val_auc_3: 0.9958
# Epoch 84/100
# 35/35 [==============================] - 21s 596ms/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9603 - val_f1-score: 0.9785 - val_precision_3: 0.9914 - val_auc_3: 0.9958
# Epoch 85/100
# 35/35 [==============================] - 72s 2s/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9603 - val_f1-score: 0.9785 - val_precision_3: 0.9914 - val_auc_3: 0.9958
# Epoch 86/100
# 35/35 [==============================] - 83s 2s/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9603 - val_f1-score: 0.9785 - val_precision_3: 0.9914 - val_auc_3: 0.9958
# Epoch 87/100
# 35/35 [==============================] - 85s 2s/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9603 - val_f1-score: 0.9785 - val_precision_3: 0.9914 - val_auc_3: 0.9958
# Epoch 88/100
# 35/35 [==============================] - 77s 2s/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9603 - val_f1-score: 0.9785 - val_precision_3: 0.9914 - val_auc_3: 0.9958
# Epoch 89/100
# 35/35 [==============================] - 78s 2s/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9604 - val_f1-score: 0.9785 - val_precision_3: 0.9914 - val_auc_3: 0.9958
# Epoch 90/100
# 35/35 [==============================] - 80s 2s/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9914 - val_auc_3: 0.9958
# Epoch 91/100
# 35/35 [==============================] - 73s 2s/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3607 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 92/100
# 35/35 [==============================] - 77s 2s/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 93/100
# 35/35 [==============================] - 80s 2s/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 94/100
# 35/35 [==============================] - 78s 2s/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 95/100
# 35/35 [==============================] - 84s 2s/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3607 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 96/100
# 35/35 [==============================] - 83s 2s/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 97/100
# 35/35 [==============================] - 77s 2s/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 98/100
# 35/35 [==============================] - 73s 2s/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9604 - val_f1-score: 0.9786 - val_precision_3: 0.9915 - val_auc_3: 0.9958
# Epoch 99/100
# 35/35 [==============================] - 75s 2s/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9604 - val_f1-score: 0.9785 - val_precision_3: 0.9914 - val_auc_3: 0.9958
# Epoch 100/100
# 35/35 [==============================] - 80s 2s/step - loss: 0.3377 - iou_score: 0.9960 - f1-score: 0.9980 - precision_3: 0.9991 - auc_3: 0.9999 - val_loss: 0.3608 - val_iou_score: 0.9604 - val_f1-score: 0.9785 - val_precision_3: 0.9914 - val_auc_3: 0.9958

# %%
# Plot training & validation iou_score values
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['f1-score'])
plt.plot(history.history['val_f1-score'])
plt.title('Model f1 Score')
plt.ylabel('f1 Score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['auc_3'])
plt.plot(history.history['val_auc_3'])
plt.title('Model AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['precision_3'])
plt.plot(history.history['val_precision_3'])
plt.title('Model Precision')
plt.ylabel('Precision')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
n = 5

for i in range(n):
    
    image, gt_mask = valid_dataset[i]
    image = np.expand_dims(image, axis=0)
    pr_mask = model.predict(image).round()
    
    visualize(
        image=denormalize(image.squeeze()),
        gt_mask=gt_mask[..., 1].squeeze(),
        pr_mask=pr_mask[..., 1].squeeze(),
    )

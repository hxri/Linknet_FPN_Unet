# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import tensorflow as tf
import cv2
import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
DATA_DIR = './dataset2/'

# %%
x_train_dir = os.path.join(DATA_DIR, 'train_images')
y_train_dir = os.path.join(DATA_DIR, 'train_annotations')

x_valid_dir = os.path.join(DATA_DIR, 'val_images')
y_valid_dir = os.path.join(DATA_DIR, 'val_annotations')

# %% [markdown]
# ## Dataloader

# %%
# helper function for data visualization
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()
    
# helper function for data visualization    
def denormalize(x):
    """Scale image to range 0..1 for correct plot"""
    x_max = np.percentile(x, 98)
    x_min = np.percentile(x, 2)    
    x = (x - x_min) / (x_max - x_min)
    x = x.clip(0, 1)
    return x
    

# classes for data loading and preprocessing
class Dataset:
    """CamVid Dataset. Read images, apply augmentation and preprocessing transformations.
    
    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing 
            (e.g. noralization, shape manipulation, etc.)
    
    """
    
    CLASSES = ['background', 'blob']
    
    def __init__(
            self, 
            images_dir, 
            masks_dir, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
    ):
        self.ids = os.listdir(images_dir)
        self.images_fps = [os.path.join(images_dir, image_id) for image_id in self.ids]
        self.masks_fps = [os.path.join(masks_dir, image_id) for image_id in self.ids]
        
        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        # read data
        image = cv2.imread(self.images_fps[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.masks_fps[i], 0)
        
        # extract certain classes from mask (e.g. cars)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1).astype('float')
        
        # add background if mask is not binary
        if mask.shape[-1] != 1:
            background = 1 - mask.sum(axis=-1, keepdims=True)
            mask = np.concatenate((mask, background), axis=-1)
        
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
            
        return image, mask
        
    def __len__(self):
        return len(self.ids)
    
    
class Dataloder(keras.utils.Sequence):
    """Load data from dataset and form batches
    
    Args:
        dataset: instance of Dataset class for image loading and preprocessing.
        batch_size: Integet number of images in batch.
        shuffle: Boolean, if `True` shuffle image indexes each epoch.
    """
    
    def __init__(self, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(dataset))

        self.on_epoch_end()

    def __getitem__(self, i):
        
        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        data = []
        for j in range(start, stop):
            data.append(self.dataset[j])
        
        # transpose list of lists
        batch = [np.stack(samples, axis=0) for samples in zip(*data)]
        
        return (batch[0],batch[1])
    
    def __len__(self):
        """Denotes the number of batches per epoch"""
        return len(self.indexes) // self.batch_size
    
    def on_epoch_end(self):
        """Callback function to shuffle indexes each epoch"""
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

# %%
# Lets look at data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['background', 'blob'])

image, mask = dataset[5] # get some sample
visualize(
    image=image, 
    background=mask[..., 0].squeeze(),
    blob=mask[..., 1].squeeze(),
)

# %% [markdown]
# ## Augmentation

# %%
import albumentations as A

# %%
def round_clip_0_1(x, **kwargs):
    return x.round().clip(0, 1)

# define heavy augmentations
def get_training_augmentation():
    train_transform = [

        A.Resize (320, 480, interpolation=1, always_apply=True, p=1),
    ]
    return A.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        A.PadIfNeeded(384, 480, always_apply=True)
    ]
    return A.Compose(test_transform)

def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        A.Lambda(image=preprocessing_fn),
    ]
    return A.Compose(_transform)

# %%
# Lets look at augmented data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['background', 'blob'], augmentation=get_training_augmentation())

image, mask = dataset[12] # get some sample
visualize(
    image=image, 
    background=mask[..., 0].squeeze(),
    blob=mask[..., 1].squeeze(),
)

# %% [markdown]
# ## Model

# %%
# %env SM_FRAMEWORK=tf.keras

import segmentation_models as sm
# Out:
# env: SM_FRAMEWORK=tf.keras
# Segmentation Models: using `tf.keras` framework.

# %%
BACKBONE = 'vgg16'
BATCH_SIZE = 2
CLASSES = ['background', 'blob']
LR = 0.0001
EPOCHS = 5

preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
# define network parameters
n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
activation = 'sigmoid' if n_classes == 1 else 'softmax'

def build_model_func():
    #create model
    model = sm.FPN(BACKBONE, classes=n_classes, activation=activation)

    # define optomizer
    optim = keras.optimizers.Adam(LR)

    # Segmentation models losses can be combined together by '+' and scaled by integer or float factor
    dice_loss = sm.losses.DiceLoss()
    focal_loss = sm.losses.BinaryFocalLoss() if n_classes == 1 else sm.losses.CategoricalFocalLoss()
    total_loss = dice_loss + (1 * focal_loss)

    # actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
    # total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss 

    metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5), tf.keras.metrics.Precision(), tf.keras.metrics.AUC()]

    # compile keras model with defined optimozer, loss and metrics
    model.compile(optim, total_loss, metrics)
    return model

# %%
# Dataset for train images
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

# Dataset for validation images
valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

train_dataloader = Dataloder(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_dataloader = Dataloder(valid_dataset, batch_size=1, shuffle=False)

# check shapes for errors
assert train_dataloader[0][0].shape == (BATCH_SIZE, 320, 480, 3)
assert train_dataloader[0][1].shape == (BATCH_SIZE, 320, 480, n_classes)



# define callbacks for learning rate scheduling and best checkpoints saving
filepath = "checkpoints/saved_weights.{epoch:02d}.hdf5"
callbacks = [
    keras.callbacks.ModelCheckpoint(
            filepath, 
            save_weights_only=True, 
            save_best_only=False, 
            mode="min",
            verbose=0,
            save_freq='epoch',
        ),
    keras.callbacks.ReduceLROnPlateau(),
]

# %%
print(valid_dataloader[0][0].shape)
# Out:
# (1, 320, 480, 3)

# %%
checkpoint_path = "checkpoints/saved_weights.03.hdf5"
#checkpoint_path = None
from tensorflow.keras.models import model_from_json

def get_init_epoch(checkpoint_path):
    return int(checkpoint_path.split('.')[1])

# Load checkpoint:
if checkpoint_path is not None:
    # Load model:
    model = build_model_func()
    model.load_weights(checkpoint_path)
    # Finding the epoch index from which we are resuming
    initial_epoch = get_init_epoch(checkpoint_path)
    # Calculating the correct value of count
    count = initial_epoch*BATCH_SIZE
    # Update the value of count in callback instance
    callbacks[1].count = count
else:
    model = build_model_func()
    initial_epoch = 0

# train model
history = model.fit(
    train_dataloader, 
    steps_per_epoch=len(train_dataloader), 
    epochs=100, 
    callbacks=callbacks,
    initial_epoch=initial_epoch,
    validation_data=valid_dataloader, 
    validation_steps=len(valid_dataloader),
)
# Out:
# Epoch 4/100
# 35/35 [==============================] - 19s 552ms/step - loss: 0.3605 - iou_score: 0.9619 - f1-score: 0.9795 - precision_1: 0.9912 - auc_1: 0.9984 - val_loss: 0.3650 - val_iou_score: 0.9625 - val_f1-score: 0.9798 - val_precision_1: 0.9914 - val_auc_1: 0.9972
# Epoch 5/100
# 35/35 [==============================] - 18s 520ms/step - loss: 0.3589 - iou_score: 0.9615 - f1-score: 0.9793 - precision_1: 0.9917 - auc_1: 0.9984 - val_loss: 0.3603 - val_iou_score: 0.9626 - val_f1-score: 0.9799 - val_precision_1: 0.9920 - val_auc_1: 0.9974
# Epoch 6/100
# 35/35 [==============================] - 18s 521ms/step - loss: 0.3536 - iou_score: 0.9694 - f1-score: 0.9840 - precision_1: 0.9935 - auc_1: 0.9988 - val_loss: 0.3581 - val_iou_score: 0.9642 - val_f1-score: 0.9808 - val_precision_1: 0.9920 - val_auc_1: 0.9976
# Epoch 7/100
# 35/35 [==============================] - 18s 513ms/step - loss: 0.3509 - iou_score: 0.9727 - f1-score: 0.9858 - precision_1: 0.9938 - auc_1: 0.9990 - val_loss: 0.3561 - val_iou_score: 0.9654 - val_f1-score: 0.9814 - val_precision_1: 0.9923 - val_auc_1: 0.9973
# Epoch 8/100
# 35/35 [==============================] - 18s 513ms/step - loss: 0.3514 - iou_score: 0.9716 - f1-score: 0.9852 - precision_1: 0.9937 - auc_1: 0.9988 - val_loss: 0.3551 - val_iou_score: 0.9663 - val_f1-score: 0.9820 - val_precision_1: 0.9924 - val_auc_1: 0.9979
# Epoch 9/100
# 35/35 [==============================] - 18s 512ms/step - loss: 0.3514 - iou_score: 0.9711 - f1-score: 0.9849 - precision_1: 0.9940 - auc_1: 0.9990 - val_loss: 0.3708 - val_iou_score: 0.9448 - val_f1-score: 0.9686 - val_precision_1: 0.9873 - val_auc_1: 0.9957
# Epoch 10/100
# 35/35 [==============================] - 18s 512ms/step - loss: 0.3498 - iou_score: 0.9744 - f1-score: 0.9867 - precision_1: 0.9943 - auc_1: 0.9990 - val_loss: 0.3580 - val_iou_score: 0.9626 - val_f1-score: 0.9800 - val_precision_1: 0.9915 - val_auc_1: 0.9976
# Epoch 11/100
# 35/35 [==============================] - 18s 512ms/step - loss: 0.3473 - iou_score: 0.9777 - f1-score: 0.9885 - precision_1: 0.9951 - auc_1: 0.9991 - val_loss: 0.3559 - val_iou_score: 0.9655 - val_f1-score: 0.9816 - val_precision_1: 0.9924 - val_auc_1: 0.9976
# Epoch 12/100
# 35/35 [==============================] - 18s 512ms/step - loss: 0.3459 - iou_score: 0.9795 - f1-score: 0.9894 - precision_1: 0.9955 - auc_1: 0.9993 - val_loss: 0.3556 - val_iou_score: 0.9657 - val_f1-score: 0.9816 - val_precision_1: 0.9924 - val_auc_1: 0.9977
# Epoch 13/100
# 35/35 [==============================] - 18s 511ms/step - loss: 0.3454 - iou_score: 0.9804 - f1-score: 0.9900 - precision_1: 0.9957 - auc_1: 0.9993 - val_loss: 0.3537 - val_iou_score: 0.9683 - val_f1-score: 0.9832 - val_precision_1: 0.9929 - val_auc_1: 0.9983
# Epoch 14/100
# 35/35 [==============================] - 18s 513ms/step - loss: 0.3454 - iou_score: 0.9804 - f1-score: 0.9900 - precision_1: 0.9957 - auc_1: 0.9993 - val_loss: 0.3544 - val_iou_score: 0.9672 - val_f1-score: 0.9825 - val_precision_1: 0.9927 - val_auc_1: 0.9980
# Epoch 15/100
# 35/35 [==============================] - 18s 512ms/step - loss: 0.3445 - iou_score: 0.9816 - f1-score: 0.9906 - precision_1: 0.9959 - auc_1: 0.9994 - val_loss: 0.3555 - val_iou_score: 0.9658 - val_f1-score: 0.9818 - val_precision_1: 0.9924 - val_auc_1: 0.9979
# Epoch 16/100
# 35/35 [==============================] - 18s 518ms/step - loss: 0.3439 - iou_score: 0.9828 - f1-score: 0.9912 - precision_1: 0.9962 - auc_1: 0.9995 - val_loss: 0.3556 - val_iou_score: 0.9659 - val_f1-score: 0.9818 - val_precision_1: 0.9925 - val_auc_1: 0.9978
# Epoch 17/100
# 35/35 [==============================] - 18s 512ms/step - loss: 0.3432 - iou_score: 0.9840 - f1-score: 0.9918 - precision_1: 0.9964 - auc_1: 0.9995 - val_loss: 0.3559 - val_iou_score: 0.9653 - val_f1-score: 0.9814 - val_precision_1: 0.9923 - val_auc_1: 0.9978
# Epoch 18/100
# 35/35 [==============================] - 18s 511ms/step - loss: 0.3430 - iou_score: 0.9843 - f1-score: 0.9920 - precision_1: 0.9965 - auc_1: 0.9995 - val_loss: 0.3556 - val_iou_score: 0.9660 - val_f1-score: 0.9818 - val_precision_1: 0.9925 - val_auc_1: 0.9975
# Epoch 19/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3426 - iou_score: 0.9850 - f1-score: 0.9924 - precision_1: 0.9967 - auc_1: 0.9996 - val_loss: 0.3551 - val_iou_score: 0.9668 - val_f1-score: 0.9824 - val_precision_1: 0.9927 - val_auc_1: 0.9975
# Epoch 20/100
# 35/35 [==============================] - 18s 512ms/step - loss: 0.3424 - iou_score: 0.9852 - f1-score: 0.9924 - precision_1: 0.9967 - auc_1: 0.9996 - val_loss: 0.3561 - val_iou_score: 0.9653 - val_f1-score: 0.9814 - val_precision_1: 0.9924 - val_auc_1: 0.9975
# Epoch 21/100
# 35/35 [==============================] - 18s 512ms/step - loss: 0.3427 - iou_score: 0.9847 - f1-score: 0.9922 - precision_1: 0.9967 - auc_1: 0.9995 - val_loss: 0.3563 - val_iou_score: 0.9650 - val_f1-score: 0.9813 - val_precision_1: 0.9924 - val_auc_1: 0.9975
# Epoch 22/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3417 - iou_score: 0.9865 - f1-score: 0.9931 - precision_1: 0.9970 - auc_1: 0.9996 - val_loss: 0.3554 - val_iou_score: 0.9666 - val_f1-score: 0.9822 - val_precision_1: 0.9926 - val_auc_1: 0.9974
# Epoch 23/100
# 35/35 [==============================] - 18s 506ms/step - loss: 0.3418 - iou_score: 0.9862 - f1-score: 0.9930 - precision_1: 0.9969 - auc_1: 0.9996 - val_loss: 0.3550 - val_iou_score: 0.9668 - val_f1-score: 0.9823 - val_precision_1: 0.9926 - val_auc_1: 0.9975
# Epoch 24/100
# 35/35 [==============================] - 18s 503ms/step - loss: 0.3408 - iou_score: 0.9879 - f1-score: 0.9939 - precision_1: 0.9973 - auc_1: 0.9997 - val_loss: 0.3550 - val_iou_score: 0.9670 - val_f1-score: 0.9824 - val_precision_1: 0.9927 - val_auc_1: 0.9974
# Epoch 25/100
# 35/35 [==============================] - 18s 502ms/step - loss: 0.3400 - iou_score: 0.9895 - f1-score: 0.9947 - precision_1: 0.9976 - auc_1: 0.9998 - val_loss: 0.3553 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9974
# Epoch 26/100
# 35/35 [==============================] - 18s 501ms/step - loss: 0.3397 - iou_score: 0.9902 - f1-score: 0.9950 - precision_1: 0.9977 - auc_1: 0.9998 - val_loss: 0.3549 - val_iou_score: 0.9674 - val_f1-score: 0.9827 - val_precision_1: 0.9928 - val_auc_1: 0.9974
# Epoch 27/100
# 35/35 [==============================] - 18s 502ms/step - loss: 0.3394 - iou_score: 0.9907 - f1-score: 0.9953 - precision_1: 0.9978 - auc_1: 0.9998 - val_loss: 0.3553 - val_iou_score: 0.9669 - val_f1-score: 0.9824 - val_precision_1: 0.9927 - val_auc_1: 0.9974
# Epoch 28/100
# 35/35 [==============================] - 18s 503ms/step - loss: 0.3393 - iou_score: 0.9909 - f1-score: 0.9954 - precision_1: 0.9979 - auc_1: 0.9998 - val_loss: 0.3552 - val_iou_score: 0.9670 - val_f1-score: 0.9824 - val_precision_1: 0.9927 - val_auc_1: 0.9974
# Epoch 29/100
# 35/35 [==============================] - 18s 502ms/step - loss: 0.3391 - iou_score: 0.9913 - f1-score: 0.9956 - precision_1: 0.9980 - auc_1: 0.9998 - val_loss: 0.3554 - val_iou_score: 0.9669 - val_f1-score: 0.9824 - val_precision_1: 0.9927 - val_auc_1: 0.9973
# Epoch 30/100
# 35/35 [==============================] - 18s 503ms/step - loss: 0.3389 - iou_score: 0.9916 - f1-score: 0.9958 - precision_1: 0.9980 - auc_1: 0.9998 - val_loss: 0.3554 - val_iou_score: 0.9668 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9973
# Epoch 31/100
# 35/35 [==============================] - 18s 501ms/step - loss: 0.3388 - iou_score: 0.9919 - f1-score: 0.9959 - precision_1: 0.9981 - auc_1: 0.9998 - val_loss: 0.3553 - val_iou_score: 0.9669 - val_f1-score: 0.9824 - val_precision_1: 0.9927 - val_auc_1: 0.9973
# Epoch 32/100
# 35/35 [==============================] - 18s 502ms/step - loss: 0.3387 - iou_score: 0.9921 - f1-score: 0.9960 - precision_1: 0.9981 - auc_1: 0.9999 - val_loss: 0.3555 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9973
# Epoch 33/100
# 35/35 [==============================] - 18s 504ms/step - loss: 0.3386 - iou_score: 0.9923 - f1-score: 0.9961 - precision_1: 0.9982 - auc_1: 0.9999 - val_loss: 0.3555 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9973
# Epoch 34/100
# 35/35 [==============================] - 18s 503ms/step - loss: 0.3385 - iou_score: 0.9926 - f1-score: 0.9963 - precision_1: 0.9982 - auc_1: 0.9999 - val_loss: 0.3556 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 35/100
# 35/35 [==============================] - 18s 503ms/step - loss: 0.3384 - iou_score: 0.9926 - f1-score: 0.9963 - precision_1: 0.9982 - auc_1: 0.9999 - val_loss: 0.3556 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 36/100
# 35/35 [==============================] - 18s 503ms/step - loss: 0.3384 - iou_score: 0.9927 - f1-score: 0.9963 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3556 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 37/100
# 35/35 [==============================] - 18s 502ms/step - loss: 0.3384 - iou_score: 0.9927 - f1-score: 0.9963 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3556 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 38/100
# 35/35 [==============================] - 18s 502ms/step - loss: 0.3384 - iou_score: 0.9927 - f1-score: 0.9963 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3556 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 39/100
# 35/35 [==============================] - 18s 501ms/step - loss: 0.3384 - iou_score: 0.9928 - f1-score: 0.9963 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 40/100
# 35/35 [==============================] - 18s 503ms/step - loss: 0.3384 - iou_score: 0.9928 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 41/100
# 35/35 [==============================] - 18s 502ms/step - loss: 0.3384 - iou_score: 0.9928 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 42/100
# 35/35 [==============================] - 18s 503ms/step - loss: 0.3383 - iou_score: 0.9928 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 43/100
# 35/35 [==============================] - 18s 503ms/step - loss: 0.3383 - iou_score: 0.9928 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 44/100
# 35/35 [==============================] - 18s 501ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 45/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 46/100
# 35/35 [==============================] - 18s 503ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 47/100
# 35/35 [==============================] - 18s 504ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 48/100
# 35/35 [==============================] - 18s 503ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 49/100
# 35/35 [==============================] - 18s 504ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 50/100
# 35/35 [==============================] - 18s 504ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 51/100
# 35/35 [==============================] - 18s 503ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 52/100
# 35/35 [==============================] - 18s 504ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 53/100
# 35/35 [==============================] - 18s 503ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 54/100
# 35/35 [==============================] - 18s 503ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 55/100
# 35/35 [==============================] - 18s 502ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 56/100
# 35/35 [==============================] - 18s 501ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 57/100
# 35/35 [==============================] - 18s 502ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 58/100
# 35/35 [==============================] - 18s 505ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 59/100
# 35/35 [==============================] - 18s 508ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 60/100
# 35/35 [==============================] - 18s 511ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 61/100
# 35/35 [==============================] - 18s 508ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 62/100
# 35/35 [==============================] - 18s 508ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 63/100
# 35/35 [==============================] - 18s 511ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 64/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 65/100
# 35/35 [==============================] - 18s 507ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 66/100
# 35/35 [==============================] - 18s 511ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 67/100
# 35/35 [==============================] - 18s 511ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 68/100
# 35/35 [==============================] - 18s 508ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 69/100
# 35/35 [==============================] - 18s 505ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 70/100
# 35/35 [==============================] - 18s 504ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 71/100
# 35/35 [==============================] - 18s 501ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 72/100
# 35/35 [==============================] - 18s 503ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 73/100
# 35/35 [==============================] - 18s 508ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 74/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 75/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 76/100
# 35/35 [==============================] - 18s 507ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 77/100
# 35/35 [==============================] - 18s 504ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 78/100
# 35/35 [==============================] - 18s 502ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 79/100
# 35/35 [==============================] - 18s 502ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 80/100
# 35/35 [==============================] - 18s 504ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 81/100
# 35/35 [==============================] - 18s 502ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 82/100
# 35/35 [==============================] - 18s 502ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 83/100
# 35/35 [==============================] - 18s 505ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 84/100
# 35/35 [==============================] - 18s 502ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 85/100
# 35/35 [==============================] - 18s 502ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 86/100
# 35/35 [==============================] - 18s 503ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 87/100
# 35/35 [==============================] - 18s 503ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 88/100
# 35/35 [==============================] - 18s 501ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 89/100
# 35/35 [==============================] - 18s 502ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 90/100
# 35/35 [==============================] - 18s 502ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 91/100
# 35/35 [==============================] - 18s 502ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 92/100
# 35/35 [==============================] - 18s 502ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 93/100
# 35/35 [==============================] - 18s 504ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 94/100
# 35/35 [==============================] - 18s 502ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 95/100
# 35/35 [==============================] - 18s 502ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 96/100
# 35/35 [==============================] - 18s 503ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 97/100
# 35/35 [==============================] - 18s 501ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9667 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 98/100
# 35/35 [==============================] - 18s 500ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 99/100
# 35/35 [==============================] - 18s 501ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972
# Epoch 100/100
# 35/35 [==============================] - 18s 500ms/step - loss: 0.3383 - iou_score: 0.9929 - f1-score: 0.9964 - precision_1: 0.9983 - auc_1: 0.9999 - val_loss: 0.3557 - val_iou_score: 0.9666 - val_f1-score: 0.9823 - val_precision_1: 0.9927 - val_auc_1: 0.9972

# %%
# Plot training & validation iou_score values
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['f1-score'])
plt.plot(history.history['val_f1-score'])
plt.title('Model f1 Score')
plt.ylabel('f1 Score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['auc_1'])
plt.plot(history.history['val_auc_1'])
plt.title('Model AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['precision_1'])
plt.plot(history.history['val_precision_1'])
plt.title('Model Precision')
plt.ylabel('Precision')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
n = 5

for i in range(n):
    
    image, gt_mask = valid_dataset[i]
    image = np.expand_dims(image, axis=0)
    pr_mask = model.predict(image).round()
    
    visualize(
        image=denormalize(image.squeeze()),
        gt_mask=gt_mask[..., 1].squeeze(),
        pr_mask=pr_mask[..., 1].squeeze(),
    )

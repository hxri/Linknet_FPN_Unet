# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import tensorflow as tf
import cv2
import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
DATA_DIR = './dataset2/'

# %%
x_train_dir = os.path.join(DATA_DIR, 'train_images')
y_train_dir = os.path.join(DATA_DIR, 'train_annotations')

x_valid_dir = os.path.join(DATA_DIR, 'val_images')
y_valid_dir = os.path.join(DATA_DIR, 'val_annotations')

# %% [markdown]
# ## Dataloader

# %%
# helper function for data visualization
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()
    
# helper function for data visualization    
def denormalize(x):
    """Scale image to range 0..1 for correct plot"""
    x_max = np.percentile(x, 98)
    x_min = np.percentile(x, 2)    
    x = (x - x_min) / (x_max - x_min)
    x = x.clip(0, 1)
    return x
    

# classes for data loading and preprocessing
class Dataset:
    """CamVid Dataset. Read images, apply augmentation and preprocessing transformations.
    
    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing 
            (e.g. noralization, shape manipulation, etc.)
    
    """
    
    CLASSES = ['background', 'blob']
    
    def __init__(
            self, 
            images_dir, 
            masks_dir, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
    ):
        self.ids = os.listdir(images_dir)
        self.images_fps = [os.path.join(images_dir, image_id) for image_id in self.ids]
        self.masks_fps = [os.path.join(masks_dir, image_id) for image_id in self.ids]
        
        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        # read data
        image = cv2.imread(self.images_fps[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.masks_fps[i], 0)
        
        # extract certain classes from mask (e.g. cars)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1).astype('float')
        
        # add background if mask is not binary
        if mask.shape[-1] != 1:
            background = 1 - mask.sum(axis=-1, keepdims=True)
            mask = np.concatenate((mask, background), axis=-1)
        
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
            
        return image, mask
        
    def __len__(self):
        return len(self.ids)
    
    
class Dataloder(keras.utils.Sequence):
    """Load data from dataset and form batches
    
    Args:
        dataset: instance of Dataset class for image loading and preprocessing.
        batch_size: Integet number of images in batch.
        shuffle: Boolean, if `True` shuffle image indexes each epoch.
    """
    
    def __init__(self, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(dataset))

        self.on_epoch_end()

    def __getitem__(self, i):
        
        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        data = []
        for j in range(start, stop):
            data.append(self.dataset[j])
        
        # transpose list of lists
        batch = [np.stack(samples, axis=0) for samples in zip(*data)]
        
        return (batch[0],batch[1])
    
    def __len__(self):
        """Denotes the number of batches per epoch"""
        return len(self.indexes) // self.batch_size
    
    def on_epoch_end(self):
        """Callback function to shuffle indexes each epoch"""
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

# %%
# Lets look at data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['background', 'blob'])

image, mask = dataset[5] # get some sample
visualize(
    image=image, 
    background=mask[..., 0].squeeze(),
    blob=mask[..., 1].squeeze(),
)

# %% [markdown]
# ## Augmentation

# %%
import albumentations as A

# %%
def round_clip_0_1(x, **kwargs):
    return x.round().clip(0, 1)

# define heavy augmentations
def get_training_augmentation():
    train_transform = [

        A.Resize (320, 480, interpolation=1, always_apply=True, p=1),
    ]
    return A.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        A.PadIfNeeded(384, 480, always_apply=True)
    ]
    return A.Compose(test_transform)

def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        A.Lambda(image=preprocessing_fn),
    ]
    return A.Compose(_transform)

# %%
# Lets look at augmented data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['background', 'blob'], augmentation=get_training_augmentation())

image, mask = dataset[12] # get some sample
visualize(
    image=image, 
    background=mask[..., 0].squeeze(),
    blob=mask[..., 1].squeeze(),
)

# %% [markdown]
# ## Model

# %%
# %env SM_FRAMEWORK=tf.keras

import segmentation_models as sm
# Out:
# env: SM_FRAMEWORK=tf.keras
# Segmentation Models: using `tf.keras` framework.

# %%
BACKBONE = 'resnet101'
BATCH_SIZE = 2
CLASSES = ['background', 'blob']
LR = 0.0001
EPOCHS = 100

preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
# define network parameters
n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
activation = 'sigmoid' if n_classes == 1 else 'softmax'

def build_model_func():
    #create model
    model = sm.Unet(BACKBONE, classes=n_classes, activation=activation)

    # define optomizer
    optim = keras.optimizers.Adam(LR)

    # Segmentation models losses can be combined together by '+' and scaled by integer or float factor
    dice_loss = sm.losses.DiceLoss()
    focal_loss = sm.losses.BinaryFocalLoss() if n_classes == 1 else sm.losses.CategoricalFocalLoss()
    total_loss = dice_loss + (1 * focal_loss)

    # actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
    # total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss 

    metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5), tf.keras.metrics.Precision(), tf.keras.metrics.AUC()]

    # compile keras model with defined optimozer, loss and metrics
    model.compile(optim, total_loss, metrics)
    return model

# %%
# Dataset for train images
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

# Dataset for validation images
valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

train_dataloader = Dataloder(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_dataloader = Dataloder(valid_dataset, batch_size=1, shuffle=False)

# check shapes for errors
assert train_dataloader[0][0].shape == (BATCH_SIZE, 320, 480, 3)
assert train_dataloader[0][1].shape == (BATCH_SIZE, 320, 480, n_classes)



# define callbacks for learning rate scheduling and best checkpoints saving
filepath = "checkpoints/saved_weights.{epoch:02d}.hdf5"
callbacks = [
    keras.callbacks.ModelCheckpoint(
            filepath, 
            save_weights_only=True, 
            save_best_only=False, 
            mode="min",
            verbose=0,
            save_freq='epoch',
        ),
    keras.callbacks.ReduceLROnPlateau(),
]

# %%
print(valid_dataloader[0][0].shape)
# Out:
# (1, 320, 480, 3)

# %%
checkpoint_path = "checkpoints/"

from tensorflow.keras.models import model_from_json
import glob
import os

list_of_files = glob.glob(checkpoint_path + '/*')

if (len(list_of_files) == 0):
    latest_file = None
else:
    latest_file = max(list_of_files, key=os.path.getctime)

def get_init_epoch(checkpoint_path):
    print("Loading Weights from last Checkpoint - " + latest_file) 
    return int(latest_file.split('.')[1])
    
# Load checkpoint:
if latest_file is not None:
    # Load model:
    model = build_model_func()
    model.load_weights(latest_file)
    # Finding the epoch index from which we are resuming
    initial_epoch = get_init_epoch(checkpoint_path)
    print(initial_epoch)
    # Calculating the correct value of count
    count = initial_epoch*BATCH_SIZE
    # Update the value of count in callback instance
    callbacks[1].count = count
else:
    model = build_model_func()
    initial_epoch = 0

print("\n\n\n***********  Training Parameters  ***********\n\n")
print("Backbone = %s" %BACKBONE)
print("Batch Size = %s" %BATCH_SIZE)
print("Classes = %s" %n_classes)
print("Learning Rate = %s" %LR)
print("Epochs = %s" %EPOCHS)
print("\n\n\n")

# train model
history = model.fit(
    train_dataloader, 
    steps_per_epoch=len(train_dataloader), 
    epochs=EPOCHS, 
    callbacks=callbacks,
    initial_epoch=initial_epoch,
    validation_data=valid_dataloader, 
    validation_steps=len(valid_dataloader),
)

print("\n\n\n***********  Training Complete  ***********")
# Out:
# ***********  Training Parameters  ***********
#
#
# Backbone = resnet101
# Batch Size = 2
# Classes = 3
# Learning Rate = 0.0001
# Epochs = 100
#
#
#
#
# Epoch 1/100
# 35/35 [==============================] - 20s 583ms/step - loss: 0.7821 - iou_score: 0.1758 - f1-score: 0.2485 - precision: 0.5931 - auc: 0.7191 - val_loss: 0.8410 - val_iou_score: 0.4110 - val_f1-score: 0.4539 - val_precision: 0.2778 - val_auc: 0.4338
# Epoch 2/100
# 35/35 [==============================] - 18s 525ms/step - loss: 0.6530 - iou_score: 0.4863 - f1-score: 0.5607 - precision: 0.9642 - auc: 0.9671 - val_loss: 0.8318 - val_iou_score: 0.3298 - val_f1-score: 0.3453 - val_precision: 0.8020 - val_auc: 0.5229
# Epoch 3/100
# 35/35 [==============================] - 18s 521ms/step - loss: 0.6003 - iou_score: 0.6211 - f1-score: 0.6684 - precision: 0.9796 - auc: 0.9840 - val_loss: 0.8483 - val_iou_score: 0.1012 - val_f1-score: 0.1305 - val_precision: 0.2524 - val_auc: 0.5965
# Epoch 4/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.5633 - iou_score: 0.8088 - f1-score: 0.8427 - precision: 0.9862 - auc: 0.9904 - val_loss: 0.6992 - val_iou_score: 0.3568 - val_f1-score: 0.3901 - val_precision: 0.9058 - val_auc: 0.9492
# Epoch 5/100
# 35/35 [==============================] - 18s 519ms/step - loss: 0.5309 - iou_score: 0.8804 - f1-score: 0.9084 - precision: 0.9884 - auc: 0.9926 - val_loss: 0.6945 - val_iou_score: 0.3052 - val_f1-score: 0.3359 - val_precision: 0.8961 - val_auc: 0.9468
# Epoch 6/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.5042 - iou_score: 0.9474 - f1-score: 0.9715 - precision: 0.9903 - auc: 0.9944 - val_loss: 0.6848 - val_iou_score: 0.3178 - val_f1-score: 0.3378 - val_precision: 0.9269 - val_auc: 0.9565
# Epoch 7/100
# 35/35 [==============================] - 19s 533ms/step - loss: 0.4807 - iou_score: 0.9560 - f1-score: 0.9765 - precision: 0.9917 - auc: 0.9957 - val_loss: 0.6672 - val_iou_score: 0.3450 - val_f1-score: 0.3702 - val_precision: 0.9288 - val_auc: 0.9593
# Epoch 8/100
# 35/35 [==============================] - 18s 521ms/step - loss: 0.4600 - iou_score: 0.9525 - f1-score: 0.9702 - precision: 0.9928 - auc: 0.9968 - val_loss: 0.6608 - val_iou_score: 0.6596 - val_f1-score: 0.6890 - val_precision: 0.9228 - val_auc: 0.9555
# Epoch 9/100
# 35/35 [==============================] - 19s 530ms/step - loss: 0.4424 - iou_score: 0.9651 - f1-score: 0.9815 - precision: 0.9933 - auc: 0.9970 - val_loss: 0.6537 - val_iou_score: 0.6769 - val_f1-score: 0.7025 - val_precision: 0.9323 - val_auc: 0.9634
# Epoch 10/100
# 35/35 [==============================] - 19s 533ms/step - loss: 0.4269 - iou_score: 0.9687 - f1-score: 0.9836 - precision: 0.9939 - auc: 0.9976 - val_loss: 0.5586 - val_iou_score: 0.7592 - val_f1-score: 0.8016 - val_precision: 0.9521 - val_auc: 0.9804
# Epoch 11/100
# 35/35 [==============================] - 19s 539ms/step - loss: 0.4146 - iou_score: 0.9711 - f1-score: 0.9849 - precision: 0.9941 - auc: 0.9979 - val_loss: 0.4957 - val_iou_score: 0.8391 - val_f1-score: 0.8863 - val_precision: 0.9665 - val_auc: 0.9849
# Epoch 12/100
# 35/35 [==============================] - 19s 549ms/step - loss: 0.4056 - iou_score: 0.9699 - f1-score: 0.9843 - precision: 0.9940 - auc: 0.9978 - val_loss: 0.4555 - val_iou_score: 0.8897 - val_f1-score: 0.9282 - val_precision: 0.9775 - val_auc: 0.9876
# Epoch 13/100
# 35/35 [==============================] - 19s 532ms/step - loss: 0.3972 - iou_score: 0.9720 - f1-score: 0.9854 - precision: 0.9943 - auc: 0.9981 - val_loss: 0.4440 - val_iou_score: 0.9023 - val_f1-score: 0.9373 - val_precision: 0.9792 - val_auc: 0.9886
# Epoch 14/100
# 35/35 [==============================] - 19s 530ms/step - loss: 0.3892 - iou_score: 0.9758 - f1-score: 0.9874 - precision: 0.9952 - auc: 0.9986 - val_loss: 0.4233 - val_iou_score: 0.9271 - val_f1-score: 0.9567 - val_precision: 0.9839 - val_auc: 0.9917
# Epoch 15/100
# 35/35 [==============================] - 19s 533ms/step - loss: 0.3823 - iou_score: 0.9789 - f1-score: 0.9891 - precision: 0.9957 - auc: 0.9989 - val_loss: 0.4209 - val_iou_score: 0.9354 - val_f1-score: 0.9620 - val_precision: 0.9858 - val_auc: 0.9920
# Epoch 16/100
# 35/35 [==============================] - 19s 535ms/step - loss: 0.3772 - iou_score: 0.9803 - f1-score: 0.9899 - precision: 0.9961 - auc: 0.9990 - val_loss: 0.4161 - val_iou_score: 0.9377 - val_f1-score: 0.9635 - val_precision: 0.9865 - val_auc: 0.9922
# Epoch 17/100
# 35/35 [==============================] - 19s 533ms/step - loss: 0.3733 - iou_score: 0.9807 - f1-score: 0.9901 - precision: 0.9961 - auc: 0.9990 - val_loss: 0.4099 - val_iou_score: 0.9384 - val_f1-score: 0.9641 - val_precision: 0.9863 - val_auc: 0.9919
# Epoch 18/100
# 35/35 [==============================] - 19s 532ms/step - loss: 0.3703 - iou_score: 0.9804 - f1-score: 0.9899 - precision: 0.9960 - auc: 0.9990 - val_loss: 0.4061 - val_iou_score: 0.9368 - val_f1-score: 0.9631 - val_precision: 0.9860 - val_auc: 0.9919
# Epoch 19/100
# 35/35 [==============================] - 19s 531ms/step - loss: 0.3667 - iou_score: 0.9824 - f1-score: 0.9909 - precision: 0.9964 - auc: 0.9993 - val_loss: 0.4008 - val_iou_score: 0.9414 - val_f1-score: 0.9661 - val_precision: 0.9871 - val_auc: 0.9926
# Epoch 20/100
# 35/35 [==============================] - 19s 532ms/step - loss: 0.3631 - iou_score: 0.9850 - f1-score: 0.9923 - precision: 0.9968 - auc: 0.9995 - val_loss: 0.3965 - val_iou_score: 0.9441 - val_f1-score: 0.9679 - val_precision: 0.9873 - val_auc: 0.9923
# Epoch 21/100
# 35/35 [==============================] - 19s 555ms/step - loss: 0.3611 - iou_score: 0.9847 - f1-score: 0.9922 - precision: 0.9968 - auc: 0.9995 - val_loss: 0.3983 - val_iou_score: 0.9350 - val_f1-score: 0.9619 - val_precision: 0.9855 - val_auc: 0.9909
# Epoch 22/100
# 35/35 [==============================] - 20s 571ms/step - loss: 0.3590 - iou_score: 0.9857 - f1-score: 0.9927 - precision: 0.9970 - auc: 0.9995 - val_loss: 0.3930 - val_iou_score: 0.9419 - val_f1-score: 0.9660 - val_precision: 0.9868 - val_auc: 0.9923
# Epoch 23/100
# 35/35 [==============================] - 19s 552ms/step - loss: 0.3572 - iou_score: 0.9863 - f1-score: 0.9930 - precision: 0.9971 - auc: 0.9995 - val_loss: 0.3936 - val_iou_score: 0.9390 - val_f1-score: 0.9644 - val_precision: 0.9863 - val_auc: 0.9917
# Epoch 24/100
# 35/35 [==============================] - 19s 536ms/step - loss: 0.3559 - iou_score: 0.9863 - f1-score: 0.9930 - precision: 0.9971 - auc: 0.9995 - val_loss: 0.3903 - val_iou_score: 0.9418 - val_f1-score: 0.9662 - val_precision: 0.9868 - val_auc: 0.9921
# Epoch 25/100
# 35/35 [==============================] - 19s 534ms/step - loss: 0.3545 - iou_score: 0.9867 - f1-score: 0.9932 - precision: 0.9972 - auc: 0.9996 - val_loss: 0.3884 - val_iou_score: 0.9413 - val_f1-score: 0.9660 - val_precision: 0.9866 - val_auc: 0.9920
# Epoch 26/100
# 35/35 [==============================] - 19s 549ms/step - loss: 0.3538 - iou_score: 0.9862 - f1-score: 0.9929 - precision: 0.9971 - auc: 0.9995 - val_loss: 0.3876 - val_iou_score: 0.9414 - val_f1-score: 0.9659 - val_precision: 0.9866 - val_auc: 0.9920
# Epoch 27/100
# 35/35 [==============================] - 19s 535ms/step - loss: 0.3528 - iou_score: 0.9862 - f1-score: 0.9930 - precision: 0.9970 - auc: 0.9996 - val_loss: 0.3861 - val_iou_score: 0.9410 - val_f1-score: 0.9656 - val_precision: 0.9866 - val_auc: 0.9923
# Epoch 28/100
# 35/35 [==============================] - 19s 531ms/step - loss: 0.3511 - iou_score: 0.9879 - f1-score: 0.9939 - precision: 0.9975 - auc: 0.9997 - val_loss: 0.3856 - val_iou_score: 0.9402 - val_f1-score: 0.9656 - val_precision: 0.9865 - val_auc: 0.9919
# Epoch 29/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3498 - iou_score: 0.9890 - f1-score: 0.9944 - precision: 0.9977 - auc: 0.9998 - val_loss: 0.3819 - val_iou_score: 0.9462 - val_f1-score: 0.9692 - val_precision: 0.9876 - val_auc: 0.9926
# Epoch 30/100
# 35/35 [==============================] - 19s 530ms/step - loss: 0.3503 - iou_score: 0.9871 - f1-score: 0.9934 - precision: 0.9971 - auc: 0.9995 - val_loss: 0.3810 - val_iou_score: 0.9442 - val_f1-score: 0.9680 - val_precision: 0.9872 - val_auc: 0.9922
# Epoch 31/100
# 35/35 [==============================] - 19s 533ms/step - loss: 0.3500 - iou_score: 0.9865 - f1-score: 0.9931 - precision: 0.9970 - auc: 0.9994 - val_loss: 0.3807 - val_iou_score: 0.9444 - val_f1-score: 0.9683 - val_precision: 0.9872 - val_auc: 0.9928
# Epoch 32/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3489 - iou_score: 0.9876 - f1-score: 0.9937 - precision: 0.9973 - auc: 0.9996 - val_loss: 0.3822 - val_iou_score: 0.9416 - val_f1-score: 0.9660 - val_precision: 0.9866 - val_auc: 0.9926
# Epoch 33/100
# 35/35 [==============================] - 18s 515ms/step - loss: 0.3480 - iou_score: 0.9882 - f1-score: 0.9940 - precision: 0.9975 - auc: 0.9996 - val_loss: 0.3781 - val_iou_score: 0.9465 - val_f1-score: 0.9693 - val_precision: 0.9878 - val_auc: 0.9934
# Epoch 34/100
# 35/35 [==============================] - 19s 529ms/step - loss: 0.3476 - iou_score: 0.9880 - f1-score: 0.9939 - precision: 0.9974 - auc: 0.9996 - val_loss: 0.3800 - val_iou_score: 0.9433 - val_f1-score: 0.9676 - val_precision: 0.9872 - val_auc: 0.9929
# Epoch 35/100
# 35/35 [==============================] - 19s 532ms/step - loss: 0.3466 - iou_score: 0.9890 - f1-score: 0.9944 - precision: 0.9976 - auc: 0.9997 - val_loss: 0.3779 - val_iou_score: 0.9460 - val_f1-score: 0.9693 - val_precision: 0.9877 - val_auc: 0.9931
# Epoch 36/100
# 35/35 [==============================] - 18s 524ms/step - loss: 0.3459 - iou_score: 0.9896 - f1-score: 0.9947 - precision: 0.9978 - auc: 0.9998 - val_loss: 0.3768 - val_iou_score: 0.9464 - val_f1-score: 0.9697 - val_precision: 0.9878 - val_auc: 0.9933
# Epoch 37/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3452 - iou_score: 0.9903 - f1-score: 0.9951 - precision: 0.9980 - auc: 0.9998 - val_loss: 0.3748 - val_iou_score: 0.9488 - val_f1-score: 0.9710 - val_precision: 0.9883 - val_auc: 0.9937
# Epoch 38/100
# 35/35 [==============================] - 19s 531ms/step - loss: 0.3449 - iou_score: 0.9901 - f1-score: 0.9950 - precision: 0.9979 - auc: 0.9998 - val_loss: 0.3766 - val_iou_score: 0.9468 - val_f1-score: 0.9698 - val_precision: 0.9879 - val_auc: 0.9930
# Epoch 39/100
# 35/35 [==============================] - 19s 538ms/step - loss: 0.3449 - iou_score: 0.9895 - f1-score: 0.9947 - precision: 0.9978 - auc: 0.9998 - val_loss: 0.3785 - val_iou_score: 0.9435 - val_f1-score: 0.9676 - val_precision: 0.9871 - val_auc: 0.9927
# Epoch 40/100
# 35/35 [==============================] - 19s 531ms/step - loss: 0.3449 - iou_score: 0.9892 - f1-score: 0.9945 - precision: 0.9978 - auc: 0.9997 - val_loss: 0.3767 - val_iou_score: 0.9466 - val_f1-score: 0.9697 - val_precision: 0.9876 - val_auc: 0.9931
# Epoch 41/100
# 35/35 [==============================] - 18s 522ms/step - loss: 0.3446 - iou_score: 0.9892 - f1-score: 0.9945 - precision: 0.9977 - auc: 0.9997 - val_loss: 0.3751 - val_iou_score: 0.9472 - val_f1-score: 0.9701 - val_precision: 0.9879 - val_auc: 0.9932
# Epoch 42/100
# 35/35 [==============================] - 18s 522ms/step - loss: 0.3442 - iou_score: 0.9895 - f1-score: 0.9947 - precision: 0.9978 - auc: 0.9998 - val_loss: 0.3725 - val_iou_score: 0.9494 - val_f1-score: 0.9715 - val_precision: 0.9883 - val_auc: 0.9939
# Epoch 43/100
# 35/35 [==============================] - 18s 523ms/step - loss: 0.3429 - iou_score: 0.9914 - f1-score: 0.9957 - precision: 0.9982 - auc: 0.9998 - val_loss: 0.3759 - val_iou_score: 0.9451 - val_f1-score: 0.9687 - val_precision: 0.9875 - val_auc: 0.9932
# Epoch 44/100
# 35/35 [==============================] - 18s 521ms/step - loss: 0.3425 - iou_score: 0.9918 - f1-score: 0.9959 - precision: 0.9983 - auc: 0.9999 - val_loss: 0.3726 - val_iou_score: 0.9495 - val_f1-score: 0.9715 - val_precision: 0.9883 - val_auc: 0.9938
# Epoch 45/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3422 - iou_score: 0.9920 - f1-score: 0.9960 - precision: 0.9984 - auc: 0.9999 - val_loss: 0.3775 - val_iou_score: 0.9428 - val_f1-score: 0.9674 - val_precision: 0.9871 - val_auc: 0.9927
# Epoch 46/100
# 35/35 [==============================] - 18s 515ms/step - loss: 0.3419 - iou_score: 0.9922 - f1-score: 0.9961 - precision: 0.9984 - auc: 0.9999 - val_loss: 0.3741 - val_iou_score: 0.9471 - val_f1-score: 0.9701 - val_precision: 0.9880 - val_auc: 0.9934
# Epoch 47/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3416 - iou_score: 0.9924 - f1-score: 0.9962 - precision: 0.9984 - auc: 0.9999 - val_loss: 0.3754 - val_iou_score: 0.9455 - val_f1-score: 0.9691 - val_precision: 0.9876 - val_auc: 0.9927
# Epoch 48/100
# 35/35 [==============================] - 18s 521ms/step - loss: 0.3413 - iou_score: 0.9927 - f1-score: 0.9963 - precision: 0.9985 - auc: 0.9999 - val_loss: 0.3750 - val_iou_score: 0.9459 - val_f1-score: 0.9692 - val_precision: 0.9876 - val_auc: 0.9928
# Epoch 49/100
# 35/35 [==============================] - 18s 518ms/step - loss: 0.3410 - iou_score: 0.9930 - f1-score: 0.9964 - precision: 0.9985 - auc: 0.9999 - val_loss: 0.3748 - val_iou_score: 0.9457 - val_f1-score: 0.9691 - val_precision: 0.9877 - val_auc: 0.9927
# Epoch 50/100
# 35/35 [==============================] - 18s 523ms/step - loss: 0.3409 - iou_score: 0.9929 - f1-score: 0.9964 - precision: 0.9985 - auc: 0.9999 - val_loss: 0.3740 - val_iou_score: 0.9467 - val_f1-score: 0.9696 - val_precision: 0.9878 - val_auc: 0.9929
# Epoch 51/100
# 35/35 [==============================] - 18s 523ms/step - loss: 0.3408 - iou_score: 0.9928 - f1-score: 0.9964 - precision: 0.9985 - auc: 0.9999 - val_loss: 0.3751 - val_iou_score: 0.9447 - val_f1-score: 0.9684 - val_precision: 0.9876 - val_auc: 0.9926
# Epoch 52/100
# 35/35 [==============================] - 18s 521ms/step - loss: 0.3407 - iou_score: 0.9926 - f1-score: 0.9962 - precision: 0.9984 - auc: 0.9999 - val_loss: 0.3757 - val_iou_score: 0.9441 - val_f1-score: 0.9681 - val_precision: 0.9874 - val_auc: 0.9924
# Epoch 53/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3405 - iou_score: 0.9931 - f1-score: 0.9965 - precision: 0.9986 - auc: 0.9999 - val_loss: 0.3727 - val_iou_score: 0.9478 - val_f1-score: 0.9703 - val_precision: 0.9881 - val_auc: 0.9931
# Epoch 54/100
# 35/35 [==============================] - 18s 521ms/step - loss: 0.3398 - iou_score: 0.9945 - f1-score: 0.9972 - precision: 0.9989 - auc: 0.9999 - val_loss: 0.3728 - val_iou_score: 0.9478 - val_f1-score: 0.9703 - val_precision: 0.9881 - val_auc: 0.9931
# Epoch 55/100
# 35/35 [==============================] - 18s 524ms/step - loss: 0.3393 - iou_score: 0.9954 - f1-score: 0.9977 - precision: 0.9990 - auc: 0.9999 - val_loss: 0.3726 - val_iou_score: 0.9481 - val_f1-score: 0.9706 - val_precision: 0.9882 - val_auc: 0.9931
# Epoch 56/100
# 35/35 [==============================] - 18s 523ms/step - loss: 0.3391 - iou_score: 0.9959 - f1-score: 0.9980 - precision: 0.9992 - auc: 0.9999 - val_loss: 0.3728 - val_iou_score: 0.9479 - val_f1-score: 0.9704 - val_precision: 0.9881 - val_auc: 0.9930
# Epoch 57/100
# 35/35 [==============================] - 18s 523ms/step - loss: 0.3389 - iou_score: 0.9964 - f1-score: 0.9982 - precision: 0.9992 - auc: 0.9999 - val_loss: 0.3727 - val_iou_score: 0.9480 - val_f1-score: 0.9705 - val_precision: 0.9881 - val_auc: 0.9930
# Epoch 58/100
# 35/35 [==============================] - 18s 522ms/step - loss: 0.3387 - iou_score: 0.9967 - f1-score: 0.9983 - precision: 0.9993 - auc: 1.0000 - val_loss: 0.3729 - val_iou_score: 0.9477 - val_f1-score: 0.9703 - val_precision: 0.9881 - val_auc: 0.9929
# Epoch 59/100
# 35/35 [==============================] - 18s 522ms/step - loss: 0.3387 - iou_score: 0.9969 - f1-score: 0.9984 - precision: 0.9993 - auc: 1.0000 - val_loss: 0.3727 - val_iou_score: 0.9481 - val_f1-score: 0.9706 - val_precision: 0.9882 - val_auc: 0.9930
# Epoch 60/100
# 35/35 [==============================] - 18s 522ms/step - loss: 0.3386 - iou_score: 0.9971 - f1-score: 0.9985 - precision: 0.9994 - auc: 1.0000 - val_loss: 0.3730 - val_iou_score: 0.9477 - val_f1-score: 0.9703 - val_precision: 0.9881 - val_auc: 0.9929
# Epoch 61/100
# 35/35 [==============================] - 18s 523ms/step - loss: 0.3385 - iou_score: 0.9972 - f1-score: 0.9986 - precision: 0.9994 - auc: 1.0000 - val_loss: 0.3730 - val_iou_score: 0.9477 - val_f1-score: 0.9703 - val_precision: 0.9881 - val_auc: 0.9929
# Epoch 62/100
# 35/35 [==============================] - 18s 521ms/step - loss: 0.3384 - iou_score: 0.9973 - f1-score: 0.9986 - precision: 0.9994 - auc: 1.0000 - val_loss: 0.3732 - val_iou_score: 0.9474 - val_f1-score: 0.9701 - val_precision: 0.9880 - val_auc: 0.9929
# Epoch 63/100
# 35/35 [==============================] - 18s 522ms/step - loss: 0.3384 - iou_score: 0.9974 - f1-score: 0.9987 - precision: 0.9994 - auc: 1.0000 - val_loss: 0.3731 - val_iou_score: 0.9476 - val_f1-score: 0.9702 - val_precision: 0.9881 - val_auc: 0.9929
# Epoch 64/100
# 35/35 [==============================] - 18s 524ms/step - loss: 0.3384 - iou_score: 0.9974 - f1-score: 0.9987 - precision: 0.9994 - auc: 1.0000 - val_loss: 0.3729 - val_iou_score: 0.9478 - val_f1-score: 0.9704 - val_precision: 0.9881 - val_auc: 0.9929
# Epoch 65/100
# 35/35 [==============================] - 18s 524ms/step - loss: 0.3384 - iou_score: 0.9974 - f1-score: 0.9987 - precision: 0.9994 - auc: 1.0000 - val_loss: 0.3726 - val_iou_score: 0.9483 - val_f1-score: 0.9707 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 66/100
# 35/35 [==============================] - 18s 523ms/step - loss: 0.3384 - iou_score: 0.9974 - f1-score: 0.9987 - precision: 0.9994 - auc: 1.0000 - val_loss: 0.3725 - val_iou_score: 0.9484 - val_f1-score: 0.9708 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 67/100
# 35/35 [==============================] - 18s 525ms/step - loss: 0.3384 - iou_score: 0.9974 - f1-score: 0.9987 - precision: 0.9994 - auc: 1.0000 - val_loss: 0.3726 - val_iou_score: 0.9483 - val_f1-score: 0.9707 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 68/100
# 35/35 [==============================] - 18s 524ms/step - loss: 0.3384 - iou_score: 0.9974 - f1-score: 0.9987 - precision: 0.9994 - auc: 1.0000 - val_loss: 0.3725 - val_iou_score: 0.9484 - val_f1-score: 0.9708 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 69/100
# 35/35 [==============================] - 18s 523ms/step - loss: 0.3384 - iou_score: 0.9974 - f1-score: 0.9987 - precision: 0.9994 - auc: 1.0000 - val_loss: 0.3725 - val_iou_score: 0.9484 - val_f1-score: 0.9708 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 70/100
# 35/35 [==============================] - 18s 523ms/step - loss: 0.3384 - iou_score: 0.9974 - f1-score: 0.9987 - precision: 0.9994 - auc: 1.0000 - val_loss: 0.3724 - val_iou_score: 0.9486 - val_f1-score: 0.9709 - val_precision: 0.9883 - val_auc: 0.9929
# Epoch 71/100
# 35/35 [==============================] - 18s 525ms/step - loss: 0.3384 - iou_score: 0.9974 - f1-score: 0.9987 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3724 - val_iou_score: 0.9486 - val_f1-score: 0.9709 - val_precision: 0.9883 - val_auc: 0.9929
# Epoch 72/100
# 35/35 [==============================] - 18s 524ms/step - loss: 0.3384 - iou_score: 0.9974 - f1-score: 0.9987 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3724 - val_iou_score: 0.9486 - val_f1-score: 0.9709 - val_precision: 0.9883 - val_auc: 0.9929
# Epoch 73/100
# 35/35 [==============================] - 18s 524ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9987 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3724 - val_iou_score: 0.9485 - val_f1-score: 0.9709 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 74/100
# 35/35 [==============================] - 18s 525ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9987 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3726 - val_iou_score: 0.9484 - val_f1-score: 0.9708 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 75/100
# 35/35 [==============================] - 18s 522ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9987 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3726 - val_iou_score: 0.9483 - val_f1-score: 0.9707 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 76/100
# 35/35 [==============================] - 18s 521ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9987 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3727 - val_iou_score: 0.9483 - val_f1-score: 0.9707 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 77/100
# 35/35 [==============================] - 18s 521ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9987 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3728 - val_iou_score: 0.9481 - val_f1-score: 0.9706 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 78/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9987 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3728 - val_iou_score: 0.9481 - val_f1-score: 0.9706 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 79/100
# 35/35 [==============================] - 18s 521ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9987 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3729 - val_iou_score: 0.9480 - val_f1-score: 0.9705 - val_precision: 0.9881 - val_auc: 0.9928
# Epoch 80/100
# 35/35 [==============================] - 19s 530ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9988 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3728 - val_iou_score: 0.9482 - val_f1-score: 0.9706 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 81/100
# 35/35 [==============================] - 18s 525ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9988 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3727 - val_iou_score: 0.9483 - val_f1-score: 0.9707 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 82/100
# 35/35 [==============================] - 18s 521ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9988 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3726 - val_iou_score: 0.9483 - val_f1-score: 0.9707 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 83/100
# 35/35 [==============================] - 18s 516ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9988 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3725 - val_iou_score: 0.9485 - val_f1-score: 0.9708 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 84/100
# 35/35 [==============================] - 19s 531ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9988 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3723 - val_iou_score: 0.9487 - val_f1-score: 0.9710 - val_precision: 0.9883 - val_auc: 0.9929
# Epoch 85/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9988 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3725 - val_iou_score: 0.9485 - val_f1-score: 0.9708 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 86/100
# 35/35 [==============================] - 18s 528ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9988 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3724 - val_iou_score: 0.9486 - val_f1-score: 0.9709 - val_precision: 0.9883 - val_auc: 0.9929
# Epoch 87/100
# 35/35 [==============================] - 18s 520ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9988 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3723 - val_iou_score: 0.9487 - val_f1-score: 0.9710 - val_precision: 0.9883 - val_auc: 0.9929
# Epoch 88/100
# 35/35 [==============================] - 19s 532ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9988 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3726 - val_iou_score: 0.9484 - val_f1-score: 0.9708 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 89/100
# 35/35 [==============================] - 19s 544ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9988 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3725 - val_iou_score: 0.9485 - val_f1-score: 0.9708 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 90/100
# 35/35 [==============================] - 19s 537ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9988 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3726 - val_iou_score: 0.9484 - val_f1-score: 0.9708 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 91/100
# 35/35 [==============================] - 19s 534ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9988 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3727 - val_iou_score: 0.9483 - val_f1-score: 0.9707 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 92/100
# 35/35 [==============================] - 18s 522ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9988 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3726 - val_iou_score: 0.9483 - val_f1-score: 0.9707 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 93/100
# 35/35 [==============================] - 18s 522ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9988 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3726 - val_iou_score: 0.9484 - val_f1-score: 0.9708 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 94/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9988 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3725 - val_iou_score: 0.9485 - val_f1-score: 0.9709 - val_precision: 0.9883 - val_auc: 0.9929
# Epoch 95/100
# 35/35 [==============================] - 18s 527ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9988 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3725 - val_iou_score: 0.9486 - val_f1-score: 0.9709 - val_precision: 0.9883 - val_auc: 0.9929
# Epoch 96/100
# 35/35 [==============================] - 18s 526ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9988 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3726 - val_iou_score: 0.9484 - val_f1-score: 0.9708 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 97/100
# 35/35 [==============================] - 19s 529ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9988 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3725 - val_iou_score: 0.9485 - val_f1-score: 0.9709 - val_precision: 0.9883 - val_auc: 0.9929
# Epoch 98/100
# 35/35 [==============================] - 19s 536ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9988 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3726 - val_iou_score: 0.9484 - val_f1-score: 0.9708 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 99/100
# 35/35 [==============================] - 19s 534ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9988 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3727 - val_iou_score: 0.9482 - val_f1-score: 0.9707 - val_precision: 0.9882 - val_auc: 0.9929
# Epoch 100/100
# 35/35 [==============================] - 19s 535ms/step - loss: 0.3383 - iou_score: 0.9975 - f1-score: 0.9988 - precision: 0.9995 - auc: 1.0000 - val_loss: 0.3728 - val_iou_score: 0.9482 - val_f1-score: 0.9706 - val_precision: 0.9882 - val_auc: 0.9929
#
#
#
# ***********  Training Complete  ***********

# %%
# Plot training & validation iou_score values
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['f1-score'])
plt.plot(history.history['val_f1-score'])
plt.title('Model f1 Score')
plt.ylabel('f1 Score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.ylabel('Precision')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
n = 5

for i in range(n):
    
    image, gt_mask = valid_dataset[i]
    image = np.expand_dims(image, axis=0)
    pr_mask = model.predict(image).round()
    
    visualize(
        image=denormalize(image.squeeze()),
        gt_mask=gt_mask[..., 1].squeeze(),
        pr_mask=pr_mask[..., 1].squeeze(),
    )

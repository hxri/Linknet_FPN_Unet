# %%
import numpy as np
import os
import time

os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"

import keras
import tensorflow as tf

from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

batch_size = 256
num_classes = 10
epochs = 100

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(16, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(Dropout(0.5))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
model.add(Dropout(0.5))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))


model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy', tf.keras.metrics.CategoricalCrossentropy()])
train_start_t = time.time()
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
train_end_t = time.time()
train_dur_t = train_end_t - train_start_t
print("train use time %f s" % train_dur_t)
test_start_t = time.time()
score = model.evaluate(x_test, y_test, verbose=0)
test_end_t = time.time()
test_dur_t = test_end_t - test_start_t
print("test use time %f s" % test_dur_t)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Epoch 1/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.4184 - accuracy: 0.1050 - categorical_crossentropy: 2.4184 - val_loss: 2.3126 - val_accuracy: 0.1036 - val_categorical_crossentropy: 2.3126
# Epoch 2/100
# 235/235 [==============================] - 1s 3ms/step - loss: 2.3912 - accuracy: 0.1084 - categorical_crossentropy: 2.3912 - val_loss: 2.3054 - val_accuracy: 0.1121 - val_categorical_crossentropy: 2.3054
# Epoch 3/100
# 235/235 [==============================] - 1s 3ms/step - loss: 2.3645 - accuracy: 0.1144 - categorical_crossentropy: 2.3645 - val_loss: 2.2983 - val_accuracy: 0.1251 - val_categorical_crossentropy: 2.2983
# Epoch 4/100
# 235/235 [==============================] - 1s 3ms/step - loss: 2.3399 - accuracy: 0.1244 - categorical_crossentropy: 2.3399 - val_loss: 2.2912 - val_accuracy: 0.1442 - val_categorical_crossentropy: 2.2912
# Epoch 5/100
# 235/235 [==============================] - 1s 3ms/step - loss: 2.3166 - accuracy: 0.1333 - categorical_crossentropy: 2.3166 - val_loss: 2.2843 - val_accuracy: 0.1643 - val_categorical_crossentropy: 2.2843
# Epoch 6/100
# 235/235 [==============================] - 1s 3ms/step - loss: 2.2948 - accuracy: 0.1419 - categorical_crossentropy: 2.2948 - val_loss: 2.2774 - val_accuracy: 0.1756 - val_categorical_crossentropy: 2.2774
# Epoch 7/100
# 235/235 [==============================] - 1s 3ms/step - loss: 2.2728 - accuracy: 0.1567 - categorical_crossentropy: 2.2728 - val_loss: 2.2705 - val_accuracy: 0.1890 - val_categorical_crossentropy: 2.2705
# Epoch 8/100
# 235/235 [==============================] - 1s 3ms/step - loss: 2.2532 - accuracy: 0.1679 - categorical_crossentropy: 2.2532 - val_loss: 2.2637 - val_accuracy: 0.2031 - val_categorical_crossentropy: 2.2637
# Epoch 9/100
# 235/235 [==============================] - 1s 3ms/step - loss: 2.2323 - accuracy: 0.1831 - categorical_crossentropy: 2.2323 - val_loss: 2.2567 - val_accuracy: 0.2190 - val_categorical_crossentropy: 2.2567
# Epoch 10/100
# 235/235 [==============================] - 1s 3ms/step - loss: 2.2130 - accuracy: 0.1968 - categorical_crossentropy: 2.2130 - val_loss: 2.2497 - val_accuracy: 0.2412 - val_categorical_crossentropy: 2.2497
# Epoch 11/100
# 235/235 [==============================] - 1s 3ms/step - loss: 2.1941 - accuracy: 0.2128 - categorical_crossentropy: 2.1941 - val_loss: 2.2425 - val_accuracy: 0.2616 - val_categorical_crossentropy: 2.2425
# Epoch 12/100
# 235/235 [==============================] - 1s 3ms/step - loss: 2.1755 - accuracy: 0.2246 - categorical_crossentropy: 2.1755 - val_loss: 2.2352 - val_accuracy: 0.2870 - val_categorical_crossentropy: 2.2352
# Epoch 13/100
# 235/235 [==============================] - 1s 3ms/step - loss: 2.1540 - accuracy: 0.2427 - categorical_crossentropy: 2.1540 - val_loss: 2.2276 - val_accuracy: 0.3133 - val_categorical_crossentropy: 2.2276
# Epoch 14/100
# 235/235 [==============================] - 1s 3ms/step - loss: 2.1348 - accuracy: 0.2583 - categorical_crossentropy: 2.1348 - val_loss: 2.2199 - val_accuracy: 0.3430 - val_categorical_crossentropy: 2.2199
# Epoch 15/100
# 235/235 [==============================] - 1s 3ms/step - loss: 2.1156 - accuracy: 0.2786 - categorical_crossentropy: 2.1156 - val_loss: 2.2118 - val_accuracy: 0.3710 - val_categorical_crossentropy: 2.2118
# Epoch 16/100
# 235/235 [==============================] - 1s 3ms/step - loss: 2.0950 - accuracy: 0.2945 - categorical_crossentropy: 2.0950 - val_loss: 2.2035 - val_accuracy: 0.3982 - val_categorical_crossentropy: 2.2035
# Epoch 17/100
# 235/235 [==============================] - 1s 3ms/step - loss: 2.0743 - accuracy: 0.3137 - categorical_crossentropy: 2.0743 - val_loss: 2.1948 - val_accuracy: 0.4285 - val_categorical_crossentropy: 2.1948
# Epoch 18/100
# 235/235 [==============================] - 1s 3ms/step - loss: 2.0530 - accuracy: 0.3362 - categorical_crossentropy: 2.0530 - val_loss: 2.1858 - val_accuracy: 0.4577 - val_categorical_crossentropy: 2.1858
# Epoch 19/100
# 235/235 [==============================] - 1s 3ms/step - loss: 2.0294 - accuracy: 0.3567 - categorical_crossentropy: 2.0294 - val_loss: 2.1764 - val_accuracy: 0.4837 - val_categorical_crossentropy: 2.1764
# Epoch 20/100
# 235/235 [==============================] - 1s 3ms/step - loss: 2.0077 - accuracy: 0.3751 - categorical_crossentropy: 2.0077 - val_loss: 2.1666 - val_accuracy: 0.5123 - val_categorical_crossentropy: 2.1666
# Epoch 21/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.9833 - accuracy: 0.3941 - categorical_crossentropy: 1.9833 - val_loss: 2.1564 - val_accuracy: 0.5376 - val_categorical_crossentropy: 2.1564
# Epoch 22/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.9592 - accuracy: 0.4158 - categorical_crossentropy: 1.9592 - val_loss: 2.1457 - val_accuracy: 0.5604 - val_categorical_crossentropy: 2.1457
# Epoch 23/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.9342 - accuracy: 0.4381 - categorical_crossentropy: 1.9342 - val_loss: 2.1345 - val_accuracy: 0.5811 - val_categorical_crossentropy: 2.1345
# Epoch 24/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.9082 - accuracy: 0.4540 - categorical_crossentropy: 1.9082 - val_loss: 2.1229 - val_accuracy: 0.5996 - val_categorical_crossentropy: 2.1229
# Epoch 25/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.8826 - accuracy: 0.4719 - categorical_crossentropy: 1.8826 - val_loss: 2.1107 - val_accuracy: 0.6171 - val_categorical_crossentropy: 2.1107
# Epoch 26/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.8533 - accuracy: 0.4890 - categorical_crossentropy: 1.8533 - val_loss: 2.0980 - val_accuracy: 0.6317 - val_categorical_crossentropy: 2.0980
# Epoch 27/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.8246 - accuracy: 0.5073 - categorical_crossentropy: 1.8246 - val_loss: 2.0848 - val_accuracy: 0.6462 - val_categorical_crossentropy: 2.0848
# Epoch 28/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.7960 - accuracy: 0.5210 - categorical_crossentropy: 1.7960 - val_loss: 2.0710 - val_accuracy: 0.6603 - val_categorical_crossentropy: 2.0710
# Epoch 29/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.7652 - accuracy: 0.5348 - categorical_crossentropy: 1.7652 - val_loss: 2.0567 - val_accuracy: 0.6708 - val_categorical_crossentropy: 2.0567
# Epoch 30/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.7349 - accuracy: 0.5481 - categorical_crossentropy: 1.7349 - val_loss: 2.0418 - val_accuracy: 0.6807 - val_categorical_crossentropy: 2.0418
# Epoch 31/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.7029 - accuracy: 0.5630 - categorical_crossentropy: 1.7029 - val_loss: 2.0264 - val_accuracy: 0.6877 - val_categorical_crossentropy: 2.0264
# Epoch 32/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.6714 - accuracy: 0.5722 - categorical_crossentropy: 1.6714 - val_loss: 2.0106 - val_accuracy: 0.6989 - val_categorical_crossentropy: 2.0106
# Epoch 33/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.6386 - accuracy: 0.5850 - categorical_crossentropy: 1.6386 - val_loss: 1.9942 - val_accuracy: 0.7063 - val_categorical_crossentropy: 1.9942
# Epoch 34/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.6070 - accuracy: 0.5938 - categorical_crossentropy: 1.6070 - val_loss: 1.9775 - val_accuracy: 0.7136 - val_categorical_crossentropy: 1.9775
# Epoch 35/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.5760 - accuracy: 0.6011 - categorical_crossentropy: 1.5760 - val_loss: 1.9604 - val_accuracy: 0.7195 - val_categorical_crossentropy: 1.9604
# Epoch 36/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.5427 - accuracy: 0.6106 - categorical_crossentropy: 1.5427 - val_loss: 1.9429 - val_accuracy: 0.7256 - val_categorical_crossentropy: 1.9429
# Epoch 37/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.5124 - accuracy: 0.6184 - categorical_crossentropy: 1.5124 - val_loss: 1.9251 - val_accuracy: 0.7310 - val_categorical_crossentropy: 1.9251
# Epoch 38/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.4795 - accuracy: 0.6274 - categorical_crossentropy: 1.4795 - val_loss: 1.9071 - val_accuracy: 0.7368 - val_categorical_crossentropy: 1.9071
# Epoch 39/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.4464 - accuracy: 0.6343 - categorical_crossentropy: 1.4464 - val_loss: 1.8889 - val_accuracy: 0.7430 - val_categorical_crossentropy: 1.8889
# Epoch 40/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.4174 - accuracy: 0.6403 - categorical_crossentropy: 1.4174 - val_loss: 1.8705 - val_accuracy: 0.7483 - val_categorical_crossentropy: 1.8705
# Epoch 41/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.3860 - accuracy: 0.6488 - categorical_crossentropy: 1.3860 - val_loss: 1.8521 - val_accuracy: 0.7530 - val_categorical_crossentropy: 1.8521
# Epoch 42/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.3564 - accuracy: 0.6534 - categorical_crossentropy: 1.3564 - val_loss: 1.8337 - val_accuracy: 0.7588 - val_categorical_crossentropy: 1.8337
# Epoch 43/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.3293 - accuracy: 0.6583 - categorical_crossentropy: 1.3293 - val_loss: 1.8153 - val_accuracy: 0.7631 - val_categorical_crossentropy: 1.8153
# Epoch 44/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.2994 - accuracy: 0.6626 - categorical_crossentropy: 1.2994 - val_loss: 1.7969 - val_accuracy: 0.7663 - val_categorical_crossentropy: 1.7969
# Epoch 45/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.2732 - accuracy: 0.6712 - categorical_crossentropy: 1.2732 - val_loss: 1.7786 - val_accuracy: 0.7695 - val_categorical_crossentropy: 1.7786
# Epoch 46/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.2477 - accuracy: 0.6729 - categorical_crossentropy: 1.2477 - val_loss: 1.7605 - val_accuracy: 0.7737 - val_categorical_crossentropy: 1.7605
# Epoch 47/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.2198 - accuracy: 0.6788 - categorical_crossentropy: 1.2198 - val_loss: 1.7426 - val_accuracy: 0.7757 - val_categorical_crossentropy: 1.7426
# Epoch 48/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.1969 - accuracy: 0.6833 - categorical_crossentropy: 1.1969 - val_loss: 1.7249 - val_accuracy: 0.7783 - val_categorical_crossentropy: 1.7249
# Epoch 49/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.1740 - accuracy: 0.6873 - categorical_crossentropy: 1.1740 - val_loss: 1.7074 - val_accuracy: 0.7808 - val_categorical_crossentropy: 1.7074
# Epoch 50/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.1483 - accuracy: 0.6898 - categorical_crossentropy: 1.1483 - val_loss: 1.6902 - val_accuracy: 0.7829 - val_categorical_crossentropy: 1.6902
# Epoch 51/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.1284 - accuracy: 0.6973 - categorical_crossentropy: 1.1284 - val_loss: 1.6732 - val_accuracy: 0.7859 - val_categorical_crossentropy: 1.6732
# Epoch 52/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.1054 - accuracy: 0.6981 - categorical_crossentropy: 1.1054 - val_loss: 1.6565 - val_accuracy: 0.7881 - val_categorical_crossentropy: 1.6565
# Epoch 53/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.0856 - accuracy: 0.7034 - categorical_crossentropy: 1.0856 - val_loss: 1.6401 - val_accuracy: 0.7908 - val_categorical_crossentropy: 1.6401
# Epoch 54/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.0639 - accuracy: 0.7081 - categorical_crossentropy: 1.0639 - val_loss: 1.6240 - val_accuracy: 0.7934 - val_categorical_crossentropy: 1.6240
# Epoch 55/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.0471 - accuracy: 0.7119 - categorical_crossentropy: 1.0471 - val_loss: 1.6082 - val_accuracy: 0.7964 - val_categorical_crossentropy: 1.6082
# Epoch 56/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.0288 - accuracy: 0.7155 - categorical_crossentropy: 1.0288 - val_loss: 1.5926 - val_accuracy: 0.7986 - val_categorical_crossentropy: 1.5926
# Epoch 57/100
# 235/235 [==============================] - 1s 3ms/step - loss: 1.0116 - accuracy: 0.7182 - categorical_crossentropy: 1.0116 - val_loss: 1.5774 - val_accuracy: 0.8008 - val_categorical_crossentropy: 1.5774
# Epoch 58/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.9952 - accuracy: 0.7220 - categorical_crossentropy: 0.9952 - val_loss: 1.5625 - val_accuracy: 0.8025 - val_categorical_crossentropy: 1.5625
# Epoch 59/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.9788 - accuracy: 0.7242 - categorical_crossentropy: 0.9788 - val_loss: 1.5477 - val_accuracy: 0.8048 - val_categorical_crossentropy: 1.5477
# Epoch 60/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.9655 - accuracy: 0.7272 - categorical_crossentropy: 0.9655 - val_loss: 1.5333 - val_accuracy: 0.8065 - val_categorical_crossentropy: 1.5333
# Epoch 61/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.9475 - accuracy: 0.7316 - categorical_crossentropy: 0.9475 - val_loss: 1.5192 - val_accuracy: 0.8094 - val_categorical_crossentropy: 1.5192
# Epoch 62/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.9378 - accuracy: 0.7305 - categorical_crossentropy: 0.9378 - val_loss: 1.5054 - val_accuracy: 0.8107 - val_categorical_crossentropy: 1.5054
# Epoch 63/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.9207 - accuracy: 0.7358 - categorical_crossentropy: 0.9207 - val_loss: 1.4920 - val_accuracy: 0.8131 - val_categorical_crossentropy: 1.4920
# Epoch 64/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.9103 - accuracy: 0.7391 - categorical_crossentropy: 0.9103 - val_loss: 1.4789 - val_accuracy: 0.8144 - val_categorical_crossentropy: 1.4789
# Epoch 65/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.8998 - accuracy: 0.7394 - categorical_crossentropy: 0.8998 - val_loss: 1.4661 - val_accuracy: 0.8158 - val_categorical_crossentropy: 1.4661
# Epoch 66/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.8853 - accuracy: 0.7426 - categorical_crossentropy: 0.8853 - val_loss: 1.4534 - val_accuracy: 0.8173 - val_categorical_crossentropy: 1.4534
# Epoch 67/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.8763 - accuracy: 0.7444 - categorical_crossentropy: 0.8763 - val_loss: 1.4410 - val_accuracy: 0.8194 - val_categorical_crossentropy: 1.4410
# Epoch 68/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.8640 - accuracy: 0.7461 - categorical_crossentropy: 0.8640 - val_loss: 1.4289 - val_accuracy: 0.8211 - val_categorical_crossentropy: 1.4289
# Epoch 69/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.8528 - accuracy: 0.7480 - categorical_crossentropy: 0.8528 - val_loss: 1.4171 - val_accuracy: 0.8229 - val_categorical_crossentropy: 1.4171
# Epoch 70/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.8419 - accuracy: 0.7510 - categorical_crossentropy: 0.8419 - val_loss: 1.4056 - val_accuracy: 0.8248 - val_categorical_crossentropy: 1.4056
# Epoch 71/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.8330 - accuracy: 0.7531 - categorical_crossentropy: 0.8330 - val_loss: 1.3943 - val_accuracy: 0.8263 - val_categorical_crossentropy: 1.3943
# Epoch 72/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.8257 - accuracy: 0.7544 - categorical_crossentropy: 0.8257 - val_loss: 1.3833 - val_accuracy: 0.8274 - val_categorical_crossentropy: 1.3833
# Epoch 73/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.8110 - accuracy: 0.7579 - categorical_crossentropy: 0.8110 - val_loss: 1.3725 - val_accuracy: 0.8296 - val_categorical_crossentropy: 1.3725
# Epoch 74/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.8057 - accuracy: 0.7592 - categorical_crossentropy: 0.8057 - val_loss: 1.3618 - val_accuracy: 0.8307 - val_categorical_crossentropy: 1.3618
# Epoch 75/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.7975 - accuracy: 0.7616 - categorical_crossentropy: 0.7975 - val_loss: 1.3515 - val_accuracy: 0.8328 - val_categorical_crossentropy: 1.3515
# Epoch 76/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.7886 - accuracy: 0.7634 - categorical_crossentropy: 0.7886 - val_loss: 1.3414 - val_accuracy: 0.8347 - val_categorical_crossentropy: 1.3414
# Epoch 77/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.7804 - accuracy: 0.7639 - categorical_crossentropy: 0.7804 - val_loss: 1.3315 - val_accuracy: 0.8358 - val_categorical_crossentropy: 1.3315
# Epoch 78/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.7732 - accuracy: 0.7661 - categorical_crossentropy: 0.7732 - val_loss: 1.3217 - val_accuracy: 0.8370 - val_categorical_crossentropy: 1.3217
# Epoch 79/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.7652 - accuracy: 0.7696 - categorical_crossentropy: 0.7652 - val_loss: 1.3122 - val_accuracy: 0.8382 - val_categorical_crossentropy: 1.3122
# Epoch 80/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.7575 - accuracy: 0.7705 - categorical_crossentropy: 0.7575 - val_loss: 1.3028 - val_accuracy: 0.8391 - val_categorical_crossentropy: 1.3028
# Epoch 81/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.7504 - accuracy: 0.7707 - categorical_crossentropy: 0.7504 - val_loss: 1.2936 - val_accuracy: 0.8402 - val_categorical_crossentropy: 1.2936
# Epoch 82/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.7441 - accuracy: 0.7726 - categorical_crossentropy: 0.7441 - val_loss: 1.2848 - val_accuracy: 0.8416 - val_categorical_crossentropy: 1.2848
# Epoch 83/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.7380 - accuracy: 0.7738 - categorical_crossentropy: 0.7380 - val_loss: 1.2761 - val_accuracy: 0.8424 - val_categorical_crossentropy: 1.2761
# Epoch 84/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.7317 - accuracy: 0.7759 - categorical_crossentropy: 0.7317 - val_loss: 1.2676 - val_accuracy: 0.8432 - val_categorical_crossentropy: 1.2676
# Epoch 85/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.7276 - accuracy: 0.7758 - categorical_crossentropy: 0.7276 - val_loss: 1.2591 - val_accuracy: 0.8453 - val_categorical_crossentropy: 1.2591
# Epoch 86/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.7165 - accuracy: 0.7807 - categorical_crossentropy: 0.7165 - val_loss: 1.2508 - val_accuracy: 0.8457 - val_categorical_crossentropy: 1.2508
# Epoch 87/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.7123 - accuracy: 0.7813 - categorical_crossentropy: 0.7123 - val_loss: 1.2430 - val_accuracy: 0.8464 - val_categorical_crossentropy: 1.2430
# Epoch 88/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.7067 - accuracy: 0.7809 - categorical_crossentropy: 0.7067 - val_loss: 1.2350 - val_accuracy: 0.8468 - val_categorical_crossentropy: 1.2350
# Epoch 89/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.7018 - accuracy: 0.7849 - categorical_crossentropy: 0.7018 - val_loss: 1.2272 - val_accuracy: 0.8479 - val_categorical_crossentropy: 1.2272
# Epoch 90/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.6949 - accuracy: 0.7860 - categorical_crossentropy: 0.6949 - val_loss: 1.2195 - val_accuracy: 0.8485 - val_categorical_crossentropy: 1.2195
# Epoch 91/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.6938 - accuracy: 0.7857 - categorical_crossentropy: 0.6938 - val_loss: 1.2122 - val_accuracy: 0.8494 - val_categorical_crossentropy: 1.2122
# Epoch 92/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.6886 - accuracy: 0.7867 - categorical_crossentropy: 0.6886 - val_loss: 1.2051 - val_accuracy: 0.8508 - val_categorical_crossentropy: 1.2051
# Epoch 93/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.6771 - accuracy: 0.7916 - categorical_crossentropy: 0.6771 - val_loss: 1.1979 - val_accuracy: 0.8524 - val_categorical_crossentropy: 1.1979
# Epoch 94/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.6770 - accuracy: 0.7902 - categorical_crossentropy: 0.6770 - val_loss: 1.1911 - val_accuracy: 0.8531 - val_categorical_crossentropy: 1.1911
# Epoch 95/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.6712 - accuracy: 0.7918 - categorical_crossentropy: 0.6712 - val_loss: 1.1843 - val_accuracy: 0.8543 - val_categorical_crossentropy: 1.1843
# Epoch 96/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.6691 - accuracy: 0.7919 - categorical_crossentropy: 0.6691 - val_loss: 1.1775 - val_accuracy: 0.8548 - val_categorical_crossentropy: 1.1775
# Epoch 97/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.6607 - accuracy: 0.7956 - categorical_crossentropy: 0.6607 - val_loss: 1.1711 - val_accuracy: 0.8557 - val_categorical_crossentropy: 1.1711
# Epoch 98/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.6550 - accuracy: 0.7980 - categorical_crossentropy: 0.6550 - val_loss: 1.1645 - val_accuracy: 0.8569 - val_categorical_crossentropy: 1.1645
# Epoch 99/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.6543 - accuracy: 0.7967 - categorical_crossentropy: 0.6543 - val_loss: 1.1582 - val_accuracy: 0.8580 - val_categorical_crossentropy: 1.1582
# Epoch 100/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.6471 - accuracy: 0.8012 - categorical_crossentropy: 0.6471 - val_loss: 1.1518 - val_accuracy: 0.8585 - val_categorical_crossentropy: 1.1518
# train use time 80.807695 s
# test use time 0.264293 s
# Test loss: 1.15182363986969
# Test accuracy: 0.8585000038146973

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

import cv2
import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
DATA_DIR = './dataset2/'

# %%
x_train_dir = os.path.join(DATA_DIR, 'train_images')
y_train_dir = os.path.join(DATA_DIR, 'train_annotations')

x_valid_dir = os.path.join(DATA_DIR, 'val_images')
y_valid_dir = os.path.join(DATA_DIR, 'val_annotations')

# %% [markdown]
# ## Dataloader

# %%
# helper function for data visualization
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()
    
# helper function for data visualization    
def denormalize(x):
    """Scale image to range 0..1 for correct plot"""
    x_max = np.percentile(x, 98)
    x_min = np.percentile(x, 2)    
    x = (x - x_min) / (x_max - x_min)
    x = x.clip(0, 1)
    return x
    

# classes for data loading and preprocessing
class Dataset:
    """CamVid Dataset. Read images, apply augmentation and preprocessing transformations.
    
    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing 
            (e.g. noralization, shape manipulation, etc.)
    
    """
    
    CLASSES = ['background', 'blob']
    
    def __init__(
            self, 
            images_dir, 
            masks_dir, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
    ):
        self.ids = os.listdir(images_dir)
        self.images_fps = [os.path.join(images_dir, image_id) for image_id in self.ids]
        self.masks_fps = [os.path.join(masks_dir, image_id) for image_id in self.ids]
        
        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        # read data
        image = cv2.imread(self.images_fps[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.masks_fps[i], 0)
        
        # extract certain classes from mask (e.g. cars)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1).astype('float')
        
        # add background if mask is not binary
        if mask.shape[-1] != 1:
            background = 1 - mask.sum(axis=-1, keepdims=True)
            mask = np.concatenate((mask, background), axis=-1)
        
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
            
        return image, mask
        
    def __len__(self):
        return len(self.ids)
    
    
class Dataloder(keras.utils.Sequence):
    """Load data from dataset and form batches
    
    Args:
        dataset: instance of Dataset class for image loading and preprocessing.
        batch_size: Integet number of images in batch.
        shuffle: Boolean, if `True` shuffle image indexes each epoch.
    """
    
    def __init__(self, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(dataset))

        self.on_epoch_end()

    def __getitem__(self, i):
        
        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        data = []
        for j in range(start, stop):
            data.append(self.dataset[j])
        
        # transpose list of lists
        batch = [np.stack(samples, axis=0) for samples in zip(*data)]
        
        return (batch[0],batch[1])
    
    def __len__(self):
        """Denotes the number of batches per epoch"""
        return len(self.indexes) // self.batch_size
    
    def on_epoch_end(self):
        """Callback function to shuffle indexes each epoch"""
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

# %%
# Lets look at data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['background', 'blob'])

image, mask = dataset[5] # get some sample
visualize(
    image=image, 
    background=mask[..., 0].squeeze(),
    blob=mask[..., 1].squeeze(),
)

# %% [markdown]
# ## Augmentation

# %%
import albumentations as A

# %%
def round_clip_0_1(x, **kwargs):
    return x.round().clip(0, 1)

# define heavy augmentations
def get_training_augmentation():
    train_transform = [

        A.Resize (320, 480, interpolation=1, always_apply=True, p=1),
    ]
    return A.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        A.PadIfNeeded(384, 480, always_apply=True)
    ]
    return A.Compose(test_transform)

def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        A.Lambda(image=preprocessing_fn),
    ]
    return A.Compose(_transform)

# %%
# Lets look at augmented data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['background', 'blob'], augmentation=get_training_augmentation())

image, mask = dataset[12] # get some sample
visualize(
    image=image, 
    background=mask[..., 0].squeeze(),
    blob=mask[..., 1].squeeze(),
)

# %% [markdown]
# ## Model

# %%
# %env SM_FRAMEWORK=tf.keras

import segmentation_models as sm
# Out:
# env: SM_FRAMEWORK=tf.keras

# %%
BACKBONE = 'densenet121'
BATCH_SIZE = 2
CLASSES = ['background', 'blob']
LR = 0.0001
EPOCHS = 5

preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
# define network parameters
n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
activation = 'sigmoid' if n_classes == 1 else 'softmax'

#create model
model = sm.Unet(BACKBONE, classes=n_classes, activation=activation)
# Out:
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 5s 0us/step

# %%
# define optomizer
optim = keras.optimizers.Adam(LR)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
dice_loss = sm.losses.DiceLoss()
focal_loss = sm.losses.BinaryFocalLoss() if n_classes == 1 else sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
# total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss 

metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]

# compile keras model with defined optimozer, loss and metrics
model.compile(optim, total_loss, metrics)

# %%
# Dataset for train images
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

# Dataset for validation images
valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

train_dataloader = Dataloder(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_dataloader = Dataloder(valid_dataset, batch_size=1, shuffle=False)

# check shapes for errors
assert train_dataloader[0][0].shape == (BATCH_SIZE, 320, 480, 3)
assert train_dataloader[0][1].shape == (BATCH_SIZE, 320, 480, n_classes)

# define callbacks for learning rate scheduling and best checkpoints saving
callbacks = [
    keras.callbacks.ModelCheckpoint('./best_model.h5', save_weights_only=True, save_best_only=True, mode='min'),
    keras.callbacks.ReduceLROnPlateau(),
]

# %%
print(valid_dataloader[0][0].shape)
# Out:
# (1, 320, 480, 3)

# %%
# train model
history = model.fit(
    train_dataloader, 
    steps_per_epoch=len(train_dataloader), 
    epochs=100, 
    callbacks=callbacks,
    validation_data=valid_dataloader, 
    validation_steps=len(valid_dataloader),
)
# Out:
# Epoch 1/100
# 35/35 [==============================] - 23s 667ms/step - loss: 0.7222 - iou_score: 0.2724 - f1-score: 0.3573 - val_loss: 0.7376 - val_iou_score: 0.4679 - val_f1-score: 0.5655
# Epoch 2/100
# 35/35 [==============================] - 22s 615ms/step - loss: 0.5685 - iou_score: 0.5326 - f1-score: 0.5888 - val_loss: 0.6434 - val_iou_score: 0.5434 - val_f1-score: 0.6236
# Epoch 3/100
# 35/35 [==============================] - 21s 610ms/step - loss: 0.4962 - iou_score: 0.6071 - f1-score: 0.6344 - val_loss: 0.5589 - val_iou_score: 0.6666 - val_f1-score: 0.7017
# Epoch 4/100
# 35/35 [==============================] - 21s 608ms/step - loss: 0.4575 - iou_score: 0.6229 - f1-score: 0.6432 - val_loss: 0.5031 - val_iou_score: 0.6844 - val_f1-score: 0.7114
# Epoch 5/100
# 35/35 [==============================] - 21s 613ms/step - loss: 0.4340 - iou_score: 0.6250 - f1-score: 0.6441 - val_loss: 0.4760 - val_iou_score: 0.7179 - val_f1-score: 0.7442
# Epoch 6/100
# 35/35 [==============================] - 22s 615ms/step - loss: 0.4139 - iou_score: 0.6353 - f1-score: 0.6502 - val_loss: 0.4380 - val_iou_score: 0.8129 - val_f1-score: 0.8325
# Epoch 7/100
# 35/35 [==============================] - 21s 611ms/step - loss: 0.4000 - iou_score: 0.6386 - f1-score: 0.6520 - val_loss: 0.4225 - val_iou_score: 0.8586 - val_f1-score: 0.8776
# Epoch 8/100
# 35/35 [==============================] - 22s 619ms/step - loss: 0.3902 - iou_score: 0.6496 - f1-score: 0.6623 - val_loss: 0.4108 - val_iou_score: 0.8800 - val_f1-score: 0.8994
# Epoch 9/100
# 35/35 [==============================] - 21s 612ms/step - loss: 0.3809 - iou_score: 0.8063 - f1-score: 0.8170 - val_loss: 0.4000 - val_iou_score: 0.9254 - val_f1-score: 0.9444
# Epoch 10/100
# 35/35 [==============================] - 22s 619ms/step - loss: 0.3742 - iou_score: 0.8663 - f1-score: 0.8757 - val_loss: 0.3914 - val_iou_score: 0.9278 - val_f1-score: 0.9457
# Epoch 11/100
# 35/35 [==============================] - 21s 608ms/step - loss: 0.3695 - iou_score: 0.8954 - f1-score: 0.9046 - val_loss: 0.3844 - val_iou_score: 0.9617 - val_f1-score: 0.9794
# Epoch 12/100
# 35/35 [==============================] - 21s 612ms/step - loss: 0.3655 - iou_score: 0.9251 - f1-score: 0.9337 - val_loss: 0.3808 - val_iou_score: 0.9629 - val_f1-score: 0.9801
# Epoch 13/100
# 35/35 [==============================] - 22s 627ms/step - loss: 0.3622 - iou_score: 0.9355 - f1-score: 0.9438 - val_loss: 0.3801 - val_iou_score: 0.9590 - val_f1-score: 0.9779
# Epoch 14/100
# 35/35 [==============================] - 18s 511ms/step - loss: 0.3594 - iou_score: 0.9650 - f1-score: 0.9728 - val_loss: 0.3807 - val_iou_score: 0.9551 - val_f1-score: 0.9757
# Epoch 15/100
# 35/35 [==============================] - 21s 601ms/step - loss: 0.3570 - iou_score: 0.9659 - f1-score: 0.9733 - val_loss: 0.3753 - val_iou_score: 0.9595 - val_f1-score: 0.9781
# Epoch 16/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3548 - iou_score: 0.9862 - f1-score: 0.9930 - val_loss: 0.3769 - val_iou_score: 0.9548 - val_f1-score: 0.9754
# Epoch 17/100
# 35/35 [==============================] - 21s 597ms/step - loss: 0.3531 - iou_score: 0.9869 - f1-score: 0.9934 - val_loss: 0.3728 - val_iou_score: 0.9587 - val_f1-score: 0.9776
# Epoch 18/100
# 35/35 [==============================] - 22s 624ms/step - loss: 0.3515 - iou_score: 0.9876 - f1-score: 0.9937 - val_loss: 0.3695 - val_iou_score: 0.9613 - val_f1-score: 0.9792
# Epoch 19/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3508 - iou_score: 0.9871 - f1-score: 0.9934 - val_loss: 0.3698 - val_iou_score: 0.9597 - val_f1-score: 0.9782
# Epoch 20/100
# 35/35 [==============================] - 22s 623ms/step - loss: 0.3496 - iou_score: 0.9876 - f1-score: 0.9937 - val_loss: 0.3684 - val_iou_score: 0.9600 - val_f1-score: 0.9784
# Epoch 21/100
# 35/35 [==============================] - 18s 513ms/step - loss: 0.3485 - iou_score: 0.9883 - f1-score: 0.9941 - val_loss: 0.3689 - val_iou_score: 0.9578 - val_f1-score: 0.9771
# Epoch 22/100
# 35/35 [==============================] - 22s 630ms/step - loss: 0.3478 - iou_score: 0.9884 - f1-score: 0.9941 - val_loss: 0.3682 - val_iou_score: 0.9581 - val_f1-score: 0.9773
# Epoch 23/100
# 35/35 [==============================] - 18s 523ms/step - loss: 0.3473 - iou_score: 0.9883 - f1-score: 0.9941 - val_loss: 0.3693 - val_iou_score: 0.9556 - val_f1-score: 0.9758
# Epoch 24/100
# 35/35 [==============================] - 22s 621ms/step - loss: 0.3464 - iou_score: 0.9891 - f1-score: 0.9945 - val_loss: 0.3657 - val_iou_score: 0.9597 - val_f1-score: 0.9781
# Epoch 25/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3456 - iou_score: 0.9801 - f1-score: 0.9852 - val_loss: 0.3668 - val_iou_score: 0.9575 - val_f1-score: 0.9769
# Epoch 26/100
# 35/35 [==============================] - 22s 625ms/step - loss: 0.3451 - iou_score: 0.9898 - f1-score: 0.9948 - val_loss: 0.3643 - val_iou_score: 0.9609 - val_f1-score: 0.9788
# Epoch 27/100
# 35/35 [==============================] - 18s 513ms/step - loss: 0.3449 - iou_score: 0.9894 - f1-score: 0.9946 - val_loss: 0.3653 - val_iou_score: 0.9587 - val_f1-score: 0.9775
# Epoch 28/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3444 - iou_score: 0.9896 - f1-score: 0.9947 - val_loss: 0.3681 - val_iou_score: 0.9542 - val_f1-score: 0.9751
# Epoch 29/100
# 35/35 [==============================] - 21s 606ms/step - loss: 0.3439 - iou_score: 0.9902 - f1-score: 0.9950 - val_loss: 0.3633 - val_iou_score: 0.9606 - val_f1-score: 0.9787
# Epoch 30/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3435 - iou_score: 0.9904 - f1-score: 0.9951 - val_loss: 0.3639 - val_iou_score: 0.9593 - val_f1-score: 0.9779
# Epoch 31/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3429 - iou_score: 0.9908 - f1-score: 0.9954 - val_loss: 0.3640 - val_iou_score: 0.9589 - val_f1-score: 0.9777
# Epoch 32/100
# 35/35 [==============================] - 21s 609ms/step - loss: 0.3433 - iou_score: 0.9898 - f1-score: 0.9948 - val_loss: 0.3630 - val_iou_score: 0.9600 - val_f1-score: 0.9784
# Epoch 33/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3426 - iou_score: 0.9906 - f1-score: 0.9953 - val_loss: 0.3647 - val_iou_score: 0.9576 - val_f1-score: 0.9769
# Epoch 34/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3427 - iou_score: 0.9904 - f1-score: 0.9951 - val_loss: 0.3631 - val_iou_score: 0.9591 - val_f1-score: 0.9778
# Epoch 35/100
# 35/35 [==============================] - 21s 601ms/step - loss: 0.3425 - iou_score: 0.9903 - f1-score: 0.9951 - val_loss: 0.3609 - val_iou_score: 0.9624 - val_f1-score: 0.9797
# Epoch 36/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3423 - iou_score: 0.9902 - f1-score: 0.9950 - val_loss: 0.3639 - val_iou_score: 0.9580 - val_f1-score: 0.9773
# Epoch 37/100
# 35/35 [==============================] - 18s 512ms/step - loss: 0.3421 - iou_score: 0.9903 - f1-score: 0.9951 - val_loss: 0.3612 - val_iou_score: 0.9616 - val_f1-score: 0.9793
# Epoch 38/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3417 - iou_score: 0.9907 - f1-score: 0.9953 - val_loss: 0.3622 - val_iou_score: 0.9600 - val_f1-score: 0.9783
# Epoch 39/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3410 - iou_score: 0.9918 - f1-score: 0.9958 - val_loss: 0.3625 - val_iou_score: 0.9593 - val_f1-score: 0.9780
# Epoch 40/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3405 - iou_score: 0.9924 - f1-score: 0.9961 - val_loss: 0.3621 - val_iou_score: 0.9602 - val_f1-score: 0.9785
# Epoch 41/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3406 - iou_score: 0.9919 - f1-score: 0.9959 - val_loss: 0.3620 - val_iou_score: 0.9600 - val_f1-score: 0.9783
# Epoch 42/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3403 - iou_score: 0.9924 - f1-score: 0.9961 - val_loss: 0.3609 - val_iou_score: 0.9615 - val_f1-score: 0.9792
# Epoch 43/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3408 - iou_score: 0.9911 - f1-score: 0.9955 - val_loss: 0.3609 - val_iou_score: 0.9612 - val_f1-score: 0.9790
# Epoch 44/100
# 35/35 [==============================] - 18s 511ms/step - loss: 0.3408 - iou_score: 0.9910 - f1-score: 0.9954 - val_loss: 0.3628 - val_iou_score: 0.9587 - val_f1-score: 0.9776
# Epoch 45/100
# 35/35 [==============================] - 18s 511ms/step - loss: 0.3402 - iou_score: 0.9920 - f1-score: 0.9960 - val_loss: 0.3617 - val_iou_score: 0.9600 - val_f1-score: 0.9783
# Epoch 46/100
# 35/35 [==============================] - 18s 514ms/step - loss: 0.3395 - iou_score: 0.9933 - f1-score: 0.9966 - val_loss: 0.3614 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 47/100
# 35/35 [==============================] - 18s 515ms/step - loss: 0.3390 - iou_score: 0.9944 - f1-score: 0.9972 - val_loss: 0.3612 - val_iou_score: 0.9609 - val_f1-score: 0.9788
# Epoch 48/100
# 35/35 [==============================] - 18s 512ms/step - loss: 0.3386 - iou_score: 0.9951 - f1-score: 0.9975 - val_loss: 0.3611 - val_iou_score: 0.9610 - val_f1-score: 0.9789
# Epoch 49/100
# 35/35 [==============================] - 18s 512ms/step - loss: 0.3384 - iou_score: 0.9955 - f1-score: 0.9977 - val_loss: 0.3612 - val_iou_score: 0.9607 - val_f1-score: 0.9787
# Epoch 50/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3383 - iou_score: 0.9959 - f1-score: 0.9979 - val_loss: 0.3612 - val_iou_score: 0.9607 - val_f1-score: 0.9788
# Epoch 51/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3382 - iou_score: 0.9962 - f1-score: 0.9981 - val_loss: 0.3613 - val_iou_score: 0.9607 - val_f1-score: 0.9787
# Epoch 52/100
# 35/35 [==============================] - 18s 512ms/step - loss: 0.3381 - iou_score: 0.9963 - f1-score: 0.9981 - val_loss: 0.3614 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 53/100
# 35/35 [==============================] - 18s 515ms/step - loss: 0.3380 - iou_score: 0.9965 - f1-score: 0.9982 - val_loss: 0.3613 - val_iou_score: 0.9607 - val_f1-score: 0.9787
# Epoch 54/100
# 35/35 [==============================] - 18s 515ms/step - loss: 0.3380 - iou_score: 0.9966 - f1-score: 0.9983 - val_loss: 0.3614 - val_iou_score: 0.9606 - val_f1-score: 0.9787
# Epoch 55/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3379 - iou_score: 0.9967 - f1-score: 0.9983 - val_loss: 0.3615 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 56/100
# 35/35 [==============================] - 18s 513ms/step - loss: 0.3379 - iou_score: 0.9968 - f1-score: 0.9984 - val_loss: 0.3615 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 57/100
# 35/35 [==============================] - 18s 511ms/step - loss: 0.3379 - iou_score: 0.9968 - f1-score: 0.9984 - val_loss: 0.3615 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 58/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3379 - iou_score: 0.9968 - f1-score: 0.9984 - val_loss: 0.3615 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 59/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3379 - iou_score: 0.9968 - f1-score: 0.9984 - val_loss: 0.3615 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 60/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3378 - iou_score: 0.9968 - f1-score: 0.9984 - val_loss: 0.3615 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 61/100
# 35/35 [==============================] - 18s 518ms/step - loss: 0.3378 - iou_score: 0.9968 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 62/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3378 - iou_score: 0.9968 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 63/100
# 35/35 [==============================] - 18s 511ms/step - loss: 0.3378 - iou_score: 0.9968 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 64/100
# 35/35 [==============================] - 18s 526ms/step - loss: 0.3378 - iou_score: 0.9968 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 65/100
# 35/35 [==============================] - 18s 518ms/step - loss: 0.3378 - iou_score: 0.9968 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 66/100
# 35/35 [==============================] - 18s 516ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 67/100
# 35/35 [==============================] - 18s 513ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 68/100
# 35/35 [==============================] - 18s 511ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 69/100
# 35/35 [==============================] - 18s 513ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 70/100
# 35/35 [==============================] - 18s 512ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 71/100
# 35/35 [==============================] - 18s 515ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 72/100
# 35/35 [==============================] - 18s 514ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 73/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 74/100
# 35/35 [==============================] - 18s 511ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 75/100
# 35/35 [==============================] - 18s 512ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 76/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 77/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 78/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 79/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 80/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 81/100
# 35/35 [==============================] - 18s 511ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3615 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 82/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3615 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 83/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 84/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 85/100
# 35/35 [==============================] - 18s 511ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 86/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 87/100
# 35/35 [==============================] - 18s 512ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3615 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 88/100
# 35/35 [==============================] - 18s 515ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 89/100
# 35/35 [==============================] - 18s 512ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 90/100
# 35/35 [==============================] - 18s 517ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 91/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 92/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 93/100
# 35/35 [==============================] - 18s 512ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 94/100
# 35/35 [==============================] - 18s 512ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 95/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 96/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 97/100
# 35/35 [==============================] - 18s 509ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 98/100
# 35/35 [==============================] - 18s 513ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 99/100
# 35/35 [==============================] - 18s 512ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786
# Epoch 100/100
# 35/35 [==============================] - 18s 510ms/step - loss: 0.3378 - iou_score: 0.9969 - f1-score: 0.9984 - val_loss: 0.3616 - val_iou_score: 0.9605 - val_f1-score: 0.9786

# %%
# Plot training & validation iou_score values
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['f1-score'])
plt.plot(history.history['val_f1-score'])
plt.title('Model f1 Score')
plt.ylabel('f1 Score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
n = 5

for i in range(n):
    
    image, gt_mask = valid_dataset[i]
    image = np.expand_dims(image, axis=0)
    pr_mask = model.predict(image).round()
    
    visualize(
        image=denormalize(image.squeeze()),
        gt_mask=gt_mask[..., 1].squeeze(),
        pr_mask=pr_mask[..., 1].squeeze(),
    )
